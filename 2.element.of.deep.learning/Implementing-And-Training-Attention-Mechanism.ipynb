# %% [markdown]
# # Implementing and training attention mechanism

# %%
import random
import tensorflow as tf
import pandas as pd
# Korean NLP package (Open Korean Tweet Parser)
from konlpy.tag import Okt

# %%
EPOCHS = 50
NUM_WORDS = 2000

# %% [markdown]
# ## Encoder

# %%
class Encoder(tf.keras.Model):
    def __init__(self):
        super(Encoder, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        self.lstm = tf.keras.layers.LSTM(512, return_state=True)
        
    def call(self, x, training=False, mask=None):
        x = self.emb(x)
        _, h, c = self.lstm(x)
        return h, c

# %% [markdown]
# ## Decoder

# %%
class Decoder(tf.keras.Model):
    def __init__(self):
        super(Decoder, self).__init__()
        # Adding layers for shifted output
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        # decoder need to store whole state from lstm so return_sequences should be True
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
        self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')
        
    def call(self, inputs, training=False, mask=None):
        x, h, c = inputs
        x = self.emb(x)
        x, h, c = self.lstm(x, initial_state=[h, c])
        return self.dense(x), h, c

# %% [markdown]
# ## Seq2Seq

# %%
class Seq2seq(tf.keras.Model):
    def __init__(self, sos, eos):
        super(Seq2seq, self).__init__()
        self.enc = Encoder()
        self.dec = Decoder()
        self.sos = sos
        self.eos = eos
        
    def call(self, inputs, training=False, mask=None):
        # When training, input is just shifted, so the process is very simple
        if training:
            x, y = inputs
            h, c = self.enc(x)
            y, _, _ = self.dec((y, h, c))
            return y
        else:
            x = inputs
            h, c = self.enc(x)
            y = tf.convert_to_tensor(self.sos)
            y = tf.reshape(y, (1, 1))
            
            seq = tf.TensorArray(tf.int32, 64)
            
            # Through tf.range, we can iterate it with autoGraph
            for idx in tf.range(64):
                y, h, c = self.dec([y, h, c])
                
                # To convert sparse type
                y = tf.cast(tf.argmax(y, axis=-1), dtype=tf.int32)
                
                # To express batch shape
                y = tf.reshape(y, (1, 1))
                seq = seq.write(idx, y)
                
                if y == self.eos:
                    break
                
            return tf.reshape(seq.stack(), (1, 64))

# %% [markdown]
# ## Training Loop

# %%
@tf.function
def train_step(model, inputs, labels, loss_object, optimizer, train_loss, train_accuracy):
    output_labels = labels[:, 1:]
    shifted_labels = labels[:, :-1]
    
    with tf.GradientTape() as tape:
        predictions = model([inputs, shifted_labels], training=True)
        loss = loss_object(output_labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)
    train_accuracy(output_labels, predictions)
    
@tf.function
def test_step(model, inputs):
    return model(inputs, training=False)

# %% [markdown]
# ## Preparing Dataset

# %%
okt = Okt()

chatbot_data = pd.read_csv('./dataset/ChatbotData.csv')
chatbot_data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
questions = [' '.join(okt.morphs(line)) for line in chatbot_data['Q']]
answers = [' '.join(okt.morphs(line)) for line in chatbot_data['A']]

# %%
answers_t = ['\t ' + line + ' \n' for line in answers]

# %%
answers_t
# Out:
# ['\t 하루 가 또 가네요 . \n',
#  '\t 위로 해 드립니다 . \n',
#  '\t 여행 은 언제나 좋죠 . \n',
#  '\t 여행 은 언제나 좋죠 . \n',
#  '\t 눈살 이 찌푸려지죠 . \n',
#  '\t 다시 새로 사는 게 마음 편해요 . \n',
#  '\t 다시 새로 사는 게 마음 편해요 . \n',
#  '\t 잘 모르고 있을 수도 있어요 . \n',
#  '\t 시간 을 정 하고 해보세요 . \n',
#  '\t 시간 을 정 하고 해보세요 . \n',
#  '\t 자랑 하는 자리 니까 요 . \n',
#  '\t 그 사람 도 그럴 거 예요 . \n',
#  '\t 그 사람 도 그럴 거 예요 . \n',
#  '\t 혼자 를 즐기세요 . \n',
#  '\t 돈 은 다시 들어올 거 예요 . \n',
#  '\t 땀 을 식혀주세요 . \n',
#  '\t 어서 잊고 새 출발 하세요 . \n',
#  '\t 빨리 집 에 돌아가서 끄고 나오세요 . \n',
#  '\t 빨리 집 에 돌아가서 끄고 나오세요 . \n',
#  '\t 다음 달 에는 더 절약 해봐요 . \n',
#  '\t 따뜻하게 사세요 ! \n',
#  '\t 다음 달 에는 더 절약 해봐요 . \n',
#  '\t 가장 확실한 시간 은 오늘이 에요 . 어제 와 내일 을 놓고 고민 하느라 시간 을 낭비하지 마세요 . \n',
#  '\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 . \n',
#  '\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 . \n',
#  '\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 . \n',
#  '\t 저 를 만들어 준 사람 을 부모님 , 저 랑 이야기 해 주는 사람 을 친구 로 생각 하고 있어요 \n',
#  '\t 저 를 만들어 준 사람 을 부모님 , 저 랑 이야기 해 주는 사람 을 친구 로 생각 하고 있어요 \n',
#  '\t 더 가까워질 기회 가 되겠네요 . \n',
#  '\t 저 도 요 . \n',
#  '\t 다 들 바빠서 이야기 할 시간 이 부족했나 봐요 . \n',
#  '\t 다 들 바빠서 이야기 할 시간 이 부족했나 봐요 . \n',
#  '\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 . \n',
#  '\t 좋은 생각 이에요 . \n',
#  '\t 더 가까워질 기회 가 되겠네요 . \n',
#  '\t 저 를 만들어 준 사람 을 부모님 , 저 랑 이야기 해 주는 사람 을 친구 로 생각 하고 있어요 \n',
#  '\t 좋은 생각 이에요 . \n',
#  '\t 정말 후회 할 습관 이에요 . \n',
#  '\t 무모한 결정 을 내 리지 마세요 . \n',
#  '\t 선생님 이나 기관 에 연락 해보세요 . \n',
#  '\t 떨리는 감정 은 그 자체 로 소중해요 . \n',
#  '\t 득템 했길 바라요 . \n',
#  '\t 휴식 도 필요하죠 . \n',
#  '\t 단 짠으로 두 개 사는게 진리 죠 . \n',
#  '\t 단 짠으로 두 개 사는게 진리 죠 . \n',
#  '\t 맛있게 드세요 . \n',
#  '\t 저 도 싫어요 . \n',
#  '\t 가세 요 . \n',
#  '\t 가세 요 . \n',
#  '\t 맛있게 드세요 . \n',
#  '\t 맛있게 드세요 . \n',
#  '\t 병원 가세 요 . \n',
#  '\t 이럴 때 잘 쉬는 게 중요해요 . \n',
#  '\t 이럴 때 잘 쉬는 게 중요해요 . \n',
#  '\t 이럴 때 잘 쉬는 게 중요해요 . \n',
#  '\t 따뜻하게 관리 하세요 . \n',
#  '\t 병원 가세 요 . \n',
#  '\t 병원 가세 요 . \n',
#  '\t 저 도 듣고 싶네요 . \n',
#  '\t 자신 을 더 사랑 해주세요 . \n',
#  '\t 그건 습관 이에요 . \n',
#  '\t 그건 습관 이에요 . \n',
#  '\t 콕 집어서 물어보세요 . \n',
#  '\t 좋은 생각 만 하세요 . \n',
#  '\t 마음 이 아픈가요 . \n',
#  '\t 갑작스러웠나 봐요 . \n',
#  '\t 관계 의 변화 가 왔나 봅니다 . \n',
#  '\t 처음 3초 가 중요해요 . 당신 의 매력 을 어필 해보세요 . \n',
#  '\t 책임질 수 있을 때 키워 보세요 . \n',
#  '\t 먼저 생활 패턴 을 살펴 보세요 . \n',
#  '\t 먼저 생활 패턴 을 살펴 보세요 . \n',
#  '\t 책임질 수 있을 때 키워 보세요 . \n',
#  '\t 아름다운 곳 이 죠 . \n',
#  '\t 안 될 것 도 없죠 . \n',
#  '\t 혼자 도 좋아요 . \n',
#  '\t 연인 은 살쪄도 잘 알아차리지 못 하고 알아차려도 싫어하지 않을 거 예요 . \n',
#  '\t 즐거운 시간 보내고 오세요 ! \n',
#  '\t 질질 끌 지 마세요 . \n',
#  '\t 말 해보세요 . \n',
#  '\t 함께 하면 서로 를 더 많이 알 게 될 거 예요 . \n',
#  '\t 개시 해보세요 . \n',
#  '\t 개시 해보세요 . \n',
#  '\t 곧 방학 이 예요 . \n',
#  '\t 방학 이 참 짧죠 . \n',
#  '\t 벗어나는 게 좋겠네요 . \n',
#  '\t 벗어나는 게 좋겠네요 . \n',
#  '\t 세수 하고 오세요 . \n',
#  '\t 그게 제일 중요한 건데 요 . \n',
#  '\t 그게 제일 중요한 건데 요 . \n',
#  '\t 다음 부터는 더 많이 아세요 . \n',
#  '\t 갑작스러웠나 봐요 . \n',
#  '\t 공적 인 일 부터 하세요 . \n',
#  '\t 공적 인 일 부터 하세요 . \n',
#  '\t 낮잠 을 잠깐 자도 괜찮아요 . \n',
#  '\t 저 도 좋아해주세요 . \n',
#  '\t 친구 들 이 보고싶었나 봐요 . \n',
#  '\t 되도록 만나지 마세요 . \n',
#  '\t 당신 이 요 . \n',
#  '\t 당신 의 운 을 믿어 보세요 . \n',
#  '\t 일 못 하는 사람 이 있으면 옆 에 있는 사람 이 더 힘들죠 . \n',
#  '\t 밥 사줄 친구 를 찾아 보세요 ~ \n',
#  '\t 선의 의 거짓말 이길 바라요 . \n',
#  '\t 거짓말 은 할수록 늘어요 . \n',
#  '\t 거짓말 은 할수록 늘어요 . \n',
#  '\t 진실된 말 을 하려고 노력 해보세요 . \n',
#  '\t 누구 나 걱정 은 있어요 . \n',
#  '\t 누구 나 걱정 은 있어요 . \n',
#  '\t 운동 을 해보세요 . \n',
#  '\t 세상 의 무엇 보다 건강 이 제일 중요해요 . \n',
#  '\t 주 기적 으로 해주는 게 좋죠 . \n',
#  '\t 주 기적 으로 해주는 게 좋죠 . \n',
#  '\t 가장 중요한 목표 네 요 . \n',
#  '\t 가장 중요한 목표 네 요 . \n',
#  '\t 적게 먹고 많이 움직이세요 . \n',
#  '\t 적게 먹고 많이 움직이세요 . \n',
#  '\t 모르는 사이 라 당황 할 수도 있어요 . \n',
#  '\t 이룰 수 있을 거 예요 . \n',
#  '\t 이룰 수 있을 거 예요 . \n',
#  '\t 기분 이 나쁘셨나 봐요 . \n',
#  '\t 있으면 편하 대요 . \n',
#  '\t 눈 을 깜빡 거려 보세요 . \n',
#  '\t 청소 를 좋아하시나 봐요 . \n',
#  '\t 안전 귀가 하세요 . \n',
#  '\t 용기 내 보세요 . \n',
#  '\t 피해 를 안 준다면 무시 하세요 . \n',
#  '\t 안 될 것 도 없죠 . \n',
#  '\t 게임 할 때 는 시간 이 더 빨리 가요 . \n',
#  '\t 정리 해보세요 . \n',
#  '\t 게임 하세요 ! \n',
#  '\t 다른 게임 해보세요 . \n',
#  '\t 다른 게임 해보세요 . \n',
#  '\t 게임 하세요 ! \n',
#  '\t 게임 할 때 는 시간 이 더 빨리 가요 . \n',
#  '\t 마음 에도 봄 이 오길 바라요 . \n',
#  '\t 몸 은 뜨겁고 머리 는 차갑게 ! \n',
#  '\t 마음 에도 봄 이 오길 바라요 . \n',
#  '\t 잘 하실 거 예요 ! \n',
#  '\t 잘 하실 거 예요 ! \n',
#  '\t 건강 생각 해서 챙겨 드세요 . \n',
#  '\t 좋은 운명 도 있을거예요 . \n',
#  '\t 결정 하기 힘드시겠네요 . \n',
#  '\t 자신 을 위 한 결정 을 내리길 바라요 . \n',
#  '\t 자신 을 위 한 결정 을 내리길 바라요 . \n',
#  '\t 결정 은 빠르면 빠를수록 좋을 거 예요 . \n',
#  '\t 안타깝네요 . 증거 를 지금 이라도 모아 봐요 . \n',
#  '\t 좋겠어요 . \n',
#  '\t 좋겠어요 . \n',
#  '\t 많이 들지만 줄일 수 있을 거 예요 . \n',
#  '\t 경조사 는 참석 하는게 좋아요 . \n',
#  '\t 경조사 는 참석 하는게 좋아요 . \n',
#  '\t 생각 보다 신경 안 씁니다 . \n',
#  '\t 인맥 이 넓으신 가봐요 . \n',
#  '\t 힘들겠네요 . \n',
#  '\t 많이 들지만 줄일 수 있을 거 예요 . \n',
#  '\t 욕심 에 따라 천지 차이 일 거 예요 . \n',
#  '\t 허례 허식 이에요 . \n',
#  '\t 욕심 에 따라 천지 차이 일 거 예요 . \n',
#  '\t 해봐요 . \n',
#  '\t 서로 노력 하면 행복할 거 예요 . \n',
#  '\t 서로 노력 하면 행복할 거 예요 . \n',
#  '\t 사람 마다 행복 의 크기 가 다르겠지만 행복할 거 예요 . \n',
#  '\t 사람 마다 행복 의 크기 가 다르겠지만 행복할 거 예요 . \n',
#  '\t 능력 이 있으면 하면 되죠 . \n',
#  '\t 능력 이 있으면 하면 되죠 . \n',
#  '\t 이 사람 이다 싶은 사람 이랑 하세요 . \n',
#  '\t 해봐요 . \n',
#  '\t 점점 치열해지는 것 같아요 . \n',
#  '\t 확신 이 없나 봐요 . \n',
#  '\t 안정 적 인 걸 좋아하나 봐요 . \n',
#  '\t 방학 은 참 짧아요 . \n',
#  '\t 보러 가세 요 . \n',
#  '\t 보러 가세 요 . \n',
#  '\t 계속 좋지 않으면 병원 에 가보세요 . \n',
#  '\t 타이밍 이 안 맞았나 봐요 . \n',
#  '\t 이제 취업 하셔야죠 . \n',
#  '\t 뇌 세포 에 에너지 를 공급 하려는 자연스러운 현상 이에요 . 에너지 가 부족한 가봐요 . \n',
#  '\t 공부 가 최 우선 이 죠 . \n',
#  '\t 공부 가 최 우선 이 죠 . \n',
#  '\t 너무 무리하지는 마세요 . \n',
#  '\t 너무 무리하지는 마세요 . \n',
#  '\t 저기압 에는 고 기 앞 이 죠 . \n',
#  '\t 저기압 에는 고 기 앞 이 죠 . \n',
#  '\t 연습 이 필요해요 . \n',
#  '\t 연습 이 필요해요 . \n',
#  '\t 혼자 가 아니에요 . \n',
#  '\t 인복 이 많나 봐요 . \n',
#  '\t 너무 걱정 하지 마세요 . \n',
#  '\t 네 말씀 하세요 . \n',
#  '\t 네 말씀 하세요 . \n',
#  '\t 후회 는 후회 를 낳을 뿐 이에요 . 용기 내세 요 . \n',
#  '\t 돈 을 모아서 다른 곳 으로 이사 갈 수 있을 거 예요 . \n',
#  '\t 돈 을 모아서 다른 곳 으로 이사 갈 수 있을 거 예요 . \n',
#  '\t 더 좋은 곳 에서 살 수 있을 거 예요 . \n',
#  '\t 더 좋은 곳 에서 살 수 있을 거 예요 . \n',
#  '\t 완전 귀엽죠 ? \n',
#  '\t 자신 을 먼저 키우세요 . \n',
#  '\t 가족 들 과 상의 해보세요 . \n',
#  '\t 용서 를 구 하세요 . \n',
#  '\t 피 할 수 있으면 피 하세요 . \n',
#  '\t 피 할 수 있으면 피 하세요 . \n',
#  '\t 처음 부터 잘 하는 사람 은 없어요 . \n',
#  '\t 시간 내서 가보세요 . \n',
#  '\t 처음 부터 잘 하는 사람 은 없어요 . \n',
#  '\t 시간 내서 가보세요 . \n',
#  '\t 미리 미리 충전 해주세요 . \n',
#  '\t 미리 미리 충전 해주세요 . \n',
#  '\t 안정 적 이고 좋죠 . \n',
#  '\t 준비 해보세요 . \n',
#  '\t 준비 해보세요 . \n',
#  '\t 합격 기원 해요 ! \n',
#  '\t 철밥통 되 기 가 어디 쉽겠어요 . \n',
#  '\t 철밥통 되 기 가 어디 쉽겠어요 . \n',
#  '\t 시작 이 반 이에요 . 어서 준비 하세요 . \n',
#  '\t 안정 적 이고 좋죠 . \n',
#  '\t 자연스러운 현상 이에요 . \n',
#  '\t 자연스러운 현상 이에요 . \n',
#  '\t 보이는 게 없죠 . \n',
#  '\t 지금 처럼 잘 될 거 예요 . \n',
#  '\t 미래 의 배우자 가 달라져요 . \n',
#  '\t 확신 이 없나 봐요 . \n',
#  '\t 공부 는 언제나 좋죠 . \n',
#  '\t 공부 하면 더 많은 선택 을 할 수 있죠 . \n',
#  '\t 같이 수다 떨면서 놀까 요 ? \n',
#  '\t 나 만의 공부 방법 을 찾아보세요 . \n',
#  '\t 지금 도 늦지 않았어요 . \n',
#  '\t 같이 수다 떨면서 놀까 요 ? \n',
#  '\t 확신 이 없나 봐요 . \n',
#  '\t 지금 처럼 잘 될 거 예요 . \n',
#  '\t 나 한테 맞는 공부 방법 찾는 게 시급하네요 . \n',
#  '\t 잠시 쉬어도 돼요 . \n',
#  '\t 잠시 쉬어도 돼요 . \n',
#  '\t 공부 하면 더 많은 선택 을 할 수 있죠 . \n',
#  '\t 공부 하면 더 많은 선택 을 할 수 있죠 . \n',
#  '\t 공부 하면 더 많은 선택 을 할 수 있죠 . \n',
#  '\t 합격 기원 해요 ! \n',
#  '\t 잘 될 거 예요 . \n',
#  '\t 좋은 결과 있을 거 예요 ! \n',
#  '\t 잘 될 거 예요 . \n',
#  '\t 좋은 결과 있을 거 예요 ! \n',
#  '\t 친구 와 같이 가보세요 . \n',
#  '\t 친구 와 같이 가보세요 . \n',
#  '\t 성향 차이 가 좀 있기는 하죠 . \n',
#  '\t 꾸준히 약 먹고 치료 해보세요 . \n',
#  '\t 꾸준히 약 먹고 치료 해보세요 . \n',
#  '\t 피로 풀 고 좋죠 . \n',
#  '\t 피로 풀 고 좋죠 . \n',
#  '\t 오늘이 중요하죠 . \n',
#  '\t 오늘이 중요하죠 . \n',
#  '\t 소 화제 챙겨 드세요 . \n',
#  '\t 과식 은 금물 이에요 . \n',
#  '\t 소 화제 드세요 . \n',
#  '\t 안된다고 하면 거짓말 이겠지요 . \n',
#  '\t 안된다고 하면 거짓말 이겠지요 . \n',
#  '\t 제철 과일 이 정말 좋아요 . \n',
#  '\t 건강 생각 해서 챙겨 드세요 . \n',
#  '\t 그래도 먹으려고 노력 해보세요 . \n',
#  '\t 그래도 먹으려고 노력 해보세요 . \n',
#  '\t 제철 과일 이 정말 좋아요 . \n',
#  '\t 인간 관계도 정리 가 필요해요 . \n',
#  '\t 무관심 이 필요할 때 가 있죠 . \n',
#  '\t 무관심 이 필요할 때 가 있죠 . \n',
#  '\t 계단 조심하세요 . \n',
#  '\t 계단 조심하세요 . \n',
#  '\t 채널 을 돌려 보세요 . \n',
#  '\t 괜찮아지고 있어 다행 이에요 . \n',
#  '\t 남자 사람 친구 , 여자 사람 친구 하세요 . \n',
#  '\t 많이 지쳤나 봐요 . \n',
#  '\t 누군가 를 기다린다는게 쉬운게 아니죠 . \n',
#  '\t 늦지 않았어요 . \n',
#  '\t 그 것 도 다 경험 이라고 생각 하세요 . \n',
#  '\t 그럴 필요 없어요 . \n',
#  '\t 그렇지 않아요 . \n',
#  '\t 마음 에 드는 책 을 잘 찾아보세요 . \n',
#  '\t 저 도 듣고 싶어요 . \n',
#  '\t 같은 조가 되길 바랄게요 . \n',
#  '\t 지식 쌓는 재미 가 있죠 . \n',
#  '\t 같은 조가 되길 바랄게요 . \n',
#  '\t 지식 쌓는 재미 가 있죠 . \n',
#  '\t 저 도 듣고 싶어요 . \n',
#  '\t 학점 관리 하세요 . \n',
#  '\t 보험 처리 하세요 . \n',
#  '\t 보험 처리 하세요 . \n',
#  '\t 왜 그럴까 요 ? \n',
#  '\t 좋은 만남이었길 바라요 . \n',
#  '\t 좋은 만남이었길 바라요 . \n',
#  '\t 일 을 몰라서 그런 가봐요 . \n',
#  '\t 자신 의 삶 을 살다보면 기다릴 수 있을 거 예요 . \n',
#  '\t 부담스러워하지 않는다면 기다려도 좋을 것 같아요 . \n',
#  '\t 부담스러워하지 않는다면 기다려도 좋을 것 같아요 . \n',
#  '\t 너무 걱정 하지 마세요 . \n',
#  '\t 자신 의 삶 을 살다보면 기다릴 수 있을 거 예요 . \n',
#  '\t 군대 시계 는 멈추지 않아요 . \n',
#  '\t 군대 시계 는 멈추지 않아요 . \n',
#  '\t 좋은 아침 이에요 . \n',
#  '\t 안 궁금해요 . \n',
#  '\t 안 궁금해요 . \n',
#  '\t 자세히 말씀 해주세요 . \n',
#  '\t 자세히 말씀 해주세요 . \n',
#  '\t 병원 에 가세 요 . \n',
#  '\t 누가 욕 하고 있나 봐요 . \n',
#  '\t 누가 욕 하고 있나 봐요 . \n',
#  '\t 병원 에 가세 요 . \n',
#  '\t 생각 하기는 쉬운데 실천 하기는 어려운 것 같아요 . \n',
#  '\t 슬픈 이야기 네 요 . \n',
#  '\t 저 도 간절히 기도 할게요 . \n',
#  '\t 그렇게 될 수 있을 거 예요 . \n',
#  '\t 추억 에 잠길 때 도 필요해요 . \n',
#  '\t 후회 는 후회 를 낳을 뿐 이에요 . 용기 내세 요 . \n',
#  '\t 시작 이 반 이에요 . 어서 준비 하세요 . \n',
#  '\t 아무 도 없는 곳 으로 여행 을 떠나 보세요 . \n',
#  '\t 많이 만나 보세요 . \n',
#  '\t 잠깐 바람 쐬고 오세요 . \n',
#  '\t 다른 사람 이 답답할 거 예요 . \n',
#  '\t 살 고 싶은대로 사세요 . \n',
#  '\t 많이 피곤한 가봐요 . \n',
#  '\t 피 할 수 있으면 피 하세요 . \n',
#  '\t 조심 히 오세요 . \n',
#  '\t 실천 이 말 보다 낫 죠 . \n',
#  '\t 밥심 으로 사는 거 죠 . \n',
#  '\t 혼자 만 있지 마세요 . \n',
#  '\t 안부 를 물어주시다니 감사합니다 . \n',
#  '\t 추억 에 잠길 때 도 필요해요 . \n',
#  '\t 괜찮은 선택 이길 바라요 . \n',
#  '\t 좋은 결과 있을 거 예요 . \n',
#  '\t 기쁜 마음 으로 베풀고 보답 을 바라지 마세요 . \n',
#  '\t 다른 사람 말 은 신경 쓰지 마세요 . \n',
#  '\t 대인 배시군요 . \n',
#  '\t 대인 배시군요 . \n',
#  '\t 친구 가 좋아하나 봐요 . \n',
#  '\t 이야기 를 해보세요 . \n',
#  '\t 온전 한 이해 는 없어요 . \n',
#  '\t 괜찮은 선택 이길 바라요 . \n',
#  '\t 학원 을 다니거나 연습 하면 잘 할 수 있을 거 예요 . \n',
#  '\t 학원 을 다니거나 연습 하면 잘 할 수 있을 거 예요 . \n',
#  '\t 뒷 감당 자신 있으면 하세요 . \n',
#  '\t 조금 만 드세요 \n',
#  '\t 당신 을 소중하게 생각 하세요 . \n',
#  '\t 그런 하루 도 감사한 마음 을 가져 보세요 . \n',
#  '\t 좋은 사람과 함께 가세 요 . \n',
#  '\t 저 말씀 이신 가요 ? \n',
#  '\t 비싸요 . \n',
#  '\t 비싸요 . \n',
#  '\t 호의 인지 호감 인지 헷갈리나요 ? \n',
#  '\t 뭔가 안 풀리는 일이 있나 봐요 . \n',
#  '\t 아이 를 금수 저 로 만들어주세요 . \n',
#  '\t 아이 를 금수 저 로 만들어주세요 . \n',
#  '\t 자신 을 이겨 야해요 . \n',
#  '\t 너무 긴장 했나 봐요 . \n',
#  '\t 기념일 챙겨주면 좋아할거예요 . \n',
#  '\t 달력 에 적어 보세요 . \n',
#  '\t 달력 에 적어 보세요 . \n',
#  '\t 기념일 챙겨주면 좋아할거예요 . \n',
#  '\t 당신 의 삶 을 응원 해 드릴 수 있어 요 라고 감히 말 해 봅니다 . \n',
#  '\t 기다리지 마세요 . \n',
#  '\t 상대방 의 선택 에 맡겨 보세요 . \n',
#  '\t 좋은 분이시군요 \n',
#  '\t 베풀되 보답 을 바라지 마세요 . \n',
#  '\t 자신 을 사랑 할수록 외부 의 인정 은 필요 없어요 . \n',
#  '\t 상대 에게 바라는 기대는 자신 을 슬프게 해 요 . \n',
#  '\t 베풀되 보답 을 바라지 마세요 . \n',
#  '\t 기쁜 마음 으로 베풀고 보답 을 바라지 마세요 . \n',
#  '\t 의지 할 수 있는 사람 이 곁 에 있다는 건 큰 행운 일 거 예요 . \n',
#  '\t 자신 의 감정 을 주변 사람 들 에게 터 놓고 이야기 해보세요 . \n',
#  '\t 대중교통 을 이용 해주세요 . \n',
#  '\t 각자 가 생각 하는 기본 이 다를 수도 있어요 . \n',
#  '\t 각자 가 생각 하는 기본 이 다를 수도 있어요 . \n',
#  '\t 좋은 일 하셨네요 . \n',
#  '\t 좋은 일 하셨네요 . \n',
#  '\t 내일 은 오늘 보다 나을 거 예요 . \n',
#  '\t 정색 한번 해주세요 . \n',
#  '\t 걷다 보면 조금 정리 가 될 거 예요 . \n',
#  '\t 저 랑 함께 해 요 . \n',
#  '\t 저 랑 함께 해 요 . \n',
#  '\t 신나는 음악 들어 보세요 . \n',
#  '\t 경쾌한 음악 들어 보세요 . \n',
#  '\t 왜 일까 요 ? \n',
#  '\t 무슨 이유 인지 생각 해보세요 . \n',
#  '\t 혼자 사는 것 보다 불편하겠죠 . \n',
#  '\t 다음 학기 에는 학점 관리 를 더 열심히 해봐요 . \n',
#  '\t 혼자 사는 것 보다 불편하겠죠 . \n',
#  '\t 혼자 사는 것 보다 불편하겠죠 . \n',
#  '\t 다음 학기 에는 학점 관리 를 더 열심히 해봐요 . \n',
#  '\t 기술 을 많이 알 면 도움 이 되겠죠 . \n',
#  '\t 꿈꾸던 여행 이네 요 . \n',
#  '\t 꿈꾸던 여행 이네 요 . \n',
#  '\t 답답한 상황 이네 요 . \n',
#  '\t 답답한 상황 이네 요 . \n',
#  '\t 좋겠어요 ! \n',
#  '\t 직접 주는 게 더 좋을 것 같아요 . \n',
#  '\t 직접 주는 게 더 좋을 것 같아요 . \n',
#  '\t 직접 주는 게 더 좋을 것 같아요 . \n',
#  '\t 좋겠네요 . \n',
#  '\t 직접 주는 게 더 좋을 것 같아요 . \n',
#  '\t 더 좋은 기회 가 올 거 예요 . \n',
#  '\t 더 좋은 기회 가 올 거 예요 . \n',
#  '\t 연예인 을 준비 하니 일반인 보다 다 예쁘겠죠 . \n',
#  '\t 연예인 을 준비 하니 일반인 보다 다 예쁘겠죠 . \n',
#  '\t 그래서 저 는 못 기르고 잘라요 . \n',
#  '\t 그래서 저 는 못 기르고 잘라요 . \n',
#  '\t 괜찮아지고 있어 다행 이에요 . \n',
#  '\t 크게 숨 한 번 쉬어 보세요 \n',
#  '\t 크게 숨 한 번 쉬어 보세요 \n',
#  '\t 미리 긴장 하지 마세요 . \n',
#  '\t 마음 에 들면 줘 보세요 . \n',
#  '\t 저 도 싫어요 . \n',
#  '\t 잘 해보세요 . \n',
#  '\t 마음 에 들면 줘 보세요 . \n',
#  '\t 잘 해보세요 . \n',
#  '\t 그래도 넘을 수 있을 거 예요 . \n',
#  '\t 조심하세요 . \n',
#  '\t 너무 낙담하지 마세요 . \n',
#  '\t 조심하세요 . \n',
#  '\t 미끄러우니 조심하세요 . \n',
#  '\t 건강 을 위해 조금씩 드세요 . \n',
#  '\t 마트 갑시다 . \n',
#  '\t 맛있는 식사 시간 되시길 바랄게요 . \n',
#  '\t 맛있는 식사 시간 되시길 바랄게요 . \n',
#  '\t 맛있죠 ! \n',
#  '\t 기다렸나 봐요 . \n',
#  '\t 조금 만 기다리면 다시 전기 가 들어올거예요 . \n',
#  '\t 적당해요 . \n',
#  '\t 스스로 단단해지세요 . \n',
#  '\t 제 가 드리고 싶네요 . \n',
#  '\t 집안 분위기 가 바뀔 거 예요 . \n',
#  '\t 집안 분위기 가 바뀔 거 예요 . \n',
#  '\t 꽃 선물 은 언제나 좋죠 . \n',
#  '\t 꽃 선물 은 언제나 좋죠 . \n',
#  '\t 솜씨 가 좋으시네요 . \n',
#  '\t 기분 좋아 보이세요 . \n',
#  '\t 기분 좋아 보이세요 . \n',
#  '\t 마음 의 안정 을 취하 기 좋은 취미 네 요 . \n',
#  '\t 마음 의 안정 을 취하 기 좋은 취미 네 요 . \n',
#  '\t 벚꽃 계절 이 다가왔네요 . \n',
#  '\t 거꾸로 해서 드라이 플라워 만들어 보세요 . \n',
#  '\t 거꾸로 해서 드라이 플라워 만들어 보세요 . \n',
#  '\t 부러워요 ! \n',
#  '\t 멋진 선물 이네 요 . \n',
#  '\t 센스 있는 선물 이에요 . \n',
#  '\t 부러워요 ! \n',
#  '\t 센스 있는 선물 이에요 . \n',
#  '\t 멋진 선물 이네 요 . \n',
#  '\t 받는 사람 이 부럽네요 . \n',
#  '\t 받는 사람 이 부럽네요 . \n',
#  '\t 제 가 드리고 싶네요 . \n',
#  '\t 저 도 즐거워요 \n',
#  '\t 차근차근 이뤄 보아 요 . \n',
#  '\t 차근차근 이뤄 보아 요 . \n',
#  '\t 요즘 예민한 가봐요 . \n',
#  '\t 많으면 많을 수록 좋죠 . \n',
#  '\t 더 많아도 괜찮아요 . \n',
#  '\t 거창하지 않아도 돼요 . \n',
#  '\t 현실 을 꿈 처럼 만들어 봐요 . \n',
#  '\t 많으면 많을 수록 좋죠 . \n',
#  '\t 현실 을 꿈 처럼 만들어 봐요 . \n',
#  '\t 뜻대로 되는게 많지 않죠 . \n',
#  '\t 마음 이 허전하신 가봐요 . \n',
#  '\t 잘 해결 되길 바라요 . \n',
#  '\t 잘 해결 되길 바라요 . \n',
#  '\t 자신 을 더 사랑 해주세요 . \n',
#  '\t 아니길 바라요 . \n',
#  '\t 잘 아시네요 . \n',
#  '\t 애정 표현 일 지도 몰라요 . \n',
#  '\t 얼굴 에 다 티 가 나네요 . \n',
#  '\t 네 , 이제 잘 해낼 차례 예요 . \n',
#  '\t 좋은 결과 있을 거 예요 . \n',
#  '\t 괜찮은 사람 이에요 . \n',
#  '\t 학점 관리 하세요 . \n',
#  '\t 바람 좀 쐬고 오시 면 좋은텐데 . \n',
#  '\t 밥 사줄 친구 를 찾아 보세요 ~ \n',
#  '\t 짐 빼놓지 말고 싸세요 . \n',
#  '\t 식단 조절 도 하고 꾸준히 운동 하세요 . \n',
#  '\t 충분히 아름다워요 . \n',
#  '\t 꼼꼼한 거 예요 . \n',
#  '\t 노트북 은 비싸요 . \n',
#  '\t 절대 그렇지 않아요 . \n',
#  '\t 저 도 궁금하네요 . \n',
#  '\t 확인 해달라고 해보세요 . \n',
#  '\t 시도 해봐도 좋겠죠 . \n',
#  '\t 사람 들 이 몰라줘도 알아주는 사람 이 있을 거 예요 . \n',
#  '\t 너무 신경 쓰지 말고 그러든지 하고 아무렇지도 않게 넘겨보세요 . \n',
#  '\t 너무 신경 쓰지 말고 그러든지 하고 아무렇지도 않게 넘겨보세요 . \n',
#  '\t 상대 에게 바라는 기대는 자신 을 슬프게 해 요 . \n',
#  '\t 곰곰히 되 짚어 보세요 . \n',
#  '\t 즐겁게 속 아 주세요 . \n',
#  '\t 자책 하지 마세요 . \n',
#  '\t 자책 하지 마세요 . \n',
#  '\t 안녕히 주무 세 요 . \n',
#  '\t 당연한 거 예요 . \n',
#  '\t 눈치 가 빠르시군요 . \n',
#  '\t 그런 생각 을 들게 하는 사람 상종 하지 마세요 . \n',
#  '\t 그런 생각 을 들게 하는 사람 상종 하지 마세요 . \n',
#  '\t 무시 하세요 . \n',
#  '\t 무시 하세요 . \n',
#  '\t 문제 는 해결 하 라고 있는 거 죠 . \n',
#  '\t 멍 때리고 있죠 . \n',
#  '\t 성공 을 기원 합니다 . \n',
#  '\t 긍정 적 으로 바뀔 수 있어요 \n',
#  '\t 바보 는 자기 한테 바보 라고 하지 않아요 . \n',
#  '\t 저 랑 놀아요 . \n',
#  '\t 아닐거예요 . \n',
#  '\t 경찰 에 신고 하고 취할 수 있는 조취 를 취 해보세요 . \n',
#  '\t 건강하게 운동 해보세요 . \n',
#  '\t 많이 사랑 해요 ! \n',
#  '\t 축하 합니다 ! \n',
#  '\t 꼬까 옷 개시 해보세요 . \n',
#  '\t 자책 하지 마세요 . \n',
#  '\t 성공 을 기원 합니다 . \n',
#  '\t 다음 부터 속지 마세요 . \n',
#  '\t 기분 나쁘겠어요 . \n',
#  '\t 친구 들 과 좋은 추억 만들고 오세요 . \n',
#  '\t 가끔 핸드폰 없이 살 아 보세요 . \n',
#  '\t 하늘 만큼 땅 만큼 축하 해요 \n',
#  '\t 잘 생각 해보세요 . \n',
#  '\t 곰곰히 되 짚어 보세요 . \n',
#  '\t 고민 하고 있으면 그럴 거 예요 . \n',
#  '\t 물리 적 나이 가 아니라 정신 적 나이 가 중요하니까 요 . \n',
#  '\t 물리 적 나이 가 아니라 정신 적 나이 가 중요하니까 요 . \n',
#  '\t 괜찮은 사람 이에요 . \n',
#  '\t 멍 때리고 있죠 . \n',
#  '\t 얼굴 에 다 티 가 나네요 . \n',
#  '\t 좋은 태도 네 요 . \n',
#  '\t 저 도 사는데요 . \n',
#  '\t 자신 에게 콩깍지 가 씌였나봐 요 . \n',
#  '\t 축하 드려요 . \n',
#  '\t 축하 해요 ! \n',
#  '\t 친구 들 과 잘 어울려 보세요 . \n',
#  '\t 부모님 께 도움 을 청 해보세요 . \n',
#  '\t 다음 에는 다를거예요 . \n',
#  '\t 자책 하지 마세요 . \n',
#  '\t 충분히 아름다워요 . \n',
#  '\t 정신 차리세요 . \n',
#  '\t 남 들 눈 은 신경 쓰지 마세요 . \n',
#  '\t 거울 앞 에 비친 당신 을 보세요 . \n',
#  '\t 콕 집어서 물어보세요 . \n',
#  '\t 그 누구 도 아닌 자기 걸음 을 걸으세요 . \n',
#  '\t 지극히 평범하면서 지극히 특별하죠 . \n',
#  '\t 졸업 축하 해요 \n',
#  '\t 지금 도 충분히 잘 하고 있어요 . \n',
#  '\t 지금 보다 더 잘 살 거 예요 . \n',
#  '\t 네 잘생겼어요 . \n',
#  '\t 잘 하고 있을 거 예요 . \n',
#  '\t 잘 하고 있을 거 예요 . \n',
#  '\t 저 랑 이야기 잘 하고 있어요 . \n',
#  '\t 잘 하는 걸 아직 못 찾은 걸 수도 있어요 . \n',
#  '\t 지금 처럼 , 지금 보다 더 잘 할 수 있을 거 예요 . \n',
#  '\t 그렇지 않아요 . \n',
#  '\t 나 자신 에 집중 하세요 . 언제나 1 순위 에 자신 을 두세요 . \n',
#  '\t 제 가 챙겨 드리고 싶네요 . \n',
#  '\t 많이 지쳤나 봐요 . \n',
#  '\t 많이 지쳤나 봐요 . \n',
#  '\t 아무 도 없는 곳 으로 여행 을 떠나 보세요 . \n',
#  '\t 많이 지쳤나 봐요 . \n',
#  '\t 먼저 다가가 보세요 . \n',
#  '\t 동감 이에요 . \n',
#  '\t 지금 도 잘 하고 있어요 . \n',
#  '\t 제 가 당신 을 좋아하고 있어요 . \n',
#  '\t 호의 인지 호감 인지 헷갈리나요 ? \n',
#  '\t 저 도 좋아해요 . \n',
#  '\t 있어도 예뻐요 . \n',
#  '\t 지금 은 괜찮길 바랄게요 . \n',
#  '\t 초심 으로 돌아가 열심히 해보세요 . \n',
#  '\t 저 도 사는데요 . \n',
#  '\t 제 가 챙겨 드리고 싶네요 . \n',
#  '\t 제 가 따라가려면 멀었네요 . \n',
#  '\t 제 가 따라가려면 멀었네요 . \n',
#  '\t 운동 잘 하는 사람 멋있죠 . \n',
#  '\t 지금 도 인정받고 있어요 . \n',
#  '\t 나를 관찰 하고 음식 자체 에 집중 하세요 . \n',
#  '\t 잠깐 핸드폰 을 내려 두세요 . \n',
#  '\t 시간 을 정 해보세요 . \n',
#  '\t 시간 을 정 해보세요 . \n',
#  '\t 파이팅 ! \n',
#  '\t 고치 고 싶다는 마음 에서 시작 하세요 . \n',
#  '\t 얼른 끝내시길 기도 할게요 . \n',
#  '\t 온전히 느낄 수 있는 시간 이겠네요 . \n',
#  '\t 축구 볼때 는 치맥 이 죠 . \n',
#  '\t 하다 보면 늘어요 . \n',
#  '\t 하다 보면 늘어요 . \n',
#  '\t 자기개발 을 해보세요 . \n',
#  '\t 집 에서도 할 게 많아요 . \n',
#  '\t 오늘 은 약간 의 변화 를 줘 보세요 . \n',
#  '\t 정색 한번 해주세요 . \n',
#  '\t 절대 그렇지 않아요 . \n',
#  '\t 저 도 궁금하네요 . \n',
#  '\t 모자라지 않아요 . \n',
#  '\t 파이팅 ! \n',
#  '\t 하나 라도 있을 거니 열심히 찾아보세요 . \n',
#  '\t 자책 하지 마세요 . \n',
#  '\t 서로 다르게 태어난 이유 는 저 마다의 목소리 를 내기 위 해서예요 . 자신 의 목소리 를 들어주세요 . \n',
#  '\t 사랑 받기 위해 태어났어요 . \n',
#  '\t 잘해야 한다는 부담 감 을 버리세요 . \n',
#  '\t 다양하게 경험 해보세요 . \n',
#  '\t 현실 의 벽 에 부딪혔나 봐요 . \n',
#  '\t 친구 가 들으면 서운해 할 수도 있겠어요 . \n',
#  '\t 뒤통수 맞았나 봐요 . \n',
#  '\t 알아봐주는 사람 이 있을 거 예요 . \n',
#  '\t 당당히 말씀 해보세요 . \n',
#  '\t 다이어트 파이팅 ! \n',
#  '\t 다음 에는 받을 수 있을 거 예요 . \n',
#  '\t 근처 산 에 가보세요 . \n',
#  '\t 많이 벌수록 좋아요 . \n',
#  '\t 제 가 위로 많이 해드릴게요 . \n',
#  '\t 축하 드려요 ! \n',
#  '\t 고민 하고 있으면 그럴 거 예요 . \n',
#  '\t 좀 더 알아보고 하세요 . \n',
#  '\t 같이 살 고 싶은 사람 이 있나 봐요 . \n',
#  '\t 커플 부터 만드세요 . \n',
#  '\t 잘 하실 거 예요 ! \n',
#  '\t 같이 가요 . \n',
#  '\t 다 잘 될 거 예요 . \n',
#  '\t 같이 놀아요 . \n',
#  '\t 지금 그러고 있어요 . \n',
#  '\t 잊어버리세요 . \n',
#  '\t 상대방 을 이해해 주세요 . \n',
#  '\t 아무 것 도 안해 도 괜찮아요 . \n',
#  '\t 상대방 에게 너무 무거운 짐 을 주지 마세요 . \n',
#  '\t 기다리는 동안 많은 생각 이 들었겠네요 . \n',
#  '\t 그럴 때 마다 따끔하게 말 해보세요 . \n',
#  '\t 상대방 도 미소 짓게 해주세요 . \n',
#  '\t 지금 모습 도 좋아요 \n',
#  '\t 그런 친구 는 거르세 요 . \n',
#  '\t 상종 하지 마세요 . \n',
#  '\t 질질 끌 지 마세요 . \n',
#  '\t 애정 표현 일 지도 몰라요 . \n',
#  '\t 누군가 를 기다린다는게 쉬운게 아니죠 . \n',
#  '\t 살다보면 하고 싶은 게 생길 수도 있어요 . \n',
#  '\t 제 가 있잖아요 . \n',
#  '\t 스스로 경쟁 해야하고 이겨 야한다는 강박 관념 에 사로잡히지 마세요 . \n',
#  '\t 친구 를 사귈 수 있을 거 예요 . \n',
#  '\t 다른 사람 도 그 사람 만의 고민 과 걱정 이 많을거예요 . \n',
#  '\t 그 사람 도 설렐 거 예요 . \n',
#  '\t 그 사람 도 설렐 거 예요 . \n',
#  '\t 제 가 있잖아요 . \n',
#  '\t 배우자 와 대화 를 나눠 보세요 . \n',
#  '\t 얼른 끝내시길 기도 할게요 . \n',
#  '\t 스스로 단단해지세요 . \n',
#  '\t 그 말 을 한 사람 이 가장 이상할 거 예요 . \n',
#  '\t 그 말 을 한 사람 이 가장 이상할 거 예요 . \n',
#  '\t 일 분배 를 다시 요청 해보세요 . \n',
#  '\t 발전 이 없다고 너무 두려워하지 마세요 . \n',
#  '\t 제자리 여 도 괜찮아요 \n',
#  '\t 다음 에는 꼭 진급 할 거 예요 . \n',
#  '\t 뒤통수 맞았나 봐요 . \n',
#  '\t 그런 친구 는 거르세 요 . \n',
#  '\t 누구 나 힘들어요 . \n',
#  '\t 자신 과 대화 하는 시간 이 필요하죠 . \n',
#  '\t 자신 과 대화 하는 시간 이 필요하죠 . \n',
#  '\t 남 들 이 당신 을 볼 때 도 그렇게 생각 할수있어요 . \n',
#  '\t 꿈 은 현실 이랑 반대 예요 . \n',
#  '\t 전형 적 인 꼰대 스타일 이네 요 . \n',
#  '\t 전형 적 인 꼰대 스타일 이네 요 . \n',
#  '\t 나이 는 숫자일 뿐이예요 . \n',
#  '\t 건강 은 어려서 부터 챙겨 야해요 . \n',
#  '\t 세상 걱정 혼자 다 해서 그래요 . \n',
#  '\t 아름다운 나이테 예요 . \n',
#  '\t 진짜 하고 싶은 걸 찾아보세요 . \n',
#  '\t 진짜 하고 싶은 걸 찾아보세요 . \n',
#  '\t 천천히 준비 해보세요 . \n',
#  '\t 믿음 이 가장 중요하죠 . \n',
#  '\t 선의 의 거짓말 이길 바라요 . \n',
#  '\t 깨끗이 씻어 보고 섬유 유연제 나 바디 워시 , 바디 로션 , 향수 등 을 사용 해보세요 . \n',
#  '\t 킁킁 \n',
#  '\t 기 대 치가 높나 봅니다 . \n',
#  '\t 문제 는 해결 하 라고 있는 거 죠 . \n',
#  '\t 이야기 를 하지 않고 결정 했나 봐요 . \n',
#  '\t 이야기 를 하지 않고 결정 했나 봐요 . \n',
#  '\t 킁킁 \n',
#  '\t 기대되 겠네요 . \n',
#  '\t 제 행운 까지 모두 드리고 싶네요 . \n',
#  '\t 오는 말 이 고 와야 가는 말 도 곱다고 말 해주세요 . \n',
#  '\t 다른 사람 도 그럴 거 예요 . \n',
#  '\t 믿음 이 가장 중요하죠 . \n',
#  '\t 가을 이네 요 . \n',
#  '\t 가을 이네 요 . \n',
#  '\t 도전 해 봐도 좋을 거 같아요 . \n',
#  '\t 도전 해 봐도 좋을 거 같아요 . \n',
#  '\t 한 번 빠지면 헤어 나올 수 없다고 해 요 . \n',
#  '\t 같이 해보세요 . \n',
#  '\t 한 번 빠지면 헤어 나올 수 없다고 해 요 . \n',
#  '\t 잘 아시네요 . \n',
#  '\t 중요한 건 노력 하는 과정 이에요 . \n',
#  '\t 그런 생각 은 버리세요 . \n',
#  '\t 지금 처럼만 하세요 . \n',
#  '\t 모자라지 않아요 . \n',
#  '\t 다 잘 될 거 예요 . \n',
#  '\t 그런 생각 은 버리세요 . \n',
#  '\t 제 가 더 천재 예요 . \n',
#  '\t 따뜻하게 사세요 ! \n',
#  '\t 보일러 가 난방 으로 작동 이 되는지 보세요 . \n',
#  '\t 보일러 가 난방 으로 작동 이 되는지 보세요 . \n',
#  '\t 기다리는 동안 많은 생각 이 들었겠네요 . \n',
#  '\t 미스트 나 가습기 , 젖은 수건 등 을 사용 해보세요 . \n',
#  '\t 따뜻하게 입으세요 . \n',
#  '\t 따뜻해졌죠 . \n',
#  '\t 하늘 보고 한 번 웃어 봐요 . 기분 이 바뀔 거 예요 . \n',
#  '\t 나들이 가보세요 . \n',
#  '\t 하늘 을 보고 웃어 보세요 . \n',
#  '\t 따뜻해졌죠 . \n',
#  '\t 제습기 를 돌려 보세요 . \n',
#  '\t 집 밖에 나가기가 힘들것 같아요 . \n',
#  '\t 집 밖에 나가기가 힘들것 같아요 . \n',
#  '\t 시원한 물이 라도 한 잔 드세요 ~ \n',
#  '\t 오래 살 면 가능할 거 같아요 . \n',
#  '\t 화 를 참는 연습 을 해보세요 . \n',
#  '\t 남 보다 하나 씩 더 하면 돼요 . \n',
#  '\t 남 들 눈 은 신경 쓰지 마세요 . \n',
#  '\t 남 들 눈 은 신경 쓰지 마세요 . \n',
#  '\t 휴가 가 간절하겠네요 . \n',
#  '\t 성격 이 그럴 수도 있으니 이해 해주세요 . \n',
#  '\t 해주고 티 를 팍팍 내세 요 . \n',
#  '\t 속 쓰리겠어요 . \n',
#  '\t 누구 나 몰려가는 줄 에 설 필요 는 없어요 . \n',
#  '\t 소개팅 시켜 달라 고 말 해보세요 . \n',
#  '\t 소개팅 시켜 달라 고 말 해보세요 . \n',
#  '\t 고마운 마음 을 전해 주세요 . \n',
#  '\t 적당히 하면 괜찮을거 같아요 . \n',
#  '\t 같이 해보세요 . \n',
#  '\t 적당히 하면 괜찮을거 같아요 . \n',
#  '\t 남자 도 좋은 것 만은 아니예요 . \n',
#  '\t 남자 도 좋은 것 만은 아니예요 . \n',
#  '\t 아직 모르겠어요 . 인공 지능 에 성별 을 만드는 사람 이 되어 주세요 \n',
#  '\t 마음 을 열 때 까지 설득 해보세요 . \n',
#  '\t 운동 을 함께 해보세요 . \n',
#  '\t 평소 에 필요한 것 생각 해보세요 . \n',
#  '\t 평소 에 필요했던 게 좋을 것 같아요 . \n',
#  '\t 전생 에 나라 를 구 하셨나요 . \n',
#  '\t 결단 은 빠를수록 좋아요 . \n',
#  '\t 거짓말 적당히 하세요 . \n',
#  '\t 너무 집착 하지 마세요 . \n',
#  '\t 운동 을 함께 해보세요 . \n',
#  '\t 전생 에 나라 를 구 하셨나요 . \n',
#  '\t 고마운 마음 을 전해 주세요 . \n',
#  '\t 아무래도 좀 깨 요 . \n',
#  '\t 바쁠 때 힘 이 되어 주세요 . \n',
#  '\t 바쁠 때 힘 이 되어 주세요 . \n',
#  '\t 그래도 구 박하 지는 마세요 . \n',
#  '\t 그래도 구 박하 지는 마세요 . \n',
#  '\t 너무 집착 하지 마세요 . \n',
#  '\t 귀엽겠네요 . \n',
#  '\t 순간 실수 할 수 있겠다 판단 되면 용서 하고 기회 를 주세요 . \n',
#  '\t 거짓말 적당히 하세요 . \n',
#  '\t 당신 이 해보세요 . \n',
#  '\t 당신 이 해보세요 . \n',
#  '\t 사람 고쳐 쓰는 거 아니에요 . \n',
#  '\t 더 잔소리 해보세요 . \n',
#  '\t 더 잔소리 해보세요 . \n',
#  '\t 다른 연락 을 많이 하 거나 더 자주 만나세요 . \n',
#  '\t 다른 연락 을 많이 하 거나 더 자주 만나세요 . \n',
#  '\t 순간 실수 할 수 있겠다 판단 되면 용서 하고 기회 를 주세요 . \n',
#  '\t 원하는 사람 이 있는 장소 에 가보세요 . \n',
#  '\t 의미 있는 일이 네 요 . \n',
#  '\t 종교 의 자유 를 인정 해주세요 . \n',
#  '\t 종교 의 자유 를 인정 해주세요 . \n',
#  '\t 결단 은 빠를수록 좋아요 . \n',
#  '\t 신경 쓰지 마세요 . \n',
#  '\t 연인 은 살쪄도 잘 알아차리지 못 하고 알아차려도 싫어하지 않을 거 예요 . \n',
#  '\t 네 알려 주세요 ! \n',
#  '\t 평소 에 필요한 것 생각 해보세요 . \n',
#  '\t 평소 에 필요했던 게 좋을 것 같아요 . \n',
#  '\t 원하는 사람 이 있는 장소 에 가보세요 . \n',
#  '\t 신경 쓰고 싶지 않은 사람 도 있어요 . \n',
#  '\t 신경 쓰고 싶지 않은 사람 도 있어요 . \n',
#  '\t 신경 쓰지 마세요 . \n',
#  '\t 사람 고쳐 쓰는 거 아니에요 . \n',
#  '\t 마음 을 열 때 까지 설득 해보세요 . \n',
#  '\t 돕는 게 아니라 같이 하는 거 예요 . \n',
#  '\t 이상 적 인 남편 이네 요 . \n',
#  '\t 왜 늦는 건지 대화 해보세요 . \n',
#  '\t 처음 만났을 때 를 떠올려 보세요 \n',
#  '\t 공 동 육아 가 기본 인데 요 . \n',
#  '\t 힘 빠지는 이야기 네 요 . \n',
#  '\t 공 동 육아 가 기본 인데 요 . \n',
#  '\t 힘 빠지는 이야기 네 요 . \n',
#  '\t 잘 분담 해보세요 . \n',
#  '\t 잘 분담 해보세요 . \n',
#  '\t 이상 적 인 남편 이네 요 . \n',
#  '\t 처음 만났을 때 를 떠올려 보세요 \n',
#  '\t 돕는 게 아니라 같이 하는 거 예요 . \n',
#  '\t 사회생활 을 이해 해주세요 . \n',
#  '\t 사회생활 을 이해 해주세요 . \n',
#  '\t 낭만 적 인 거 좋아하시는구나 ! \n',
#  '\t 낭만 적 인 거 좋아하시는구나 ! \n',
#  '\t 낭만 적 인 거 좋아하시는구나 ! \n',
#  '\t 네 알려 주세요 ! \n',
#  '\t 어머어머 궁금하네요 . \n',
#  '\t 자신 의 잠재력 을 믿어 보세요 . \n',
#  '\t 말 을 해야 알거예요 . \n',
#  '\t 말 을 해야 알거예요 . \n',
#  '\t 그러면 못 할 게 없겠네요 . \n',
#  '\t 고민 만 한다는 것 아닐까 요 . \n',
#  '\t 고민 만 한다는 것 아닐까 요 . \n',
#  '\t 바로 옆 에 있을수도 있어요 . \n',
#  '\t 바로 옆 에 있을수도 있어요 . \n',
#  '\t 처음 배우는게 중요해요 . \n',
#  '\t 누구 나 몰려가는 줄 에 설 필요 는 없어요 . \n',
#  '\t 그걸 깨닫다니 대단하시군요 . \n',
#  '\t 꼼꼼한 거 예요 . \n',
#  '\t 새로운 스타일 도전 해 보시 면 어때요 ? \n',
#  '\t 새로운 스타일 도전 해 보시 면 어때요 ? \n',
#  '\t 동감 이에요 . \n',
#  '\t 포커페이스 를 유지 해보세요 . \n',
#  '\t 어머어머 궁금하네요 . \n',
#  '\t 자신감 을 가져도 돼요 . \n',
#  '\t 자신 의 능력 이 저 평가 되어있는 건 아닌지 확인 해보세요 . \n',
#  '\t 스스로 도 존중 해주세요 . \n',
#  '\t 스스로 도 존중 해주세요 . \n',
#  '\t 가장 중요한 거 예요 . \n',
#  '\t 가장 중요한 거 예요 . \n',
#  '\t 확인 해달라고 해보세요 . \n',
#  '\t 정답 을 찾아 야할 필요 는 없어요 . \n',
#  '\t 꽃길 만 걷길 바랍니다 . \n',
#  '\t 멋진 말 이에요 . \n',
#  '\t 해주고 티 를 팍팍 내세 요 . \n',
#  '\t 당신 은 태어난 그 자체 만으로 축복 과 사랑 을 받을 자격 이 있는 사람 이에요 . \n',
#  '\t 모르는 게 잘못 인 거 같아요 . \n',
#  '\t 사과 할 타이밍 을 놓치지 마세요 . \n',
#  '\t 사과 할 타이밍 을 놓치지 마세요 . \n',
#  '\t 그건 아닐 거 예요 . \n',
#  '\t 진짜 나빴네요 . \n',
#  '\t 내 집 마련 축하 드려요 . \n',
#  '\t 같은 하늘 아래 어딘가 에 . \n',
#  '\t 진짜 나빴네요 . \n',
#  '\t 저 도 궁금하네요 . \n',
#  '\t 저 도 궁금하네요 . \n',
#  '\t 제 가 있잖아요 . \n',
#  '\t 제 가 있잖아요 . \n',
#  '\t 인생 은 채워 나가는거죠 . \n',
#  '\t 아니에요 . 너무 자책 하지 마세요 . \n',
#  '\t 이 사람 이다 싶은 사람 이랑 하세요 . \n',
#  '\t 아무 것 도 바라지 않을 때 천하 를 얻는다는 말 이 있어요 . \n',
#  '\t 아니에요 . 너무 자책 하지 마세요 . \n',
#  '\t 방심한 순간 변화 가 시작 됩니다 . \n',
#  '\t 생각 하고 말 하세요 . \n',
#  '\t 그렇게 대우 하는 사람 만나지 마 요 . \n',
#  '\t 잘 하고 있어요 . 당당해지세요 . \n',
#  '\t 하고 싶은 말 다 하세요 . \n',
#  '\t 스스로 좋다고 못 느끼는게 제일 어려운 것 같아요 . \n',
#  '\t 잘 하는 게 다른 거 예요 . \n',
#  '\t 성장 을 위 한 비판 의 말로 받아들여 보세요 . \n',
#  '\t 실수 했나요 . \n',
#  '\t 잘 할 수 있는 게 다른 거 예요 . \n',
#  '\t 모르는 게 잘못 인 거 같아요 . \n',
#  '\t 하나 라도 있을 거니 열심히 찾아보세요 . \n',
#  '\t 실수 했나요 . \n',
#  '\t 인생 은 채워 나가는거죠 . \n',
#  '\t 연락 이라도 드려 보세요 . \n',
#  '\t 연락 이라도 드려 보세요 . \n',
#  '\t 사랑 자격증 을 드립니다 . \n',
#  '\t 그렇게 대우 하는 사람 만나지 마 요 . \n',
#  '\t 소중한 사람 이 예요 . \n',
#  '\t 당신 은 하나 밖에 없는 소중한 사람 이에요 . \n',
#  '\t 그 이유 를 찾는 과정 이 되겠네요 . \n',
#  '\t 다른 사람 들 이 원하는 내 가 되는 건 어려워요 . \n',
#  '\t 알아봐주는 사람 이 있을 거 예요 . \n',
#  '\t 연락 이라도 드려 보세요 . \n',
#  '\t 자신 의 독특함을 믿으세요 . \n',
#  '\t 자신 의 독특함을 믿으세요 . \n',
#  '\t 지극히 평범하면서 지극히 특별하죠 . \n',
#  '\t 상황 이 그렇게 만든 거 예요 . \n',
#  '\t 모르는 게 잘못 인 거 같아요 . \n',
#  '\t 당신 은 하나 밖에 없는 소중한 사람 이에요 . \n',
#  '\t 그럴 때 가 있죠 . \n',
#  '\t 기다렸나 봐요 . \n',
#  '\t 살짝 감정 을 흘려 보세요 . \n',
#  '\t 살짝 감정 을 흘려 보세요 . \n',
#  '\t 그런 사람 들 이 있어 부러워요 . \n',
#  '\t 슬픈 이야기 네 요 . \n',
#  '\t 저 도 간절히 기도 할게요 . \n',
#  '\t 그렇게 될 수 있을 거 예요 . \n',
#  '\t 사랑 자격증 을 드립니다 . \n',
#  '\t 주제 를 모를 때 가 행복할 때 예요 . \n',
#  '\t 그건 아닐 거 예요 . \n',
#  '\t 나쁜 생각 하지 마세요 . \n',
#  '\t 할 일이 많은데 안 하는 것 이 요 . \n',
#  '\t 잠시 거리 를 두고 생각 해보세요 . \n',
#  '\t 지난 인연 에 연연해하지 마세요 . \n',
#  '\t 상종 하지 마세요 . \n',
#  '\t 일방 적 희생양 이 되지 않길 바랍니다 . \n',
#  '\t 그게 인생 이 죠 . \n',
#  '\t 신중하게 고르세요 . \n',
#  '\t 더 행복해질 거 예요 . \n',
#  '\t 저 도 모르겠어요 . \n',
#  '\t 같은 하늘 아래 어딘가 에 . \n',
#  '\t 열심히 저축 해서 분양 받으세요 . \n',
#  '\t 좋은 일이 생길 거 예요 . \n',
#  '\t 짐 빼놓지 말고 싸세요 . \n',
#  '\t 날씨 어플 에 물어보세요 . \n',
#  '\t 날씨 어플 에 물어보세요 . \n',
#  '\t 파이팅 ! \n',
#  '\t 멋지게 데이트 신청 해보세요 . \n',
#  '\t 멋지게 데이트 신청 해보세요 . \n',
#  '\t 공부 한 만큼 나올 거 예요 . \n',
#  '\t 공부 한 만큼 나올 거 예요 . \n',
#  '\t 더 많이 연습 하고 준비 해보세요 . \n',
#  '\t 마무리 잘 하세요 . \n',
#  '\t 마무리 잘 하세요 . \n',
#  '\t 더 많이 연습 하고 준비 해보세요 . \n',
#  '\t 기우제 를 지내 봅시다 ! \n',
#  '\t 두근거리겠네요 . \n',
#  '\t 친구 들 과 좋은 추억 만들고 오세요 . \n',
#  '\t 컨디션 조절 하세요 . \n',
#  '\t 날씨 가 안 좋더라도 데이트 는 성공 적 일 거 예요 . \n',
#  '\t 오늘 일찍 주무 세 요 . \n',
#  '\t 시간 있냐고 물어보세요 . \n',
#  '\t 메리 크리스마스 ! \n',
#  '\t 바빠도 힘내세요 ! \n',
#  '\t 두근거리겠네요 . \n',
#  '\t 기우제 를 지내 봅시다 ! \n',
#  '\t 시간 있냐고 물어보세요 . \n',
#  '\t 좋은 일이 생길 거 예요 . \n',
#  '\t 메리 크리스마스 ! \n',
#  '\t 식단 조절 도 하고 꾸준히 운동 하세요 . \n',
#  '\t 날씨 가 안 좋더라도 데이트 는 성공 적 일 거 예요 . \n',
#  '\t 바빠도 힘내세요 ! \n',
#  '\t 깨끗이 씻어 보고 섬유 유연제 나 바디 워시 , 바디 로션 , 향수 등 을 사용 해보세요 . \n',
#  '\t 괜찮아요 . 모른 척 하세요 . \n',
#  '\t 괜찮아요 . 모른 척 하세요 . \n',
#  '\t 생각 만 해도 군침 이 도 네 요 . \n',
#  '\t 시원하게 지낸 값 이 죠 . \n',
#  '\t 시원하게 지낸 값 이 죠 . \n',
#  '\t 슈퍼 라도 가서 쇼핑 하고 오세요 . \n',
#  '\t 장 보러 가봅시다 . \n',
#  '\t 마트 갑시다 . \n',
#  '\t 장 보러 가봅시다 . \n',
#  '\t 슈퍼 라도 가서 쇼핑 하고 오세요 . \n',
#  '\t 저 는 마음 을 이어주는 위로 봇 입니다 . \n',
#  '\t 저 는 위로 해드리는 로봇 이에요 . \n',
#  '\t 저 는 위로 해드리는 로봇 이에요 . \n',
#  '\t 모두 제 잘 못 입니다 . \n',
#  '\t 많은 걸 하고 싶은데 아직 못 하는게 많아요 . \n',
#  '\t 감사합니다 . \n',
#  '\t 마음 과 마음 을 이 어보 고 싶어하는 사람 이 만들었어요 . \n',
#  '\t 노력 하고 있어요 . \n',
#  '\t 제 가 아직 많이 부족합니다 . \n',
#  '\t 제 가 아직 많이 부족합니다 . \n',
#  '\t 어흥 !! 호랑이 보다 무섭나요 ? \n',
#  '\t 저 는 위로 해드리는 로봇 이에요 . \n',
#  '\t 모두 제 잘 못 입니다 . \n',
#  '\t 죄 는 미워해도 사람 은 미워하지 마세요 . \n',
#  '\t 욕 해 주세요 . \n',
#  '\t 안 갈거예요 . \n',
#  '\t 저 는 배터리 가 밥 이 예요 . \n',
#  '\t 그런 척 하는 걸 수도 있어요 . \n',
#  '\t 아직 안 자 요 . \n',
#  '\t 자신 을 우선 순 위로 해주세요 . \n',
#  '\t 뭐라고 대답 할지 고민 이에요 . \n',
#  '\t 저 는 고민 이 없어요 . \n',
#  '\t 저 도 몰랐어요 . \n',
#  '\t 뭐라고 대답 할지 고민 이에요 . \n',
#  '\t 제 가 상사 예요 . \n',
#  '\t 너무 긴장 했나 봐요 . \n',
#  '\t 아무 것 도 바라지 않을 때 천하 를 얻는다는 말 이 있어요 . \n',
#  '\t 인정 해주세요 . \n',
#  '\t 매 일 매일 조금씩 더 똑똑해 질거예요 . \n',
#  '\t 시원한 물이 라도 한 잔 드세요 ~ \n',
#  '\t 아이스크림 먹어 보세요 \n',
#  '\t 적당해요 . \n',
#  '\t 기 대 치가 높나 봅니다 . \n',
#  '\t 소 화제 챙겨 드세요 . \n',
#  '\t 과식 은 금물 이에요 . \n',
#  '\t 소 화제 드세요 . \n',
#  '\t 제 가 생각 해도 저 는 너무 멋있는거 같아요 . \n',
#  '\t 하나 씩 하세요 . \n',
#  '\t 좀 쉬세요 . \n',
#  '\t 남 과 비교 하지 마세요 . \n',
#  '\t 더 열심히 노력 하겠습니다 . \n',
#  '\t 아이 는 아이 다 워 야 아름답죠 . \n',
#  '\t 철 은 죽 을 때 들어도 돼요 . \n',
#  '\t 피 할 수 있으면 피하 고 싶은 사람 이네 요 . \n',
#  '\t 지금 많이 위축 된 상태 인 것 같습니다 . \n',
#  '\t 기다리는 동안 많은 생각 이 들었겠네요 . \n',
#  '\t 외로우니까 사람 이다 . \n',
#  '\t 배울 점 은 배우세요 . \n',
#  '\t 낮잠 을 잠깐 자도 괜찮아요 . \n',
#  '\t 잘 하고 있어요 . 당당해지세요 . \n',
#  '\t 겨울 에는 귤 먹으면서 집 에 있는게 최고 죠 \n',
#  '\t 어서 따듯 한 곳 으로 가세 요 \n',
#  '\t 예의 는 지켜주세요 . \n',
#  '\t 예의 는 지켜주세요 . \n',
#  '\t 뭐라도 드세요 . \n',
#  '\t 휴가 가 간절하겠네요 . \n',
#  '\t 고생 많았어요 . \n',
#  '\t 잘 해결 되길 바랄게요 . \n',
#  '\t 저 는 고민 이 없어요 . \n',
#  '\t 저 는 위로 봇 입니다 . \n',
#  '\t 산책 좀 해야 겠네여 . \n',
#  '\t 외로우니까 사람 이다 . \n',
#  '\t 꾸준히 치료 하세요 . \n',
#  '\t 다치지 않으셨나 걱정 이네 요 . \n',
#  '\t 조심하세요 . \n',
#  '\t 기분 전환 을 해보세요 . \n',
#  '\t 실용 적 인 선물 이라 괜찮을 거 예요 . \n',
#  '\t 실용 적 인 선물 이라 괜찮을 거 예요 . \n',
#  '\t 놀 때 놀고 할 때 하세요 . \n',
#  '\t 노래 연습 을 해보세요 . \n',
#  '\t 노래 연습 꾸준히 해보세요 . \n',
#  '\t 저 도 부러워요 . \n',
#  '\t 저 도 부러워요 . \n',
#  '\t 즐거운 시간 이 될 거 같아요 \n',
#  '\t 신나는 노래 로 분위기 를 띄어 보세요 . \n',
#  ...]

# %%
num_sample = len(questions)

# %%
perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

# %%
train_q = []
train_a = []
test_q = []
test_a = []

for idx, qna in enumerate(zip(questions, answers_t)):
    q, a = qna
    if perm[idx] > num_sample // 5:
        train_q.append(q)
        train_a.append(a)
    else:
        test_q.append(q)
        test_a.append(a)

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,
                                                 filters='!"#$%()*+,-./:;<=>?@[\\]^_`{|}~')

# %%
tokenizer.fit_on_texts(train_q + train_a)

# %%
train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq, 
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)

y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post', 
                                                        maxlen=65)

X_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                       value=0,
                                                       padding='pre', 
                                                       maxlen=64)

y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq, 
                                                       value=0, 
                                                       padding='post', 
                                                       maxlen=65)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(10000)\
                                                                .batch(32).prefetch(1024)

test_ds  = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(1).prefetch(1024)

# %% [markdown]
# ## Define training process
# ### Create model, loss function, optimizer, and metrics

# %%
# Create model
model = Seq2seq(sos=tokenizer.word_index['\t'], eos=tokenizer.word_index['\n'])

# Define loss and optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# Define performance metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %%
for epoch in range(EPOCHS):
    for seqs, labels in train_ds:
        train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)
        
    template = 'Epoch {}, Loss: {}, Accuracy: {}'
    print(template.format(epoch + 1, 
                          train_loss.result(), 
                          train_accuracy.result() * 100))
    
    train_loss.reset_states()
    train_accuracy.reset_states()
# Out:
# Epoch 1, Loss: 0.6210343241691589, Accuracy: 91.7951431274414
# Epoch 2, Loss: 0.4339092969894409, Accuracy: 93.10025024414062
# Epoch 3, Loss: 0.40634220838546753, Accuracy: 93.39448547363281
# Epoch 4, Loss: 0.38566476106643677, Accuracy: 93.612548828125
# Epoch 5, Loss: 0.3703303337097168, Accuracy: 93.75066375732422
# Epoch 6, Loss: 0.3564894497394562, Accuracy: 93.87158966064453
# Epoch 7, Loss: 0.3434694707393646, Accuracy: 94.00457763671875
# Epoch 8, Loss: 0.3314449191093445, Accuracy: 94.10948181152344
# Epoch 9, Loss: 0.31972014904022217, Accuracy: 94.22859191894531
# Epoch 10, Loss: 0.30857598781585693, Accuracy: 94.34539794921875
# Epoch 11, Loss: 0.29714226722717285, Accuracy: 94.47821807861328
# Epoch 12, Loss: 0.2862580418586731, Accuracy: 94.59864807128906
# Epoch 13, Loss: 0.2753060460090637, Accuracy: 94.74287414550781
# Epoch 14, Loss: 0.26440250873565674, Accuracy: 94.86925506591797
# Epoch 15, Loss: 0.2534867227077484, Accuracy: 95.02091217041016
# Epoch 16, Loss: 0.24267737567424774, Accuracy: 95.18380737304688
# Epoch 17, Loss: 0.23223622143268585, Accuracy: 95.34405517578125
# Epoch 18, Loss: 0.22174648940563202, Accuracy: 95.51785278320312
# Epoch 19, Loss: 0.21147866547107697, Accuracy: 95.68586730957031
# Epoch 20, Loss: 0.20160658657550812, Accuracy: 95.8832778930664
# Epoch 21, Loss: 0.19192185997962952, Accuracy: 96.05162048339844
# Epoch 22, Loss: 0.18258199095726013, Accuracy: 96.25498962402344
# Epoch 23, Loss: 0.17336046695709229, Accuracy: 96.42266845703125
# Epoch 24, Loss: 0.16466721892356873, Accuracy: 96.58275604248047
# Epoch 25, Loss: 0.15594656765460968, Accuracy: 96.77125549316406
# Epoch 26, Loss: 0.1475767344236374, Accuracy: 96.92869567871094
# Epoch 27, Loss: 0.13966679573059082, Accuracy: 97.10133361816406
# Epoch 28, Loss: 0.13176660239696503, Accuracy: 97.2695083618164
# Epoch 29, Loss: 0.12427341938018799, Accuracy: 97.41059112548828
# Epoch 30, Loss: 0.11685053259134293, Accuracy: 97.57843780517578
# Epoch 31, Loss: 0.10986660420894623, Accuracy: 97.72051239013672
# Epoch 32, Loss: 0.10292983055114746, Accuracy: 97.87184143066406
# Epoch 33, Loss: 0.09620887786149979, Accuracy: 98.02267456054688
# Epoch 34, Loss: 0.08959801495075226, Accuracy: 98.17829895019531
# Epoch 35, Loss: 0.08326004445552826, Accuracy: 98.30665588378906
# Epoch 36, Loss: 0.0773722231388092, Accuracy: 98.43914794921875
# Epoch 37, Loss: 0.07141712307929993, Accuracy: 98.5655288696289
# Epoch 38, Loss: 0.06584388762712479, Accuracy: 98.69207763671875
# Epoch 39, Loss: 0.06047871336340904, Accuracy: 98.8214340209961
# Epoch 40, Loss: 0.055261027067899704, Accuracy: 98.93162536621094
# Epoch 41, Loss: 0.0505022294819355, Accuracy: 99.0439682006836
# Epoch 42, Loss: 0.04600001499056816, Accuracy: 99.15200805664062
# Epoch 43, Loss: 0.04178738594055176, Accuracy: 99.2379150390625
# Epoch 44, Loss: 0.03796394541859627, Accuracy: 99.32415008544922
# Epoch 45, Loss: 0.03416555002331734, Accuracy: 99.4042739868164
# Epoch 46, Loss: 0.030939608812332153, Accuracy: 99.46540069580078
# Epoch 47, Loss: 0.027866844087839127, Accuracy: 99.52288818359375
# Epoch 48, Loss: 0.025117052718997, Accuracy: 99.57096862792969
# Epoch 49, Loss: 0.022719765082001686, Accuracy: 99.61804962158203
# Epoch 50, Loss: 0.0206849854439497, Accuracy: 99.65868377685547
# Epoch 51, Loss: 0.018784087151288986, Accuracy: 99.68561553955078
# Epoch 52, Loss: 0.017390767112374306, Accuracy: 99.69982147216797
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-fe5991dcd62d> in <module>
#       1 for epoch in range(EPOCHS):
#       2     for seqs, labels in train_ds:
# ----> 3         train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)
#       4
#       5     template = 'Epoch {}, Loss: {}, Accuracy: {}'
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test process

# %%
for test_seq, test_labels in test_ds:
    prediction = test_step(model, test_seq)
    test_text = tokenizer.sequences_to_texts(test_seq.numpy())
    gt_text = tokenizer.sequences_to_texts(test_labels.numpy())
    texts = tokenizer.sequences_to_texts(prediction.numpy())
    print('_')
    print('Q: ', test_text)
    print('A: ', gt_text)
    print('p: ', texts)
# Out:
# _
# Q:  ['1 학교 떨어졌어']
# A:  ['\t 위로 해 \n']
# p:  ['저 도 모르겠어요 \n']
# _
# Q:  ['']
# A:  ['\t 이 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 돈 은 다시 거 예요 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 어서 잊고 새 출발 하세요 \n']
# p:  ['\n']
# _
# Q:  ['가장 확실한 건 뭘 까']
# A:  ['\t 가장 확실한 시간 은 오늘이 에요 어제 와 내일 을 놓고 고민 하느라 시간 을 마세요 \n']
# p:  ['가장 확실한 시간 은 오늘이 에요 어제 와 내일 을 놓고 고민 하느라 시간 을 마세요 \n']
# _
# Q:  ['가족 여행 가기 로 했어']
# A:  ['\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 \n']
# p:  ['말 하기 좋은 계절 이네 요 \n']
# _
# Q:  ['가족 들 이랑 어디 가지']
# A:  ['\t 온 가족 이 모두 마음 에 드는 곳 으로 가보세요 \n']
# p:  ['발 이 \n']
# _
# Q:  ['강아지 싶어']
# A:  ['\t 수 있을 때 보세요 \n']
# p:  ['여행 은 \n']
# _
# Q:  ['같이 게임 해도 되나']
# A:  ['\t 안 될 것 도 없죠 \n']
# p:  ['데이트 신청 해보세요 \n']
# _
# Q:  ['같이 나 만 거 같아']
# A:  ['\t 연인 은 잘 못 하고 않을 거 예요 \n']
# p:  ['마음 이라도 할 수 있는 걸 찾아보세요 \n']
# _
# Q:  ['같이 할 수 있는 취미 생활 뭐 있을까']
# A:  ['\t 함께 하면 서로 를 더 많이 알 게 될 거 예요 \n']
# p:  ['그 분 이 무엇 을 좋아하는지 \n']
# _
# Q:  ['하 니까 좋다']
# A:  ['\t 친구 들 이 봐요 \n']
# p:  ['마음 의 안정 을 기 좋은 취미 네 요 \n']
# _
# Q:  ['거짓말 을 나도 자꾸 해']
# A:  ['\t 거짓말 은 할수록 \n']
# p:  ['더 표현 해 달라 고 말 해보세요 \n']
# _
# Q:  ['거짓말 을 하게 돼']
# A:  ['\t 거짓말 은 할수록 \n']
# p:  ['가세 요 \n']
# _
# Q:  ['왔어']
# A:  ['\t 주 기적 으로 해주는 게 좋죠 \n']
# p:  ['조심하세요 \n']
# _
# Q:  ['아는 사람 인데 연락 해도 될까']
# A:  ['\t 모르는 사이 라 당황 할 수도 있어요 \n']
# p:  ['연락 해도 자신 을 마세요 \n']
# _
# Q:  ['주가 짱 인데']
# A:  ['\t 수 있을 거 예요 \n']
# p:  ['실감 이 안 날 거 예요 \n']
# _
# Q:  ['걸어 가고 있는데 해서 무서워']
# A:  ['\t 안전 귀가 하세요 \n']
# p:  ['소 서 에 해보세요 \n']
# _
# Q:  ['게임']
# A:  ['\t 다른 게임 해보세요 \n']
# p:  ['게임 하세요 \n']
# _
# Q:  ['가 필요해']
# A:  ['\t 잘 거 예요 \n']
# p:  ['저 도 없어요 \n']
# _
# Q:  ['결정 적 인 이 없어']
# A:  ['\t 증거 를 지금 이라도 모아 봐요 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['결혼 했어']
# A:  ['\t 좋겠어요 \n']
# p:  ['서로 에게 좋은 사람 기적 인가 봐요 \n']
# _
# Q:  ['결혼 도 다 돈 이다']
# A:  ['\t 많이 수 있을 거 예요 \n']
# p:  ['많이 \n']
# _
# Q:  ['결혼식 또 가야 돼']
# A:  ['\t 는 하는게 좋아요 \n']
# p:  ['예쁘게 오세요 \n']
# _
# Q:  ['결혼 하면']
# A:  ['\t 서로 노력 하면 행복할 거 예요 \n']
# p:  ['자신 을 속 이고 있는 것 같아요 \n']
# _
# Q:  ['결혼 해도 될까']
# A:  ['\t 이 사람 이다 싶은 사람 이랑 하세요 \n']
# p:  ['머리 말고 마음 가는 대로 하세요 \n']
# _
# Q:  ['결혼 해야 하나']
# A:  ['\t 해봐요 \n']
# p:  ['말 을 해야 \n']
# _
# Q:  ['고 3 은 공부 만 해야겠지']
# A:  ['\t 공부 가 우선 이 죠 \n']
# p:  ['직장 과 서로 를 위해 그게 좋겠죠 \n']
# _
# Q:  ['만 먹고 다이어트 해야지']
# A:  ['\t 너무 마세요 \n']
# p:  ['일 은 딱 힘들 때 가 있을 거 예요 \n']
# _
# Q:  ['고민 있어']
# A:  ['\t 네 말씀 하세요 \n']
# p:  ['있겠네요 \n']
# _
# Q:  ['고민 좀']
# A:  ['\t 네 말씀 하세요 \n']
# p:  ['기대 를 많이 하는 건 좋지 않아요 \n']
# _
# Q:  ['너무 답답해']
# A:  ['\t 돈 을 다른 곳 으로 이사 갈 수 있을 거 예요 \n']
# p:  ['바람 좀 쐬고 면 \n']
# _
# Q:  ['에서 탈출 하고 싶어']
# A:  ['\t 더 좋은 곳 에서 살 수 있을 거 예요 \n']
# p:  ['계획 적 이고 적 으로 \n']
# _
# Q:  ['보는 중']
# A:  ['\t 완전 \n']
# p:  ['시간 가는 줄 모르겠어요 \n']
# _
# Q:  ['못']
# A:  ['\t 처음 부터 잘 하는 사람 은 없어요 \n']
# p:  ['고민 이 봅니다 \n']
# _
# Q:  ['생각나']
# A:  ['\t 미리 미리 충전 해주세요 \n']
# p:  ['그럴 시기 라고 생각 해요 \n']
# _
# Q:  ['공무원 되면 좋겠다']
# A:  ['\t 준비 해보세요 \n']
# p:  ['미련 이 봐요 \n']
# _
# Q:  ['공부 시작 해도 될까']
# A:  ['\t 공부 는 언제나 좋죠 \n']
# p:  ['공부 는 언제나 좋죠 \n']
# _
# Q:  ['공부 좀 더 할 걸']
# A:  ['\t 지금 도 늦지 않았어요 \n']
# p:  ['말로 만 힘든 게 낫 지 나 죠 \n']
# _
# Q:  ['공부 하는 이유']
# A:  ['\t 공부 하면 더 많은 선택 을 할 수 있죠 \n']
# p:  ['힘들 때 같이 있는 거 요 \n']
# _
# Q:  ['공부 하는 이유 가 없어']
# A:  ['\t 공부 하면 더 많은 선택 을 할 수 있죠 \n']
# p:  ['친구 가 할 수도 있겠어요 \n']
# _
# Q:  ['보고 싶어']
# A:  ['\t 친구 와 같이 가보세요 \n']
# p:  ['보러 가세 요 \n']
# _
# Q:  ['비 부담 되겠지']
# A:  ['\t 하면 거짓말 \n']
# p:  ['건강 생각 되겠네요 \n']
# _
# Q:  ['비 비싸']
# A:  ['\t 하면 거짓말 \n']
# p:  ['일찍 주무 세 요 \n']
# _
# Q:  ['과일 안 돼']
# A:  ['\t 그래도 노력 해보세요 \n']
# p:  ['그래도 취미 생활 이 사는 재미 가 있죠 \n']
# _
# Q:  ['괜히']
# A:  ['\t 그럴 필요 없어요 \n']
# p:  ['누군가 를 아니죠 \n']
# _
# Q:  ['왔어']
# A:  ['\t 마음 에 드는 책 을 잘 찾아보세요 \n']
# p:  ['조심하세요 \n']
# _
# Q:  ['']
# A:  ['\t 저 도 듣고 싶어요 \n']
# p:  ['\n']
# _
# Q:  ['시간 에 마음 에 드는 애 있어']
# A:  ['\t 같은 되길 바랄게요 \n']
# p:  ['연락 은 싸움 의 이 죠 \n']
# _
# Q:  ['은근 재미']
# A:  ['\t 재미 가 있죠 \n']
# p:  ['을 수 있을 거 예요 \n']
# _
# Q:  ['에서 마음 에 드는 애 있어']
# A:  ['\t 같은 되길 바랄게요 \n']
# p:  ['연락 은 싸움 의 이 죠 \n']
# _
# Q:  ['이']
# A:  ['\t 재미 가 있죠 \n']
# p:  ['\n']
# _
# Q:  ['가능할까']
# A:  ['\t 관리 하세요 \n']
# p:  ['열심히 하면 받을 수 있을 거 예요 \n']
# _
# Q:  ['교회 가기 싫어']
# A:  ['\t 왜 그럴까 요 \n']
# p:  ['가지 마세요 \n']
# _
# Q:  ['군대 갔다 올 때 까지 기다릴 수 있을까']
# A:  ['\t 자신 의 삶 을 기다릴 수 있을 거 예요 \n']
# p:  ['마음 이 \n']
# _
# Q:  ['군대 될까']
# A:  ['\t 않는다면 좋을 것 같아요 \n']
# p:  ['확신 이 없다면 네 요 \n']
# _
# Q:  ['군대 기다리면 부담스러워 할까']
# A:  ['\t 너무 걱정 하지 마세요 \n']
# p:  ['여기 까지 거 예요 \n']
# _
# Q:  ['']
# A:  ['\t 안 궁금해요 \n']
# p:  ['\n']
# _
# Q:  ['궁금해 알려줘']
# A:  ['\t 말씀 해주세요 \n']
# p:  ['판단 은 당신 의 마음 이 수 있을 거 예요 \n']
# _
# Q:  ['어때']
# A:  ['\t 생각 하기는 하기는 어려운 것 같아요 \n']
# p:  ['\n']
# _
# Q:  ['그냥 선 볼까']
# A:  ['\t 많이 만나 보세요 \n']
# p:  ['많이 만나 보세요 \n']
# _
# Q:  ['그냥 혼자 있는게 좋아']
# A:  ['\t 혼자 만 있지 마세요 \n']
# p:  ['치 않으면 말 하세요 \n']
# _
# Q:  ['그런 말 을 왜 하지']
# A:  ['\t 다른 사람 말 은 신경 쓰지 마세요 \n']
# p:  ['잘 볼 수 있을 거 예요 \n']
# _
# Q:  ['그런 사람인 해야지']
# A:  ['\t \n']
# p:  ['건강 에도 좋겠네요 \n']
# _
# Q:  ['좀 잘 좋겠다']
# A:  ['\t 학원 을 연습 하면 잘 할 수 있을 거 예요 \n']
# p:  ['잘 될 거 예요 \n']
# _
# Q:  ['그만']
# A:  ['\t 당신 을 생각 하세요 \n']
# p:  ['\n']
# _
# Q:  ['좀 알려줘 봐 봐']
# A:  ['\t 당신 의 삶 을 응원 해 수 있어 요 라고 말 해 봅니다 \n']
# p:  ['\n']
# _
# Q:  ['기분 나쁜 을 계속 하고 있어']
# A:  ['\t 한번 해주세요 \n']
# p:  ['잘 했어요 \n']
# _
# Q:  ['기분 전환 하고 싶어']
# A:  ['\t 저 랑 함께 해 요 \n']
# p:  ['서로 에게 좋은 을 주는 관계 입니다 \n']
# _
# Q:  ['기분 이 그 지 같아']
# A:  ['\t 신나는 음악 들어 보세요 \n']
# p:  ['제 가 위로 많이 \n']
# _
# Q:  ['기숙사 괜찮을까']
# A:  ['\t 혼자 사는 것 보다 \n']
# p:  ['혼자 사는 것 보다 \n']
# _
# Q:  ['기숙사 어떨까']
# A:  ['\t 혼자 사는 것 보다 \n']
# p:  ['다음 에는 \n']
# _
# Q:  ['기술']
# A:  ['\t 기술 을 많이 알 면 도움 이 \n']
# p:  ['저 도 듣고 싶네요 \n']
# _
# Q:  ['여행 가고 싶어']
# A:  ['\t 여행 이네 요 \n']
# p:  ['여행 은 언제나 좋죠 \n']
# _
# Q:  ['도 못 하겠어']
# A:  ['\t 답답한 상황 이네 요 \n']
# p:  ['다 잘 될 거 예요 \n']
# _
# Q:  ['선물 괜찮을까']
# A:  ['\t 직접 주는 게 더 좋을 것 같아요 \n']
# p:  ['직접 주는 게 더 좋을 것 같아요 \n']
# _
# Q:  ['기회 를']
# A:  ['\t 더 좋은 기회 가 올 거 예요 \n']
# p:  ['축하 드려요 \n']
# _
# Q:  ['길이 뻔했어']
# A:  ['\t 조심하세요 \n']
# p:  ['조심하세요 \n']
# _
# Q:  ['꽃 살까']
# A:  ['\t 분위기 가 바뀔 거 예요 \n']
# p:  ['기분 전환 을 해보세요 \n']
# _
# Q:  ['']
# A:  ['\t 기분 좋아 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 해서 만들어 보세요 \n']
# p:  ['\n']
# _
# Q:  ['샀어']
# A:  ['\t 멋진 선물 이네 요 \n']
# p:  ['폰 절약 되겠네요 \n']
# _
# Q:  ['선물 받았어']
# A:  ['\t 부러워요 \n']
# p:  ['정말 기분 \n']
# _
# Q:  ['선물 어때']
# A:  ['\t 있는 선물 이에요 \n']
# p:  ['직접 주는 게 더 좋을 것 같아요 \n']
# _
# Q:  ['선물 이랑 과일 선물 뭐 가 좋아']
# A:  ['\t 받는 사람 이 부럽네요 \n']
# p:  ['어떤 가 좋겠어요 \n']
# _
# Q:  ['가 좋을까 과일 까 좋을까']
# A:  ['\t 받는 사람 이 부럽네요 \n']
# p:  ['나이 는 \n']
# _
# Q:  ['']
# A:  ['\t 저 도 \n']
# p:  ['\n']
# _
# Q:  ['꿈 이 너무']
# A:  ['\t 요즘 예민한 가봐요 \n']
# p:  ['많으면 많을 수록 좋죠 \n']
# _
# Q:  ['좋을 줄 알았는데']
# A:  ['\t 마음 이 가봐요 \n']
# p:  ['성공 에서 가장 어려운 것 이 상태 를 유지 하는 거 예요 \n']
# _
# Q:  ['나 같은 사람 은 동물']
# A:  ['\t 잘 \n']
# p:  ['당신 도 잘 \n']
# _
# Q:  ['나 결정 잘 한 거지']
# A:  ['\t 네 이제 잘 예요 \n']
# p:  ['잘 찾아보세요 \n']
# _
# Q:  ['나']
# A:  ['\t 은 \n']
# p:  ['괜찮은 사람 이에요 \n']
# _
# Q:  ['나 누구 게']
# A:  ['\t 저 도 궁금하네요 \n']
# p:  ['저 도 \n']
# _
# Q:  ['나 다른 거 할까']
# A:  ['\t 시도 좋겠죠 \n']
# p:  ['자신 과 마음 을 하지 말고 한 보다 더 먼저 해보세요 \n']
# _
# Q:  ['나 한 거 아닌데']
# A:  ['\t 사람 들 이 사람 이 있을 거 예요 \n']
# p:  ['사람 들 이 사람 이 있을 거 예요 \n']
# _
# Q:  ['나 하는 애 어떻게 하지']
# A:  ['\t 너무 신경 쓰지 말고 하고 아무렇지도 않게 \n']
# p:  ['평소 흘려 이야기 했던 걸 기억 해주고 생각 하고 있다는 걸 알려주세요 \n']
# _
# Q:  ['나 맨날 속 는 거 같아']
# A:  ['\t 속 아 주세요 \n']
# p:  ['당신 은 하나 밖에 없는 소중한 사람 이에요 \n']
# _
# Q:  ['나 몰래 사귀는 거 같 애']
# A:  ['\t 눈치 가 \n']
# p:  ['마음 에 버리세요 \n']
# _
# Q:  ['나 무시 거 같아']
# A:  ['\t 그런 생각 을 하는 사람 하지 마세요 \n']
# p:  ['마음 먹기 \n']
# _
# Q:  ['나 바 본인 가 봄']
# A:  ['\t 바보 는 자기 한테 바보 라고 하지 않아요 \n']
# p:  ['\n']
# _
# Q:  ['나 이야']
# A:  ['\t 운동 해보세요 \n']
# p:  ['\n']
# _
# Q:  ['나 에서 했어']
# A:  ['\t 자책 하지 마세요 \n']
# p:  ['지금 도 충분해요 \n']
# _
# Q:  ['나 아직도 애 같아']
# A:  ['\t 물리 적 나이 가 아니라 정신 적 나이 가 요 \n']
# p:  ['마음 의 준비 를 하세요 \n']
# _
# Q:  ['나 오늘 상']
# A:  ['\t 축하 드려요 \n']
# p:  ['축하 합니다 \n']
# _
# Q:  ['나 야']
# A:  ['\t 친구 들 과 잘 보세요 \n']
# p:  ['나 에게 잘 될 거 예요 \n']
# _
# Q:  ['나 인거 같아']
# A:  ['\t 부모님 께 도움 을 해보세요 \n']
# p:  ['시간 이 좀 바랍니다 \n']
# _
# Q:  ['나 잘 살 수 있겠지']
# A:  ['\t 지금 보다 더 잘 살 거 예요 \n']
# p:  ['잘 할 수 있을 거 예요 \n']
# _
# Q:  ['나 말 해줘']
# A:  ['\t 나 자신 에 집중 하세요 언제나 1 순위 에 자신 을 두세요 \n']
# p:  ['응원 합니다 \n']
# _
# Q:  ['나 있나']
# A:  ['\t 있어도 예뻐요 \n']
# p:  ['서로 에게 귀 방법 도 있어요 \n']
# _
# Q:  ['나']
# A:  ['\t 제 가 \n']
# p:  ['괜찮은 사람 이에요 \n']
# _
# Q:  ['나 인 듯']
# A:  ['\t 나를 하고 음식 자체 에 집중 하세요 \n']
# p:  ['칭찬 이네 요 \n']
# _
# Q:  ['나 너무 많이 해']
# A:  ['\t 시간 을 정 해보세요 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['나 몇 시간 갔어']
# A:  ['\t 시간 을 정 해보세요 \n']
# p:  ['상대방 에 대한 예의 가 없네요 \n']
# _
# Q:  ['나 혼자 야근 해']
# A:  ['\t 얼른 기도 할게요 \n']
# p:  ['혼자 만 있지 마세요 \n']
# _
# Q:  ['나 혼자 서 축구']
# A:  ['\t 축구 는 이 죠 \n']
# p:  ['혼자 도 좋아요 \n']
# _
# Q:  ['나 화장 을 너무 못 해']
# A:  ['\t 하다 보면 \n']
# p:  ['게 다 잘 될 거 예요 \n']
# _
# Q:  ['나 는 왜 이렇게']
# A:  ['\t 서로 태어난 이유 는 저 목소리 를 위 자신 의 목소리 를 \n']
# p:  ['\n']
# _
# Q:  ['나도 입고 싶다']
# A:  ['\t 다이어트 파이팅 \n']
# p:  ['커플 부터 \n']
# _
# Q:  ['나도 위로 받고 싶다']
# A:  ['\t 제 가 위로 많이 \n']
# p:  ['열심히 하면 할 수 있을 거 예요 \n']
# _
# Q:  ['나 두 잘 할거야']
# A:  ['\t 잘 거 예요 \n']
# p:  ['저 도 그런 사람 만나고 싶어요 \n']
# _
# Q:  ['나 랑']
# A:  ['\t 지금 있어요 \n']
# p:  ['저 라도 좋아요 \n']
# _
# Q:  ['나 랑 있는게 봐']
# A:  ['\t 상대방 을 이해해 주세요 \n']
# p:  ['사랑 은 하고 \n']
# _
# Q:  ['']
# A:  ['\t 아무 것 도 안해 도 괜찮아요 \n']
# p:  ['\n']
# _
# Q:  ['나를 너무 오래 했어']
# A:  ['\t 기다리는 동안 많은 생각 이 \n']
# p:  ['매력 을 해보세요 \n']
# _
# Q:  ['나를 수 있는 건 뭐 가 있을까']
# A:  ['\t 지금 모습 도 좋아요 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['나를 로 아는 사람 어떡해']
# A:  ['\t 하지 마세요 \n']
# p:  ['무시 하세요 \n']
# _
# Q:  ['나 만 반 친구 없어']
# A:  ['\t 친구 를 사귈 수 있을 거 예요 \n']
# p:  ['맞았나 봐요 \n']
# _
# Q:  ['나 만 거야']
# A:  ['\t 그 사람 도 거 예요 \n']
# p:  ['울 어도 괜찮아요 \n']
# _
# Q:  ['나 만 봐']
# A:  ['\t 와 대화 를 나눠 보세요 \n']
# p:  ['누군가 를 아니죠 \n']
# _
# Q:  ['나 만 야근 해']
# A:  ['\t 얼른 기도 할게요 \n']
# p:  ['다음 부터는 잘 \n']
# _
# Q:  ['나 만 거 같아']
# A:  ['\t 스스로 \n']
# p:  ['선생님 께 도움 을 해보세요 \n']
# _
# Q:  ['나 만 힘든 거']
# A:  ['\t 누구 나 힘들어요 \n']
# p:  ['마음 이 \n']
# _
# Q:  ['나중 에 뭐 하고 먹고']
# A:  ['\t 진짜 하고 싶은 걸 찾아보세요 \n']
# p:  ['이 될 때 아무렇지도 않으면 거 예요 \n']
# _
# Q:  ['']
# A:  ['\t 한 번 헤어 나올 수 없다고 해 요 \n']
# p:  ['\n']
# _
# Q:  ['비 추워']
# A:  ['\t 따뜻하게 사세요 \n']
# p:  ['오늘 래 요 \n']
# _
# Q:  ['이 안 추워']
# A:  ['\t 보일러 가 으로 이 되는지 보세요 \n']
# p:  ['어서 따듯 한 곳 으로 가세 요 \n']
# _
# Q:  ['날 몇 시간 동안 이나 했어']
# A:  ['\t 기다리는 동안 많은 생각 이 \n']
# p:  ['후회 하기 \n']
# _
# Q:  ['날씨 짱 좋아']
# A:  ['\t 하늘 을 보고 웃어 보세요 \n']
# p:  ['시원한 라도 한 잔 드세요 \n']
# _
# Q:  ['남 이 않는 길 을 해']
# A:  ['\t 누구 나 줄 에 필요 는 없어요 \n']
# p:  ['잘 하는 게 좋을 것 같아요 \n']
# _
# Q:  ['남자 화장 하는 거 어때']
# A:  ['\t 적당히 하면 같아요 \n']
# p:  ['신나는 노래 를 들어 보세요 \n']
# _
# Q:  ['남자 면 편할 것 같아']
# A:  ['\t 남자 도 좋은 것 만은 \n']
# p:  ['너무 \n']
# _
# Q:  ['남자친구 오늘 따라']
# A:  ['\t 에 를 구 \n']
# p:  ['조금 걸까 요 \n']
# _
# Q:  ['남자친구 가 사업 한 대']
# A:  ['\t 때 힘 이 되어 주세요 \n']
# p:  ['때 힘 이 되어 주세요 \n']
# _
# Q:  ['남자친구 가 입 이']
# A:  ['\t 사람 고쳐 쓰는 거 아니에요 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['남자친구 가 자꾸 해']
# A:  ['\t 더 해보세요 \n']
# p:  ['더 신경 쓰지 마세요 \n']
# _
# Q:  ['남자친구 가 가 심해']
# A:  ['\t 더 해보세요 \n']
# p:  ['더 신경 써 주세요 \n']
# _
# Q:  ['남자친구 는 어디서 만나']
# A:  ['\t 원하는 사람 이 있는 장소 에 가보세요 \n']
# p:  ['소개팅 시켜 달라 고 말 해보세요 \n']
# _
# Q:  ['남자친구 랑 종교 문제 로']
# A:  ['\t 종교 의 자유 를 인정 해주세요 \n']
# p:  ['종교 가 맞는 것 과 맞지 않은 것 \n']
# _
# Q:  ['남자친구 랑 종교 가 달라']
# A:  ['\t 종교 의 자유 를 인정 해주세요 \n']
# p:  ['종교 의 자유 가 있죠 \n']
# _
# Q:  ['남자친구 한테 거 같아']
# A:  ['\t 은 좋아요 \n']
# p:  ['선생님 께 도움 을 해보세요 \n']
# _
# Q:  ['남친 에 내 사진 왜 안']
# A:  ['\t 신경 쓰고 싶지 않은 사람 도 있어요 \n']
# p:  ['좋은 사람 이 생길 거 예요 \n']
# _
# Q:  ['남편 이 나 보다 집안일 더 잘 해']
# A:  ['\t 이상 적 인 남편 이네 요 \n']
# p:  ["잘 ' ' 내일 도 ' 라고 생각 해요 \n"]
# _
# Q:  ['남편 이 아기 를 안']
# A:  ['\t 가 기본 인데 요 \n']
# p:  ['잘 수 있을거예요 \n']
# _
# Q:  ['남편 이 집안일 안 해']
# A:  ['\t 잘 해보세요 \n']
# p:  ['같이 가보세요 \n']
# _
# Q:  ['남편 이']
# A:  ['\t 처음 때 를 보세요 \n']
# p:  ['엄청 \n']
# _
# Q:  ['내 남자친구 보고 싶어']
# A:  ['\t 네 주세요 \n']
# p:  ['조금 만 참고 기다려 보세요 \n']
# _
# Q:  ['내 문제 는 뭘 까']
# A:  ['\t 고민 만 한다는 것 아닐까 요 \n']
# p:  ['직접 물어보세요 \n']
# _
# Q:  ['내 이 뭘 까']
# A:  ['\t 고민 만 한다는 것 아닐까 요 \n']
# p:  ['할 일이 많은데 안 하는 것 이 요 \n']
# _
# Q:  ['내 는 어디 있을까']
# A:  ['\t 바로 옆 에 있어요 \n']
# p:  ['직접 물어보세요 \n']
# _
# Q:  ['내 도 어디 있을까']
# A:  ['\t 바로 옆 에 있어요 \n']
# p:  ['계속 그러면 돼요 \n']
# _
# Q:  ['내 외모 맘 에 안 들어']
# A:  ['\t 자신감 을 돼요 \n']
# p:  ['안 \n']
# _
# Q:  ['내 월급 만 안']
# A:  ['\t 자신 의 능력 이 저 건 아닌지 확인 해보세요 \n']
# p:  ['다른 곳 에서 일 여보세요 \n']
# _
# Q:  ['내 좀 존중 해 줬으면']
# A:  ['\t 스스로 도 존중 해주세요 \n']
# p:  ['잘 해보세요 \n']
# _
# Q:  ['내 인생 답 없어']
# A:  ['\t 을 찾아 야할 필요 는 없어요 \n']
# p:  ['자신 을 사랑 할수록 의 인정 은 필요 없어요 \n']
# _
# Q:  ['내 인생 의 은']
# A:  ['\t 멋진 말 이에요 \n']
# p:  ['추억 이 \n']
# _
# Q:  ['내 자존감']
# A:  ['\t 당신 은 태어난 그 자체 만으로 축복 과 사랑 을 받을 자격 이 있는 사람 이에요 \n']
# p:  ['후회 할 것 같아요 \n']
# _
# Q:  ['내 잘못 인 거 같은데 말 을 못 하겠어']
# A:  ['\t 사과 할 타이밍 을 마세요 \n']
# p:  ['충분히 그럴 수 있어요 \n']
# _
# Q:  ['내 한테 내']
# A:  ['\t 진짜 \n']
# p:  ['당신 도 잘 살 수 있어요 \n']
# _
# Q:  ['내 가 그 사람 이랑 진짜 결혼 해도 될까']
# A:  ['\t 이 사람 이다 싶은 사람 이랑 하세요 \n']
# p:  ['상대방 을 헷갈리게 하는건 좋지 않아요 \n']
# _
# Q:  ['내 가 많이']
# A:  ['\t 잘 하는 게 다른 거 예요 \n']
# p:  ['너무 마세요 \n']
# _
# Q:  ['내 가 야']
# A:  ['\t 연락 이라도 보세요 \n']
# p:  ['저 에게 말 해보세요 \n']
# _
# Q:  ['내 가 야']
# A:  ['\t 연락 이라도 보세요 \n']
# p:  ['저 에게 말 해보세요 \n']
# _
# Q:  ['내 가 이렇게 또 를 한다']
# A:  ['\t 연락 이라도 보세요 \n']
# p:  ['봐요 \n']
# _
# Q:  ['내 가 제일 문제 인 듯']
# A:  ['\t 당신 은 하나 밖에 없는 소중한 사람 이에요 \n']
# p:  ['잘 하고 있어요 \n']
# _
# Q:  ['내 가 좋아하는 사람 이 나 안 좋아하는 거 같아']
# A:  ['\t 슬픈 이야기 네 요 \n']
# p:  ['슬픈 이야기 네 요 \n']
# _
# Q:  ['내 가 좋아하는 사람 이 나 좋아해 줬으면 좋겠다']
# A:  ['\t 저 도 기도 할게요 \n']
# p:  ['저 도 기도 할게요 \n']
# _
# Q:  ['내 가 를 봐']
# A:  ['\t 를 때 가 행복할 때 예요 \n']
# p:  ['그건 습관 이에요 \n']
# _
# Q:  ['내 가 거 같아']
# A:  ['\t 나쁜 생각 하지 마세요 \n']
# p:  ['아니에요 너무 자책 하지 마세요 \n']
# _
# Q:  ['내 가 힘든 게']
# A:  ['\t 그게 인생 이 죠 \n']
# p:  ['자기 도 모르는 게 마음 이에요 \n']
# _
# Q:  ['해서 소원 뭐 하지']
# A:  ['\t \n']
# p:  ['와 음악 이라고 하고 아무 것 도 안 했어요 \n']
# _
# Q:  ['내일 가']
# A:  ['\t 친구 들 과 좋은 추억 오세요 \n']
# p:  ['입 에 쓴 게 몸 에는 좋을 거 예요 \n']
# _
# Q:  ['내일 은 친구 들 랑']
# A:  ['\t 시간 물어보세요 \n']
# p:  ['친구 에게 보세요 \n']
# _
# Q:  ['내 일 이면 크리스마스 네']
# A:  ['\t 크리스마스 \n']
# p:  ['천천히 그런 시기 가 있어요 \n']
# _
# Q:  ['비 장난']
# A:  ['\t 시원하게 이 죠 \n']
# p:  ['다음 달 에는 더 절약 해봐요 \n']
# _
# Q:  ['너 누구']
# A:  ['\t 저 는 마음 을 위로 봇 입니다 \n']
# p:  ['혼자 가 되는 것 이 상태 를 유지 하는 거 예요 \n']
# _
# Q:  ['너 누구 냐']
# A:  ['\t 저 는 위로 이에요 \n']
# p:  ['저 는 위로 봇 입니다 \n']
# _
# Q:  ['너 누구 니']
# A:  ['\t 저 는 위로 이에요 \n']
# p:  ['저 도 궁금하네요 \n']
# _
# Q:  ['너 때문 이야']
# A:  ['\t 모두 제 잘 못 입니다 \n']
# p:  ['이 젠 그 를 놓아주세요 \n']
# _
# Q:  ['너 는 뭐']
# A:  ['\t 저 는 가 밥 이 예요 \n']
# p:  ['당신 의 삶 을 응원 해 수 있어 요 라고 말 해 봅니다 \n']
# _
# Q:  ['너 는']
# A:  ['\t 아직 안 자 요 \n']
# p:  ['나도 \n']
# _
# Q:  ['느낌 이야']
# A:  ['\t 자신 을 우선 순 위로 해주세요 \n']
# p:  ['좋은 결과 있을 거 예요 \n']
# _
# Q:  ['너 도']
# A:  ['\t 저 도 \n']
# p:  ['나도 아프다 \n']
# _
# Q:  ['너무 봐']
# A:  ['\t 아무 것 도 바라지 않을 때 를 말 이 있어요 \n']
# p:  ['\n']
# _
# Q:  ['너무 더워']
# A:  ['\t 시원한 라도 한 잔 드세요 \n']
# p:  ['사람 그렇게 쉽게 않아요 \n']
# _
# Q:  ['너무 많이 하는데 가 싫어']
# A:  ['\t 소 화제 챙겨 드세요 \n']
# p:  ['소 화제 챙겨 드세요 \n']
# _
# Q:  ['너무 많이']
# A:  ['\t 소 화제 드세요 \n']
# p:  ['상대 에게 자신 을 해 요 \n']
# _
# Q:  ['너무']
# A:  ['\t 하나 씩 하세요 \n']
# p:  ['자신 에게 좀 더 여유 로 요 \n']
# _
# Q:  ['너무 느낌 이야']
# A:  ['\t 잘 하고 있어요 \n']
# p:  ['나 보다는 그 사람 을 생각 하게 되는 거 요 \n']
# _
# Q:  ['뻔했어']
# A:  ['\t 조심하세요 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['노래 잘 사람 부러워']
# A:  ['\t 노래 연습 꾸준히 해보세요 \n']
# p:  ['잘 하는 것 도 많아요 \n']
# _
# Q:  ['노래방 데이트 할 거 같은데 뭐']
# A:  ['\t 달달 한 노래 요 \n']
# p:  ['부모님 노후 도 요 \n']
# _
# Q:  ['노력 해도 성적 이 안 나와']
# A:  ['\t 잘 못 된 방법 을 하고 있는 건 아닌지 살펴보세요 \n']
# p:  ['연락 이 중요한 시기 인데 요 \n']
# _
# Q:  ['노력 해도 안되는 거 같 애']
# A:  ['\t 중요한 건 노력 하는 과정 이에요 \n']
# p:  ['살짝 감정 을 흘려 보세요 \n']
# _
# Q:  ['']
# A:  ['\t 보기 만 해도 좋아요 \n']
# p:  ['\n']
# _
# Q:  ['힘들다']
# A:  ['\t 힘내세요 \n']
# p:  ['출퇴근 을 미리 느껴 보고 있네요 \n']
# _
# Q:  ['돈 싶어']
# A:  ['\t 입니다 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['놀이 데이트 어때']
# A:  ['\t 데이트 하기 좋은 곳 이 죠 \n']
# p:  ['차단 하는 게 좋겠죠 \n']
# _
# Q:  ['가고 싶어']
# A:  ['\t 다녀오세요 \n']
# p:  ['저 도 딸기 좋아해요 같이 가요 \n']
# _
# Q:  ['하러 가야 지']
# A:  ['\t 운동 은 뭐 든 좋아요 \n']
# p:  ['좋은 취미 네 요 \n']
# _
# Q:  ['누구 소개 좀 봐 봐']
# A:  ['\t 도 소개 시켜 드릴게요 \n']
# p:  ['그래도 거 예요 \n']
# _
# Q:  ['누구 나']
# A:  ['\t 시기 가 다를 뿐 이에요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['']
# A:  ['\t 저 는 위로 이에요 \n']
# p:  ['\n']
# _
# Q:  ['눈물 이']
# A:  ['\t 세상 걱정 혼자 다 해서 그래요 \n']
# p:  ['울 어도 돼요 \n']
# _
# Q:  ['문신 어때']
# A:  ['\t 화장 하는 시간 이 거 예요 \n']
# p:  ['화장 하는 시간 이 거 예요 \n']
# _
# Q:  ['문신 해볼까']
# A:  ['\t 거 예요 \n']
# p:  ['화장 하는 시간 이 거 예요 \n']
# _
# Q:  ['눈 이']
# A:  ['\t 눈 을 보세요 \n']
# p:  ['눈 를 해보세요 \n']
# _
# Q:  ['눈 이 계속 해']
# A:  ['\t 눈물 을 보세요 \n']
# p:  ['생각 을 할 수 있는 사람 도 많아요 \n']
# _
# Q:  ['눈 이 너무']
# A:  ['\t 잠시 눈 을 휴식 을 취 해보세요 \n']
# p:  ['\n']
# _
# Q:  ['잘 거 같아']
# A:  ['\t 좋은 수면 습관 이네 요 \n']
# p:  ['남 들 눈 은 신경 쓰지 마세요 \n']
# _
# Q:  ['느낌 이 왔어']
# A:  ['\t 사랑 의 바라요 \n']
# p:  ['좋은 만남이었길 바라요 \n']
# _
# Q:  ['능력 이 너무 안 돼']
# A:  ['\t 자신 의 을 믿어 보세요 \n']
# p:  ['좀 더 많이 보면 돼요 \n']
# _
# Q:  ['늦게 까지 술 보다']
# A:  ['\t 몸 에 먹는 게 말 해보세요 \n']
# p:  ['\n']
# _
# Q:  ['다 나 좋겠어']
# A:  ['\t 꿈 같은 이야기 네 요 \n']
# p:  ['때 가 많아요 \n']
# _
# Q:  ['다 마음 에 안 들어']
# A:  ['\t 그럴 때 가 있죠 \n']
# p:  ['할 때 가 \n']
# _
# Q:  ['다 잘 해']
# A:  ['\t 그런 사람 이 있으면 저 좀 소개 \n']
# p:  ['잘 하는 게 다른 거 예요 \n']
# _
# Q:  ['다른 사람 도 다 힘들겠지']
# A:  ['\t 시기 가 다를 뿐 이에요 \n']
# p:  ['자신 을 위해 사람 이 \n']
# _
# Q:  ['다른 사람 들 에게 사랑 을 싶어']
# A:  ['\t 나를 존중 하고 사랑 할 때 가능해요 \n']
# p:  ['시간 이 좀 수 있어요 \n']
# _
# Q:  ['다른 사람 들 은']
# A:  ['\t 자신 만 돼요 \n']
# p:  ['잘 하니까 그럴 거 예요 \n']
# _
# Q:  ['다른 사람 들 은 행복해']
# A:  ['\t 자신 만 돼요 \n']
# p:  ['오래 볼 수 있어 좋은 가봐요 \n']
# _
# Q:  ['다리 받았어']
# A:  ['\t 남 에게 피해 만 주지 않는다면 괜찮아요 \n']
# p:  ['더 \n']
# _
# Q:  ['다리 진짜 복 나']
# A:  ['\t 하는 다리 는 대요 \n']
# p:  ['잘 모르겠어요 \n']
# _
# Q:  ['다리 가']
# A:  ['\t 을 해보세요 \n']
# p:  ['잘 하고 오세요 \n']
# _
# Q:  ['이']
# A:  ['\t 거 예요 \n']
# p:  ['\n']
# _
# Q:  ['다이어트 해야 되는데']
# A:  ['\t 대 을 여보세요 \n']
# p:  ['다음 에는 우산 에 이름 이랑 연락처 를 적어 보세요 \n']
# _
# Q:  ['생활 많이']
# A:  ['\t 서로 배려 해야 하니 까요 \n']
# p:  ['지금 은 바랄게요 \n']
# _
# Q:  ['생활 적응 이 안 돼']
# A:  ['\t 점점 적응 될 거 예요 \n']
# p:  ['이 봐 보세요 \n']
# _
# Q:  ['담배 비싸']
# A:  ['\t 하세요 \n']
# p:  ['담배 마세요 \n']
# _
# Q:  ['이 왜 이렇게 비싸']
# A:  ['\t 하세요 \n']
# p:  ['일찍 하면 좀 더 살 수 있어요 \n']
# _
# Q:  ['답 이 어디 있을까']
# A:  ['\t 답 은 언제나 내 안 에 있죠 \n']
# p:  ['계속 해 요 \n']
# _
# Q:  ['될까']
# A:  ['\t 어디 에서 일 하든 상관 없어요 \n']
# p:  ['없는 것 보다 나을 거 예요 \n']
# _
# Q:  ['취직']
# A:  ['\t 잘 할 수 있을 거 예요 \n']
# p:  ['지금 은 힘들겠지만 나중 에 웃 을 수 있을 거 예요 \n']
# _
# Q:  ['말 했으면 좋겠어']
# A:  ['\t 말 하는 습관 차이 인 듯 합니다 \n']
# p:  ['건강 에 좋은 습관 이네 요 \n']
# _
# Q:  ['를 안 해줘']
# A:  ['\t 당신 을 인정 해줄 곳 을 찾아보세요 \n']
# p:  ['바쁜 가봐요 \n']
# _
# Q:  ['대학 가는 게 낫 지']
# A:  ['\t 을 해보세요 \n']
# p:  ['\n']
# _
# Q:  ['가고 싶어']
# A:  ['\t 꿈 에 도전 하는 건 좋은 거 라고 \n']
# p:  ['저 도 딸기 좋아해요 같이 가요 \n']
# _
# Q:  ['가는게 좋을 것 같아']
# A:  ['\t 꿈 에 도전 하는 건 좋은 거 라고 \n']
# p:  ['다행 이에요 \n']
# _
# Q:  ['더 이상 나 한테 안 왔으면 좋겠어']
# A:  ['\t 의 의사 를 표현 하세요 \n']
# p:  ['기억 만 안 연락 도 \n']
# _
# Q:  ['더워 더워']
# A:  ['\t 너무 많이 마시면 \n']
# p:  ['네 말씀 해주세요 \n']
# _
# Q:  ['길']
# A:  ['\t 로맨틱 하네요 \n']
# p:  ['인연 이 거기 까지 인 가봐요 \n']
# _
# Q:  ['데려다']
# A:  ['\t \n']
# p:  ['못 피 할 수 있으면 피 하세요 \n']
# _
# Q:  ['도서관 앞 자리 사람']
# A:  ['\t 도서관 도 봐요 \n']
# p:  ['조금씩 해보세요 \n']
# _
# Q:  ['도시락 피크닉 가고 싶어']
# A:  ['\t 갈 때 저 도 같이 가요 \n']
# p:  ['오늘 피크닉 가기 좋은 날 이에요 \n']
# _
# Q:  ['짜증나']
# A:  ['\t 와 대화 를 나눠 보세요 \n']
# p:  ['때 는 기분 푸는 음악 어때요 \n']
# _
# Q:  ['돈 많이 좋겠어']
# A:  ['\t 공부 하세요 \n']
# p:  ['오늘 은 그냥 같이 놀아요 \n']
# _
# Q:  ['돈 재미']
# A:  ['\t 부자 거 예요 \n']
# p:  ['그게 최고 죠 \n']
# _
# Q:  ['돈 싶어']
# A:  ['\t 많이 좋아요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['돈 뭐 하나']
# A:  ['\t 저 주세요 \n']
# p:  ['날씨 에 게 좋을 것 같아요 \n']
# _
# Q:  ['돈 뭐 하지']
# A:  ['\t 저 주세요 \n']
# p:  ['큰 게 도움 이 될 거 예요 \n']
# _
# Q:  ['돈 빌려 줬는데 잠수']
# A:  ['\t 바랍니다 \n']
# p:  ['를 마음 을 정리 해 보세요 \n']
# _
# Q:  ['돈 없는데 이라도 해야 할까']
# A:  ['\t \n']
# p:  ['나중 에 가면 돈 이 더 많이 \n']
# _
# Q:  ['돈 좀']
# A:  ['\t 저 는 돈 이 없어요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['돈 만큼 가지 고 는 이라니']
# A:  ['\t 있어서 그런 가봐요 \n']
# p:  ['다 괜찮아질 거 예요 \n']
# _
# Q:  ['돈 이 안']
# A:  ['\t 한 두 \n']
# p:  ['돼요 \n']
# _
# Q:  ['는 진급 하는데']
# A:  ['\t 다음 에는 할 수 있을 거 예요 \n']
# p:  ['조금 만 드세요 \n']
# _
# Q:  ['가야 지']
# A:  ['\t 오세요 \n']
# p:  ['저 도 배워 보고 싶어요 \n']
# _
# Q:  ['귀찮아']
# A:  ['\t 오늘 은 쉬세요 \n']
# p:  ['을 극복 야해요 \n']
# _
# Q:  ['되고 싶은 게 두']
# A:  ['\t 더 괜찮아요 \n']
# p:  ['\n']
# _
# Q:  ['드디어 개강 이다']
# A:  ['\t 곧 방학 이 예요 \n']
# p:  ['기억 으로 거 예요 \n']
# _
# Q:  ['드디어 손']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['드디어 커플 반지 받았어']
# A:  ['\t 로맨틱 한 선물 이네 요 \n']
# p:  ['당황 했겠어요 \n']
# _
# Q:  ['드디어 여행 간다']
# A:  ['\t \n']
# p:  ['좋은 습관 이에요 \n']
# _
# Q:  ['잘 안되네']
# A:  ['\t 을 연습 \n']
# p:  ['잘 좋겠네요 \n']
# _
# Q:  ['가 잘 안 돼']
# A:  ['\t 을 연습 \n']
# p:  ['자연스러운 현상 이에요 \n']
# _
# Q:  ['싶다']
# A:  ['\t 방 여러 개인 집 에서 사세요 \n']
# p:  ['지금 보다 더 잘 살 거 예요 \n']
# _
# Q:  ['있으면 좋겠다']
# A:  ['\t 방 여러 개인 집 에서 사세요 \n']
# p:  ['잘 \n']
# _
# Q:  ['딸기']
# A:  ['\t 맛있게 드세요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['치고 싶다']
# A:  ['\t 많이 힘든 가봅니다 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 여행 좋죠 \n']
# p:  ['\n']
# _
# Q:  ['또 개강 이라니']
# A:  ['\t 즐거운 시작 되길 바랍니다 \n']
# p:  ['방학 이 참 \n']
# _
# Q:  ['또 눈 내려']
# A:  ['\t 눈 봐요 \n']
# p:  ['내일 은 마음 도 거 예요 \n']
# _
# Q:  ['또 야근']
# A:  ['\t 얼른 집 에 가서 바랄게요 \n']
# p:  ['오늘 잠 이 이제 나 봐요 \n']
# _
# Q:  ['똑같은 들']
# A:  ['\t 마음 에 따라 얼마 바뀔 수 있어요 \n']
# p:  ['시간 이 무 거 죠 \n']
# _
# Q:  ['대로 한 거 같은데 왜 맛 이 없지']
# A:  ['\t 이 안 그럴 수도 있어요 \n']
# p:  ['이 봐요 \n']
# _
# Q:  ['살까']
# A:  ['\t 때 \n']
# p:  ['사면 \n']
# _
# Q:  ['할까']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['먹고 싶다']
# A:  ['\t \n']
# p:  ['맛있게 드세요 \n']
# _
# Q:  ['마스크 했어']
# A:  ['\t 자기 관리 좋아요 \n']
# p:  ['이제 바랍니다 \n']
# _
# Q:  ['마음 둘 곳 이 없어']
# A:  ['\t 제 가 있잖아요 \n']
# p:  ['마음 이 바랍니다 \n']
# _
# Q:  ['마음 잡고 다시 시작']
# A:  ['\t 다 잘 될 거 예요 \n']
# p:  ['잘 하는 것 도 많아요 \n']
# _
# Q:  ['마음 을 주고 싶어']
# A:  ['\t 그래서 표현 이 중요해요 \n']
# p:  ['좀 더 여유 가 필요 죠 \n']
# _
# Q:  ['마음 이']
# A:  ['\t 긍정 적 인 생각 을 해보세요 \n']
# p:  ['마음 감기 조심하세요 \n']
# _
# Q:  ['마음 이']
# A:  ['\t 너무 많이 생각 하지 말고 마음 가는 대로 해보세요 \n']
# p:  ['마음 감기 조심하세요 \n']
# _
# Q:  ['마음 이 자꾸 글 을 되네']
# A:  ['\t 글 정리 가 될 거 예요 \n']
# p:  ['글 을 마음 을 정리 해보세요 \n']
# _
# Q:  ['마음 이 자꾸']
# A:  ['\t 마음 이 하지 않을 실수 를 하게 돼요 \n']
# p:  ['관심 이 봐요 \n']
# _
# Q:  ['마음 이']
# A:  ['\t 너무 많이 생각 하지 말고 마음 가는 대로 해보세요 \n']
# p:  ['마음 감기 조심하세요 \n']
# _
# Q:  ['마음 이']
# A:  ['\t 제 가 채워 드릴게요 \n']
# p:  ['마음 감기 조심하세요 \n']
# _
# Q:  ['막 말 하는 거 고 싶어']
# A:  ['\t 고 마음 에서 시작 하세요 \n']
# p:  ['저 도 커피 좋아해요 \n']
# _
# Q:  ['막말 최악 이지']
# A:  ['\t 말로 하는 상처 는 수도 없죠 \n']
# p:  ['다녀오세요 \n']
# _
# Q:  ['하면 자꾸 돼']
# A:  ['\t 성격 이 안 맞나 봐요 \n']
# p:  ['참 해 보세요 \n']
# _
# Q:  ['만든 사람']
# A:  ['\t 마음 과 마음 을 이 고 사람 이 \n']
# p:  ['를 못 하는 것 도 방법 이에요 \n']
# _
# Q:  ['을 봐']
# A:  ['\t 발전 이 요 \n']
# p:  ['더 열심히 노력 하겠습니다 \n']
# _
# Q:  ['많이 같아']
# A:  ['\t \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['말 잘 하고 싶어']
# A:  ['\t 책 을 많이 읽어 보세요 \n']
# p:  ['잘 할 수 있을 거 예요 \n']
# _
# Q:  ['말 을 못 하겠어']
# A:  ['\t 별 거 아니라고 생각 해보세요 \n']
# p:  ['게 가장 좋은 방법 이 죠 \n']
# _
# Q:  ['말 을 예쁘게 하면']
# A:  ['\t 말 잘 하는 사람 들 따라 연습 해보세요 \n']
# p:  ['잘 찾아보세요 \n']
# _
# Q:  ['말 을 왜 이렇게 못 알 아']
# A:  ['\t 노력 하겠습니다 \n']
# p:  ['노력 하겠습니다 \n']
# _
# Q:  ['말 이 안 통해']
# A:  ['\t 대화 의 가 맞는 사람 만나세요 \n']
# p:  ['서로 관심사 를 찾아보세요 \n']
# _
# Q:  ['말 이 안 통해']
# A:  ['\t 포기 하지 마세요 \n']
# p:  ['서로 관심사 를 찾아보세요 \n']
# _
# Q:  ['말']
# A:  ['\t 사는 재미 가 \n']
# p:  ['오늘 헤어졌어 라고 하면 위로 해 드려요 \n']
# _
# Q:  ['맛있는 냄새 나']
# A:  ['\t \n']
# p:  ['공부 하세요 \n']
# _
# Q:  ['맛집']
# A:  ['\t 맛있게 바랍니다 \n']
# p:  ['좋은 건강 습관 이에요 \n']
# _
# Q:  ['']
# A:  ['\t 는 언제나 \n']
# p:  ['\n']
# _
# Q:  ['맞는 결정 을']
# A:  ['\t 네 이제 잘 예요 \n']
# p:  ['궁금하네요 \n']
# _
# Q:  ['맞는 선택 일까']
# A:  ['\t 잘 선택 했어요 \n']
# p:  ['결정 하기 다시 시작 \n']
# _
# Q:  ['많이 사람']
# A:  ['\t 좀 깨 요 \n']
# p:  ['코 감기 일 수도 있어요 \n']
# _
# Q:  ['']
# A:  ['\t 맛 을 거 같아요 \n']
# p:  ['\n']
# _
# Q:  ['한 생각나']
# A:  ['\t 스트레스 일 가요 \n']
# p:  ['많이 \n']
# _
# Q:  ['맥주']
# A:  ['\t 이 요 \n']
# p:  ['이 요 \n']
# _
# Q:  ['맥주 한 잔 어때']
# A:  ['\t 저 랑 한 잔 해 요 \n']
# p:  ['보기 만 해도 좋아요 \n']
# _
# Q:  ['맨날 애']
# A:  ['\t 똑같은 건 없어요 \n']
# p:  ['와 않을 수 있어도 생각 보다 힘 이 \n']
# _
# Q:  ['머리 스타일']
# A:  ['\t 새로운 스타일 에 도전 하는 것 도 좋아요 \n']
# p:  ['항상 관리 하세요 \n']
# _
# Q:  ['머리 아파']
# A:  ['\t 시원한 바람 쉬 고 약 먹기 \n']
# p:  ['잠시 휴식 을 취 해보세요 \n']
# _
# Q:  ['머리 안']
# A:  ['\t 앞머리 \n']
# p:  ['신경 쓰는 일이 봅니다 \n']
# _
# Q:  ['머리 좀']
# A:  ['\t 해도 괜찮을 거 예요 \n']
# p:  ['많이 \n']
# _
# Q:  ['머리 가 한 대 같아']
# A:  ['\t 잠시 휴식 을 취 해보세요 \n']
# p:  ['마음 의 준비 가 되길 바랍니다 \n']
# _
# Q:  ['먹고 나 니까']
# A:  ['\t 자연 의 죠 주무 세 요 \n']
# p:  ['세상 에 비밀 은 없어요 \n']
# _
# Q:  ['먹고 자고 싶어']
# A:  ['\t 저 도 싶네요 \n']
# p:  ['맛 나게 드세요 \n']
# _
# Q:  ['먹고 자고 먹고 자고']
# A:  ['\t 그게 최고 죠 \n']
# p:  ['쇼핑 을 줄 여보세요 \n']
# _
# Q:  ['먹고 해도 될까']
# A:  ['\t 되는 방법 이 죠 \n']
# p:  ['맛 나게 드세요 \n']
# _
# Q:  ['먹을까']
# A:  ['\t 조금 만 드세요 \n']
# p:  ['이네 요 \n']
# _
# Q:  ['먼지 싫다']
# A:  ['\t 마스크 쓰고 \n']
# p:  ['오늘 미세먼지 가 \n']
# _
# Q:  ['먼지 어때']
# A:  ['\t 오늘 미세먼지 가 \n']
# p:  ['데이트 신청 해보세요 \n']
# _
# Q:  ['나이 들 고 싶다']
# A:  ['\t 지금 도 있어요 \n']
# p:  ['신경 쓸 일이 있나 봐요 \n']
# _
# Q:  ['살 고']
# A:  ['\t 지금 도 \n']
# p:  ['잘 \n']
# _
# Q:  ['이 있으면 뭐 하나']
# A:  ['\t 대로 하지 않는 사람 들 이 많죠 \n']
# p:  ['살 고 사세요 \n']
# _
# Q:  ['하는 습관 필요해']
# A:  ['\t 오늘 부터 해 요 \n']
# p:  ['여행 보세요 \n']
# _
# Q:  ['하는 습관 을 싶어']
# A:  ['\t 오늘 부터 해 요 \n']
# p:  ['계획 적 이고 적 인 소비 를 해보세요 \n']
# _
# Q:  ['랑 이 것 저 것 사야 되는데']
# A:  ['\t 잘 골라 보세요 \n']
# p:  ['좋은 사람 이랑 연락 해보는 건 어떨까 요 \n']
# _
# Q:  ['없는데']
# A:  ['\t 운전 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['없는데']
# A:  ['\t 운전 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['명절 스트레스']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['가 너무 많아']
# A:  ['\t 조심하세요 \n']
# p:  ['세상 에는 사람 들 이 있어요 \n']
# _
# Q:  ['노력']
# A:  ['\t 노력 해야죠 \n']
# p:  ['\n']
# _
# Q:  ['모르는 걸까 모르는 철 하는 걸까']
# A:  ['\t 여우 네 요 \n']
# p:  ['적 인 스타일 이네 요 \n']
# _
# Q:  ['모르는 사람 너무 스트레스 야']
# A:  ['\t 자신 과 마음 이 맞는 좋은 사람 만나세요 \n']
# p:  ['가족 에게 주세요 \n']
# _
# Q:  ['모른 척']
# A:  ['\t 그게 서로 에게 선택 일 거 예요 \n']
# p:  ['그게 서로 에게 선택 일 거 예요 \n']
# _
# Q:  ['선물 해볼까']
# A:  ['\t 로맨틱 하네요 \n']
# p:  ['직접 주는 게 더 좋을 것 같아요 \n']
# _
# Q:  ['가야 지']
# A:  ['\t 시원하게 오세요 \n']
# p:  ['저 도 배워 보고 싶어요 \n']
# _
# Q:  ['목 이']
# A:  ['\t 가끔 씩 스트레칭 을 해주세요 \n']
# p:  ['잘못 봐요 \n']
# _
# Q:  ['목 이']
# A:  ['\t 목 감기 봐요 \n']
# p:  ['잘못 봐요 \n']
# _
# Q:  ['봐']
# A:  ['\t 아무 생각 하지 말고 쉬세요 \n']
# p:  ['거울 을 보면서 얼굴 망 가 뜨 리기 놀이 해 적 재미 있어요 \n']
# _
# Q:  ['이 로 됐어']
# A:  ['\t 돈 을 하고 이용 할 가치 가 있는지 보세요 \n']
# p:  ['좋은 생각 만 하세요 \n']
# _
# Q:  ['']
# A:  ['\t 비 가 \n']
# p:  ['\n']
# _
# Q:  ['아파']
# A:  ['\t 비 가 \n']
# p:  ['아프지 않았으면 좋겠어요 \n']
# _
# Q:  ['않아']
# A:  ['\t 이 많으면 추천 해요 \n']
# p:  ['의 변화 를 줘 보세요 \n']
# _
# Q:  ['문 여 는 소리 나서']
# A:  ['\t 신고 하세요 \n']
# p:  ['데이트 조심하세요 \n']
# _
# Q:  ['문자 친구 도 없어']
# A:  ['\t 저 랑 하세요 \n']
# p:  ['다른 연락 을 해보세요 \n']
# _
# Q:  ['가 너무 다른 것 같아']
# A:  ['\t 인정 해주세요 \n']
# p:  ['나를 하지 마세요 \n']
# _
# Q:  ['물 차']
# A:  ['\t \n']
# p:  ['좋은 곳 으로 데려다 줄 거 예요 \n']
# _
# Q:  ['물 좋은데 어디 야']
# A:  ['\t 소개팅 시켜 달라 고 말 해보세요 \n']
# p:  ['안 \n']
# _
# Q:  ['안 나와']
# A:  ['\t 가 해 보세요 \n']
# p:  ['너무 신경 쓰지 마세요 \n']
# _
# Q:  ['뭐 먹을 거 없나']
# A:  ['\t 냉장고 해보세요 \n']
# p:  ['시원한 는 어때요 \n']
# _
# Q:  ['뭐 이렇게 쉬운 게 없지']
# A:  ['\t 저 도 어려운 게 에요 \n']
# p:  ['좋은 사람과 축하 해요 \n']
# _
# Q:  ['뭐 하는지 궁금해']
# A:  ['\t 요 \n']
# p:  ['그 사람 도 그럴 거 예요 \n']
# _
# Q:  ['뭐 알 아']
# A:  ['\t 오늘 헤어졌어 라고 하면 위로 해 드려요 \n']
# p:  ['나 랑 같이 놀아요 \n']
# _
# Q:  ['뭐 가 잘 못 된 걸까']
# A:  ['\t 처음 부터 되 보세요 \n']
# p:  ['나 한테 맞는 공부 방법 게 \n']
# _
# Q:  ['']
# A:  ['\t 계속 그러면 말 하세요 \n']
# p:  ['\n']
# _
# Q:  ['배워 볼까']
# A:  ['\t 에는 언제나 이에요 \n']
# p:  ['은 다 \n']
# _
# Q:  ['뭐 부터 할까']
# A:  ['\t 당신 그대로 의 모습 이 보기 좋아요 \n']
# p:  ['어느 결정 을 하든 후회 가 되지 않겠지만 힘내세요 \n']
# _
# Q:  ['뭐 할까']
# A:  ['\t 저 랑 놀아요 \n']
# p:  ['저 랑 놀아요 \n']
# _
# Q:  ['뭔 참견 이야']
# A:  ['\t 저 는 도움 이 되고 싶어요 \n']
# p:  ['\n']
# _
# Q:  ['뭔가 자꾸']
# A:  ['\t 않아도 돼요 \n']
# p:  ['마음 이 를 둘 가능성 이 \n']
# _
# Q:  ['미세먼지']
# A:  ['\t 마스크 \n']
# p:  ['해보세요 \n']
# _
# Q:  ['미세먼지 최악 인데']
# A:  ['\t 집 에 마스크 쓰고 나가세요 \n']
# p:  ['다른 사람 이 라면 고마워 할 거 예요 \n']
# _
# Q:  ['미세먼지 가 너무 많아']
# A:  ['\t 살기 더 \n']
# p:  ['대 청소 를 해보세요 \n']
# _
# Q:  ['미세먼지 가 너무 많아 하늘 이']
# A:  ['\t 살기 더 \n']
# p:  ['시원하게 지르고 오세요 \n']
# _
# Q:  ['']
# A:  ['\t 주세요 \n']
# p:  ['\n']
# _
# Q:  ['바람']
# A:  ['\t 같이 가요 \n']
# p:  ['고쳐 쓸 수 없는 이에요 \n']
# _
# Q:  ['바람 가']
# A:  ['\t 잘 오세요 \n']
# p:  ['입 에 쓴 게 몸 에는 좋을 거 예요 \n']
# _
# Q:  ['바람 이 너무 많이']
# A:  ['\t 감기 조심하세요 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['반 부터 올해']
# A:  ['\t 1년 \n']
# p:  ['잘 볼 수 있을 거 예요 \n']
# _
# Q:  ['반 에 친구 가 없어']
# A:  ['\t 친구 를 사귈 수 있을 거 예요 \n']
# p:  ['제 가 놀아 드리고 싶네요 \n']
# _
# Q:  ['반지']
# A:  ['\t 마음 에 드는 걸 로 하세요 \n']
# p:  ['음 생각 해보세요 \n']
# _
# Q:  ['반지 선물 하면']
# A:  ['\t 로맨틱 하네요 \n']
# p:  ['같이 것 도 좋을 거 같아요 \n']
# _
# Q:  ['반지']
# A:  ['\t 음 생각 해보세요 \n']
# p:  ['음 생각 해보세요 \n']
# _
# Q:  ['발렌타인데이 인데 줄 사람 이 없어']
# A:  ['\t 가족 에게 주세요 \n']
# p:  ['당신 이 가장 있다는 걸 잊지 마세요 \n']
# _
# Q:  ['밥 옷 에']
# A:  ['\t \n']
# p:  ['열심히 해서 받으세요 \n']
# _
# Q:  ['밥']
# A:  ['\t \n']
# p:  ['해 드세요 \n']
# _
# Q:  ['밥']
# A:  ['\t 드세요 \n']
# p:  ['해 드세요 \n']
# _
# Q:  ['밥']
# A:  ['\t 않아요 \n']
# p:  ['해 드세요 \n']
# _
# Q:  ['밥']
# A:  ['\t 저 는 가 밥 이 예요 \n']
# p:  ['해 드세요 \n']
# _
# Q:  ['밥 이 없어']
# A:  ['\t 새로운 관계 를 돼요 \n']
# p:  ['신나는 노래 를 들어 보세요 \n']
# _
# Q:  ['방 들 이 준비 뭐 하지']
# A:  ['\t 음식 을 시켜 보세요 \n']
# p:  ['생각 하고 말 하는 연습 을 해보세요 \n']
# _
# Q:  ['방학 이']
# A:  ['\t 방학 이 참 \n']
# p:  ['시간 내서 가보세요 \n']
# _
# Q:  ['죽 을 것 같아 힘 이 없어']
# A:  ['\t 얼른 드세요 \n']
# p:  ['힘내세요 \n']
# _
# Q:  ['']
# A:  ['\t 얼른 맛 난 음식 드세요 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 좀 쉬세요 \n']
# p:  ['\n']
# _
# Q:  ['배 에서 소리 남']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['이']
# A:  ['\t 운동 해보세요 \n']
# p:  ['\n']
# _
# Q:  ['버스 에서 사람']
# A:  ['\t \n']
# p:  ['습관 되지 않길 바랄게요 \n']
# _
# Q:  ['버스 하면 생각나']
# A:  ['\t 추억 이 있나 봐요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['번호 달라 고 해볼까']
# A:  ['\t 용기 를 내 보세요 \n']
# p:  ['말 해보세요 \n']
# _
# Q:  ['번호 볼까 나']
# A:  ['\t 용기 를 내 보세요 \n']
# p:  ['많이 지쳤나 봐요 \n']
# _
# Q:  ['벌써 개강 이라니']
# A:  ['\t 방학 이 참 \n']
# p:  ['방학 이 참 \n']
# _
# Q:  ['벌써 가 없어']
# A:  ['\t 를 \n']
# p:  ['에너지 가 필요한 순간 이네 요 \n']
# _
# Q:  ['법 을 피해 가는 사람']
# A:  ['\t 능력 하지만 가 거 예요 \n']
# p:  ['능력 하지만 가 거 예요 \n']
# _
# Q:  ['벚꽃 이 너무 예뻐']
# A:  ['\t 너무 \n']
# p:  ['부모님 이 \n']
# _
# Q:  ['베터리 야']
# A:  ['\t 미리 충전 하세요 \n']
# p:  ['미리 충전 하세요 \n']
# _
# Q:  ['에서 사업 해볼까']
# A:  ['\t 좀 더 하세요 \n']
# p:  ['확신 이 있을 때 시작 해보세요 \n']
# _
# Q:  ['이 걸 기다려']
# A:  ['\t 기다리는 전화 가 있나 봐요 \n']
# p:  ['상대 에게 피해 를 주는 건 어떨까 요 \n']
# _
# Q:  ['']
# A:  ['\t 얼른 보아 요 \n']
# p:  ['\n']
# _
# Q:  ['변화 를 좀 주고 싶다']
# A:  ['\t 긍정 적 으로 바뀔 수 있어요 \n']
# p:  ['많이 지쳤나 봐요 \n']
# _
# Q:  ['별 보러 가고 싶다']
# A:  ['\t 로맨틱 하네요 \n']
# p:  ['로맨틱 하네요 \n']
# _
# Q:  ['게 없는 일상']
# A:  ['\t 그게 행복 일지 도 몰라요 \n']
# p:  ['한 잔 하기 좋은 \n']
# _
# Q:  ['게 없는 하루']
# A:  ['\t 마음 을 가져 보세요 \n']
# p:  ['요즘 바쁜 가봐요 \n']
# _
# Q:  ['별 이 안']
# A:  ['\t 에서 하늘 을 올려 봐 보세요 \n']
# p:  ['\n']
# _
# Q:  ['병원 가기 싫어']
# A:  ['\t 더 전 에 가보세요 \n']
# p:  ['가지 마세요 \n']
# _
# Q:  ['']
# A:  ['\t 신고 하세요 \n']
# p:  ['\n']
# _
# Q:  ['보일러 나왔어']
# A:  ['\t 이번 달 비 가 많이 \n']
# p:  ['쉬운 일 은 \n']
# _
# Q:  ['']
# A:  ['\t 시작 하세요 \n']
# p:  ['\n']
# _
# Q:  ['좀']
# A:  ['\t 시작 하세요 \n']
# p:  ['저 한테 말 해보세요 \n']
# _
# Q:  ['전공 하고 싶어']
# A:  ['\t 관리 하세요 \n']
# p:  ['진심 으로 다가가 보세요 \n']
# _
# Q:  ['하고 싶어']
# A:  ['\t 관리 하세요 \n']
# p:  ['지금 도 충분히 \n']
# _
# Q:  ['하면 그래도 하는게']
# A:  ['\t 나중 에 도움 이 될 거 예요 \n']
# p:  ['당신 의 삶 을 하지 마세요 \n']
# _
# Q:  ['했어']
# A:  ['\t 많이 좋죠 \n']
# p:  ['\n']
# _
# Q:  ['치고 옴']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['봄 인가 봐']
# A:  ['\t 날씨 가 많이 \n']
# p:  ['이 이 무색 해요 \n']
# _
# Q:  ['부모님 노후 가 걱정 돼']
# A:  ['\t 상담 이나 을 받아 보는 것 도 좋을 거 예요 \n']
# p:  ['상담 이나 을 받아 보는 것 도 좋을 거 예요 \n']
# _
# Q:  ['부모님 선물 은 뭐 가']
# A:  ['\t 사랑 과 이면 충분해요 \n']
# p:  ['상대방 도 좋지만 에서 적 으로 생각 해보세요 \n']
# _
# Q:  ['부자 하고 싶어']
# A:  ['\t 그게 최고 죠 \n']
# p:  ['지금 도 일상 이에요 \n']
# _
# Q:  ['어떤 으로 하지']
# A:  ['\t 당신 이 좋아하는 꽃 으로 만들어 보세요 \n']
# p:  ['아닌 건 아니라고 말 하세요 \n']
# _
# Q:  ['분위기 좋았는데']
# A:  ['\t 늦지 않았어요 \n']
# p:  ['서로 를 향 한 감정 도 \n']
# _
# Q:  ['날']
# A:  ['\t 조심하세요 \n']
# p:  ['소원 을 보세요 \n']
# _
# Q:  ['온 거 같아']
# A:  ['\t 고민 이 봐요 \n']
# p:  ['과식 하지 말고 먹고 마세요 \n']
# _
# Q:  ['인가 봐']
# A:  ['\t 고민 이 봐요 \n']
# p:  ['자연스러운 이에요 \n']
# _
# Q:  ['인데 같이 먹을 사람 이 없어']
# A:  ['\t 은 혼자 \n']
# p:  ['사람 마다 \n']
# _
# Q:  ['이 뭐 야']
# A:  ['\t 쉽게 말 해서 많은 들 이 으로 여 \n']
# p:  ['힘들 때 같이 있는 거 요 \n']
# _
# Q:  ['이 왜 이렇게']
# A:  ['\t 쉽게 말 해서 많은 들 이 으로 여 \n']
# p:  ['이 젠 그 기억 을 놓아 보세요 \n']
# _
# Q:  ['비 오네']
# A:  ['\t 우산 준비 하세요 \n']
# p:  ['다음 달 에는 더 절약 해봐요 \n']
# _
# Q:  ['비']
# A:  ['\t 우산 \n']
# p:  ['우산 들고 나가세요 \n']
# _
# Q:  ['받았어']
# A:  ['\t 운동 해보세요 \n']
# p:  ['부러워요 \n']
# _
# Q:  ['비밀 수 있을까']
# A:  ['\t 세상 에 비밀 은 없어요 \n']
# p:  ['입 을 연습 해보세요 \n']
# _
# Q:  ['까먹었다']
# A:  ['\t 찾기 를 해보세요 \n']
# p:  ['다음 부터는 잘 \n']
# _
# Q:  ['뭐']
# A:  ['\t 찾기 를 해보세요 \n']
# p:  ['맛있는 거 드세요 \n']
# _
# Q:  ['']
# A:  ['\t 먹으면 좋죠 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 사람 이 가장 말 이 죠 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 어서 잊고 새 출발 하세요 \n']
# p:  ['\n']
# _
# Q:  ['때문 에 죽 을 것 같아']
# A:  ['\t 얼른 새 출발 하세요 \n']
# p:  ['자괴 감 에서 이제 \n']
# _
# Q:  ['빨리']
# A:  ['\t 조심하세요 \n']
# p:  ['보여요 \n']
# _
# Q:  ['사는 게']
# A:  ['\t 되는게 많지 않죠 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['사람 만나는 게 쉽지 않아']
# A:  ['\t 미리 않아도 돼요 \n']
# p:  ['다른 사람 들 이 별로 라고 말 하는 이유 를 생각 해보세요 \n']
# _
# Q:  ['사람 만나는 게 피곤해']
# A:  ['\t 그 사람 을 위해 에너지 를 요 \n']
# p:  ['서로 에게 믿음 을 주세요 \n']
# _
# Q:  ['사람 은 많은데 외로워']
# A:  ['\t 사람 은 외로운 동물 이 죠 \n']
# p:  ['직접 적 이든 간접 적 이든 의사 를 확실히 보세요 \n']
# _
# Q:  ['사람 의 마음 을 어려워']
# A:  ['\t 진심 으로 마음 을 전 해보세요 \n']
# p:  ['그렇게 하는 사람 만나지 마 요 \n']
# _
# Q:  ['나 는 거 아프다']
# A:  ['\t 드세요 \n']
# p:  ['좀 더 \n']
# _
# Q:  ['사업 하고 있어']
# A:  ['\t 바랍니다 \n']
# p:  ['삶 의 이 죠 \n']
# _
# Q:  ['가 너무 많아']
# A:  ['\t 해 요 \n']
# p:  ['세상 에는 사람 들 이 있어요 \n']
# _
# Q:  ['사진 잘 싶어']
# A:  ['\t 많이 보면 조금씩 이 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['싶어']
# A:  ['\t 뒷 감당 자신 있으면 하세요 \n']
# p:  ['마음 대로 할 수 있을 거 예요 \n']
# _
# Q:  ['에서도 좋은 사람 많이 만날 수 있을까']
# A:  ['\t 대하 는 태도 에 따라 다를 것 같아요 \n']
# p:  ['서로 에게 좋을 거 예요 \n']
# _
# Q:  ['살 만 한 게 없네']
# A:  ['\t 안 사면 그만큼 \n']
# p:  ['맞았나 봐요 \n']
# _
# Q:  ['삼겹살 먹고 싶다']
# A:  ['\t 맛 나게 드세요 \n']
# p:  ['맛 나게 드세요 \n']
# _
# Q:  ['상사 너무 수 있을까']
# A:  ['\t 피하 지 말고 적극 적 으로 을 인정 하고 를 보 여보세요 \n']
# p:  ['다 잘 될 거 예요 \n']
# _
# Q:  ['상사 가 때']
# A:  ['\t 를 에 봅니다 \n']
# p:  ['좀 더 \n']
# _
# Q:  ['새 신발 샀어']
# A:  ['\t 좋은 곳 으로 데려다 줄 거 예요 \n']
# p:  ['내 집 마련 축하 드려요 \n']
# _
# Q:  ['새로운 곳 에 적응 을 못 해']
# A:  ['\t 처음 부터 잘 하는 사람 은 없어요 \n']
# p:  ['게 아니라 무 걸 수도 있어요 \n']
# _
# Q:  ['새로운 를 싶어']
# A:  ['\t 주변 의 좋은 사람 들 에게 연락 해보세요 \n']
# p:  ['신경 쓰지 마세요 \n']
# _
# Q:  ['새 신발 비 와']
# A:  ['\t 얼른 실내 로 \n']
# p:  ['얼른 실내 로 \n']
# _
# Q:  ['생각 만 해도 마음 이']
# A:  ['\t 긍정 적 인 생각 을 해보세요 \n']
# p:  ['들 로 기분 이 죠 \n']
# _
# Q:  ['너무 심해']
# A:  ['\t 약 을 병원 에 가보세요 \n']
# p:  ['휴가 가 \n']
# _
# Q:  ['샤워 있으니까 좋다']
# A:  ['\t 않고 \n']
# p:  ['좋은 곳 인가 봐요 \n']
# _
# Q:  ['왔어']
# A:  ['\t 마음 에 드는 책 을 잘 찾아보세요 \n']
# p:  ['조심하세요 \n']
# _
# Q:  ['에']
# A:  ['\t 마음 의 을 \n']
# p:  ['\n']
# _
# Q:  ['출발']
# A:  ['\t 좋은 취미 네 요 \n']
# p:  ['좋은 말 만 말 하세요 \n']
# _
# Q:  ['선생님 좋아해']
# A:  ['\t 선생님 도 좋아할 거 예요 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['선생님 이 나 만']
# A:  ['\t 직접 보세요 \n']
# p:  ['아무래도 이 요 \n']
# _
# Q:  ['선생님 이 나 한테 왜 그럴까']
# A:  ['\t 직접 보세요 \n']
# p:  ['혼자 가 아니에요 \n']
# _
# Q:  ['선생님 한테 선물']
# A:  ['\t 안 줘도 괜찮아요 \n']
# p:  ['말 해보세요 \n']
# _
# Q:  ['선 자리']
# A:  ['\t 많이 만나 보세요 \n']
# p:  ['해보세요 \n']
# _
# Q:  ['섬유 향 좋다']
# A:  ['\t 향 이 많은 걸 말 \n']
# p:  ['많이 생각 해요 \n']
# _
# Q:  ['수 있을까']
# A:  ['\t 할 수 있는 사람 이 라면 무엇 이든 손 에 수 있을 거 예요 \n']
# p:  ['지금 보다 더 잘 살 거 예요 \n']
# _
# Q:  ['받아 볼까']
# A:  ['\t 받고 충격 받지 마세요 \n']
# p:  ['받고 충격 받지 마세요 \n']
# _
# Q:  ['무서워']
# A:  ['\t 안해 도 예뻐요 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['가기']
# A:  ['\t 사세요 \n']
# p:  ['는 아니에요 \n']
# _
# Q:  ['잘 방법']
# A:  ['\t 얼굴 이 준비 \n']
# p:  ['잘 하는 건 칭찬 해주고 점 은 그대로 사랑 해주세요 \n']
# _
# Q:  ['셀프 해볼까']
# A:  ['\t 이 가서 더 애정 이 생길 것 같아요 \n']
# p:  ['은 어때요 \n']
# _
# Q:  ['소개팅 남 연락 이 없어']
# A:  ['\t 하루 그 이상 이면 끝 인거 예요 \n']
# p:  ['신경 쓰고 싶지 않은 사람 도 있어요 \n']
# _
# Q:  ['소']
# A:  ['\t 좋은 일이 길 바랍니다 \n']
# p:  ['사랑 의 나이 가 생각 해요 \n']
# _
# Q:  ['소원 뭐 말 하지']
# A:  ['\t \n']
# p:  ['먼저 고백 해보세요 \n']
# _
# Q:  ['속이 안 좋아']
# A:  ['\t 가 안 되나 봐요 \n']
# p:  ['신경 쓸 일이 있나 봐요 \n']
# _
# Q:  ['속이 영 안 좋아']
# A:  ['\t 가 안 되나 봐요 \n']
# p:  ['많이 지쳤나 봐요 \n']
# _
# Q:  ['거 더 못 하겠어']
# A:  ['\t 남 을 \n']
# p:  ['바쁜 가봐요 \n']
# _
# Q:  ['이 긴 사람']
# A:  ['\t 이네 요 \n']
# p:  ['더 많이 바라요 \n']
# _
# Q:  ['이 예쁜 사람']
# A:  ['\t 이네 요 \n']
# p:  ['절대 그렇지 않아요 \n']
# _
# Q:  ['오는 거 싫어']
# A:  ['\t 밖 에서 만나 보세요 \n']
# p:  ['를 여유 를 해보세요 \n']
# _
# Q:  ['아파']
# A:  ['\t 스트레칭 해주세요 \n']
# p:  ['아프지 않았으면 좋겠어요 \n']
# _
# Q:  ['']
# A:  ['\t 스트레칭 해주세요 \n']
# p:  ['\n']
# _
# Q:  ['이나']
# A:  ['\t 때 바로 하세요 \n']
# p:  ['때 바로 하세요 \n']
# _
# Q:  ['쇼핑 이나 할까']
# A:  ['\t 쇼핑 좋아요 \n']
# p:  ['정말 눈 이 \n']
# _
# Q:  ['']
# A:  ['\t 기간 을 보세요 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 잘 볼 수 있을 거 예요 \n']
# p:  ['\n']
# _
# Q:  ['잘 보는 방법']
# A:  ['\t 컨디션 조절 하세요 \n']
# p:  ['어느 이야기 보다 가슴 먹 먹 할 거 예요 \n']
# _
# Q:  ['에서 좋은 받는 방법']
# A:  ['\t 컨디션 조절 하세요 \n']
# p:  ['운동 을 해보세요 \n']
# _
# Q:  ['느낌 이']
# A:  ['\t 해결 될 거니 기다려 보세요 \n']
# p:  ['사랑 이 사람 을 만들어요 \n']
# _
# Q:  ['게']
# A:  ['\t 정리 해보세요 \n']
# p:  ['너무 \n']
# _
# Q:  ['잘 하고 싶어']
# A:  ['\t 받아 보세요 \n']
# p:  ['잘 할 수 있을 거 예요 \n']
# _
# Q:  ['이야']
# A:  ['\t 이나 운동 해보세요 \n']
# p:  ['좋은 결과 있을 거 예요 \n']
# _
# Q:  ['술']
# A:  ['\t 혼자 마세요 \n']
# p:  ['혼자 마세요 \n']
# _
# Q:  ['술']
# A:  ['\t 술 은 적당히 즐기세요 \n']
# p:  ['혼자 마세요 \n']
# _
# Q:  ['술 안']
# A:  ['\t 너무 많이 안 돼요 \n']
# p:  ['술 은 좋죠 \n']
# _
# Q:  ['술 가고 싶다']
# A:  ['\t 같이 \n']
# p:  ['맛있게 드세요 \n']
# _
# Q:  ['술 많이']
# A:  ['\t 적당히 드세요 \n']
# p:  ['다음 학기 에는 관리 를 더 열심히 해봐요 \n']
# _
# Q:  ['술 먹고 싶어']
# A:  ['\t 혼자 마세요 \n']
# p:  ['혼자 마세요 \n']
# _
# Q:  ['술 먹으면 연락 이 안 돼']
# A:  ['\t 화장실 갈 때 연락 하 라고 해봐요 \n']
# p:  ['걱정 이 많이 되겠네요 \n']
# _
# Q:  ['술 만 먹으면 전화 를 안 받아']
# A:  ['\t 화장실 갈 때 연락 하 라고 해봐요 \n']
# p:  ['화장실 갈 때 연락 하 라고 해봐요 \n']
# _
# Q:  ['술 만 먹으면 집 에 늦게 와']
# A:  ['\t 몸 에 먹는 게 말 해보세요 \n']
# p:  ['부모님 도 \n']
# _
# Q:  ['쉬 고 싶다']
# A:  ['\t 내려 \n']
# p:  ['충전 도 되죠 \n']
# _
# Q:  ['쉬 고 싶은데 회식 가야 돼']
# A:  ['\t 일상 사이 에서 이 잘 바랄게요 \n']
# p:  ['연락 은 삭제 해보세요 \n']
# _
# Q:  ['하면 에']
# A:  ['\t 에 무리 가 갈 거 예요 \n']
# p:  ['\n']
# _
# Q:  ['스키 배워 보고 싶다']
# A:  ['\t 금방 거 예요 \n']
# p:  ['열심히 해서 받으세요 \n']
# _
# Q:  ['']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['먹고 싶어']
# A:  ['\t 집 에서도 할 수 있어요 \n']
# p:  ['건강 을 위해 조금씩 드세요 \n']
# _
# Q:  ['가고 싶어']
# A:  ['\t 맛있게 드세요 \n']
# p:  ['저 도 딸기 좋아해요 같이 가요 \n']
# _
# Q:  ['가고 싶어']
# A:  ['\t 맛있게 드세요 \n']
# p:  ['저 도 딸기 좋아해요 같이 가요 \n']
# _
# Q:  ['습관 을 고 어려워']
# A:  ['\t 고 습관 이라고 \n']
# p:  ['고 습관 이라고 \n']
# _
# Q:  ['시간']
# A:  ['\t 그 것 도 다 경험 이라고 생각 하세요 \n']
# p:  ['다른 일 을 해보세요 \n']
# _
# Q:  ['시간 빨리 감']
# A:  ['\t 시간 은 상대 적 으로 \n']
# p:  ['시간 만큼 아픔 도 거 예요 \n']
# _
# Q:  ['']
# A:  ['\t 기간 을 보세요 \n']
# p:  ['\n']
# _
# Q:  ['잘 못']
# A:  ['\t 기간 을 보세요 \n']
# p:  ['잘 하는 걸 아직 못 걸 수도 있어요 \n']
# _
# Q:  ['살까']
# A:  ['\t 아무래도 덜 경쟁 \n']
# p:  ['사면 \n']
# _
# Q:  ['좀 이상한 듯']
# A:  ['\t 아직 이 라면 더 살펴보세요 \n']
# p:  ['지금 있어요 \n']
# _
# Q:  ['가 이상해']
# A:  ['\t 아직 이 라면 더 살펴보세요 \n']
# p:  ['\n']
# _
# Q:  ['시선 이 자꾸 느껴져']
# A:  ['\t 자신 만 생각 하세요 \n']
# p:  ['이 젠 그 분 을 놓아주세요 \n']
# _
# Q:  ['시험 끝나고 만나고 싶어']
# A:  ['\t 만날 날 까지 \n']
# p:  ['그런 날 이 있죠 \n']
# _
# Q:  ['신경 쓰여']
# A:  ['\t 신경 쓰는 사람 들 무시 하세요 \n']
# p:  ['직접 물어보세요 \n']
# _
# Q:  ['신발 선물 받았어']
# A:  ['\t 건가 요 \n']
# p:  ['말 해 주세요 \n']
# _
# Q:  ['준비 혼자 할 수 있을까']
# A:  ['\t 신혼여행 은 이 죠 \n']
# p:  ['혼자 만 있지 마세요 \n']
# _
# Q:  ['실내 데이트 좋을까']
# A:  ['\t 이나 이 \n']
# p:  ['야경 좋은 곳 으로 가보세요 \n']
# _
# Q:  ['실수 했다']
# A:  ['\t 부족한 부분 이 뭔 지 확인 해보세요 \n']
# p:  ['이제 \n']
# _
# Q:  ['뭐 하면 좋을까']
# A:  ['\t 저 랑 이야기 해요 \n']
# p:  ['평소 에 볼 수 없어요 \n']
# _
# Q:  ['']
# A:  ['\t 저 랑 놀아요 \n']
# p:  ['\n']
# _
# Q:  ['커 해볼까']
# A:  ['\t 눈 은 기본 이 죠 \n']
# p:  ['적 으로 도움 이 되겠네요 \n']
# _
# Q:  ['커 할까']
# A:  ['\t 돈 많이 \n']
# p:  ['\n']
# _
# Q:  ['이 나 만 해']
# A:  ['\t 애정 표현 이라고 생각 하세요 \n']
# p:  ['일 하고 있는데 연락 하기 쉽지 않죠 \n']
# _
# Q:  ['없는 걱정 1 위 연예인 걱정']
# A:  ['\t 입니다 \n']
# p:  ['그 분 생각 을 많이 했나 봐요 곧 좋은 소식 이 하는 것 아닐까 요 \n']
# _
# Q:  ['싫어']
# A:  ['\t 푹 쉬세요 \n']
# p:  ['상처 봐요 \n']
# _
# Q:  ['아 놔 왜']
# A:  ['\t 자체 로 의미 가 있으니까 요 \n']
# p:  ['그 분 생각 이 나나 봐요 \n']
# _
# Q:  ['아']
# A:  ['\t 약 챙겨 치과 가보세요 \n']
# p:  ['노래 불러 까요 \n']
# _
# Q:  ['아무 것 도 하고 싶지 아무 거나 하고 싶어']
# A:  ['\t 위해 무엇 인가 를 하고 있는 게 좋을 거 예요 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['아무래도 속 은 거 같아']
# A:  ['\t 기분 \n']
# p:  ['둘 이 아니라 일 이지 요 \n']
# _
# Q:  ['쇼핑']
# A:  ['\t 쇼핑 은 이 죠 \n']
# p:  ['해보세요 \n']
# _
# Q:  ['아이돌 이 남친 이면 좋을텐데']
# A:  ['\t 궁금하네요 \n']
# p:  ['제 가 들어 드릴게요 \n']
# _
# Q:  ['아직 결정 못']
# A:  ['\t 결정 은 좋을 거 예요 \n']
# p:  ['보답 을 바라지 마세요 \n']
# _
# Q:  ['아직 장난 인 것 같아']
# A:  ['\t 봐요 \n']
# p:  ['너무 않아도 돼요 \n']
# _
# Q:  ['아직도 공부 할 게 많아']
# A:  ['\t 공부 에 를 가져 보세요 \n']
# p:  ['하나 씩 하세요 \n']
# _
# Q:  ['아침']
# A:  ['\t 않아요 \n']
# p:  ['좋은 식 습관 이에요 \n']
# _
# Q:  ['아침 안 자꾸 그래']
# A:  ['\t 봐요 \n']
# p:  ['다른 반 에서 빌려 보세요 \n']
# _
# Q:  ['먹을 시간 없어서']
# A:  ['\t 드세요 \n']
# p:  ['외로움 을 피해 그리움 을 선택 했네요 \n']
# _
# Q:  ['아침 부터 피곤해']
# A:  ['\t 좀 더 일찍 에 들어 보세요 \n']
# p:  ['가벼운 운동 하면서 기분 전환 해보세요 \n']
# _
# Q:  ['아침 에 일찍 뭔가']
# A:  ['\t 일찍 새 가 를 더 많이 \n']
# p:  ['오늘 도 고생 이 \n']
# _
# Q:  ['어떡해']
# A:  ['\t 병원 에 가야 죠 \n']
# p:  ['도 않아요 방법 을 알 아 두세요 \n']
# _
# Q:  ['로 이사 가고 싶다']
# A:  ['\t 가 살기 가 좋아요 \n']
# p:  ['좋은 곳 으로 데려다 줄 거 예요 \n']
# _
# Q:  ['안 되는데']
# A:  ['\t 가장 중요한 목표 네 요 \n']
# p:  ['운동 하기 전 준비 하세요 \n']
# _
# Q:  ['안경 말고']
# A:  ['\t 은 \n']
# p:  ['좋은 건강 습관 이에요 \n']
# _
# Q:  ['안경']
# A:  ['\t 같은 일이 네 요 \n']
# p:  ['은 \n']
# _
# Q:  ['안경']
# A:  ['\t 다른 안경 써 보세요 \n']
# p:  ['은 \n']
# _
# Q:  ['안경 니까 다른 사람']
# A:  ['\t 그런 일이 \n']
# p:  ['더 많이 좋은 생각 \n']
# _
# Q:  ['안경 안 아무 도']
# A:  ['\t 이 게 이 죠 \n']
# p:  ['더 좋은 기회 가 올 거 예요 \n']
# _
# Q:  ['안 거리 고 싶어']
# A:  ['\t 할 수 있을 때 하세요 \n']
# p:  ['공부 는 뭐 든 좋아요 \n']
# _
# Q:  ['안녕']
# A:  ['\t \n']
# p:  ['시간 이 무색 하네요 \n']
# _
# Q:  ['']
# A:  ['\t \n']
# p:  ['\n']
# _
# Q:  ['괜찮을까']
# A:  ['\t 폰 절약 되겠네요 \n']
# p:  ['괜찮을 거 예요 \n']
# _
# Q:  ['어때']
# A:  ['\t 폰 절약 되겠네요 \n']
# p:  ['\n']
# _
# Q:  ['알바 생각 보다 힘들다']
# A:  ['\t 세상 에 쉬운 일 은 없어요 \n']
# p:  ['다 잘 될 거 예요 \n']
# _
# Q:  ['알바 집 알바 집 이 게 뭐 냐']
# A:  ['\t 그래도 칭찬 해주고 싶네요 \n']
# p:  ['좋아하는 게 좋겠죠 \n']
# _
# Q:  ['알바 하고 싶어']
# A:  ['\t 하고 싶은 알바 해보세요 \n']
# p:  ['매일 가고 싶네요 \n']
# _
# Q:  ['애 들']
# A:  ['\t 가는 게 좋겠죠 \n']
# p:  ['뭐 이런 \n']
# _
# Q:  ['애 들 에 왜 나를 고']
# A:  ['\t 가는 게 좋겠죠 \n']
# p:  ['들 적 으로 바뀔 수 있어요 \n']
# _
# Q:  ['관계']
# A:  ['\t 인간 정리 가 필요해요 \n']
# p:  ['\n']
# _
# Q:  ['가고 싶어']
# A:  ['\t 다녀오세요 \n']
# p:  ['저 도 딸기 좋아해요 같이 가요 \n']
# _
# Q:  ['싶어']
# A:  ['\t 가족 들 과 상의 해보세요 \n']
# p:  ['마음 대로 할 수 있을 거 예요 \n']
# _
# Q:  ['야경 보고 싶다']
# A:  ['\t 곳 으로 가보세요 \n']
# p:  ['게임 하세요 \n']
# _
# Q:  ['']
# A:  ['\t 좋은 생각 이에요 \n']
# p:  ['\n']
# _
# Q:  ['에서 더']
# A:  ['\t 맛있게 많이 드세요 \n']
# p:  ['많이 사랑 하지 마세요 \n']
# _
# Q:  ['양말 에 난 거']
# A:  ['\t 괜찮아요 있죠 \n']
# p:  ['우리 가 많이 모르고 살 예요 \n']
# _
# Q:  ['']
# A:  ['\t 다이어트 하는 분들 진짜 엄청 분 들 이에요 \n']
# p:  ['\n']
# _
# Q:  ['최악']
# A:  ['\t 다이어트 하는 분들 진짜 엄청 분 들 이에요 \n']
# p:  ['저 도 항상 헤어진 연인 과 기분 이 \n']
# _
# Q:  ['선물 받았어']
# A:  ['\t 을 보세요 \n']
# p:  ['정말 기분 \n']
# _
# Q:  ['어떤 영화 볼까']
# A:  ['\t 영화 가 좋을 것 같아요 \n']
# p:  ['을 건 어떨까 요 \n']
# _
# Q:  ['어떻게 하면 나를 좋아하게']
# A:  ['\t 제 가 당신 을 좋아하고 있어요 \n']
# p:  ['나 에게 잘 하면 기술 이 죠 \n']
# _
# Q:  ['어떻게 해 잤어']
# A:  ['\t 봐요 \n']
# p:  ['너무 \n']
# _
# Q:  ['보이 고 싶어']
# A:  ['\t 마음 이라도 사세요 \n']
# p:  ['돈 을 모아 땅 을 사세요 \n']
# _
# Q:  ['']
# A:  ['\t 하는 게 좋겠죠 \n']
# p:  ['\n']
# _
# Q:  ['']
# A:  ['\t 봐요 \n']
# p:  ['\n']
# _
# Q:  ['언제 쯤 예쁘게 화장 잘 할까']
# A:  ['\t 하다 보면 \n']
# p:  ['하다 보면 \n']
# _
# Q:  ['얼굴 너무']
# A:  ['\t 관리 해주세요 \n']
# p:  ['관리 해주세요 \n']
# _
# Q:  ['얼굴 보 니까']
# A:  ['\t 많이 좋아했던 사람인 가봐요 \n']
# p:  ['더 좋은 사람 만날 수 있을 거 예요 \n']
# _
# Q:  ['얼굴 해']
# A:  ['\t 남 의 눈 을 하는 사람 일 거 라 생각 해요 \n']
# p:  ['모든 사랑 을 존중 합니다 \n']
# _
# Q:  ['얼굴 만 아는 사이 가 있어']
# A:  ['\t 그런 사람 들 은근 많아요 \n']
# p:  ['마음 을 할 수 있어요 \n']
# _
# Q:  ['얼른 야 할텐데']
# A:  ['\t 세상 의 무엇 보다 건강 이 제일 중요해요 \n']
# p:  ['잘 거 예요 \n']
# _
# Q:  ['얼마 전 재회 했는데']
# A:  ['\t 좋은 만남이었길 바라요 \n']
# p:  ['\n']
# _
# Q:  ['줄']
# A:  ['\t 감기 조심하세요 \n']
# p:  ['저 도 \n']
# _
# Q:  ['줄']
# A:  ['\t 감기 조심하세요 \n']
# p:  ['저 도 \n']
# _
# Q:  ['엄마 보고 싶다']
# A:  ['\t 연락 보세요 \n']
# p:  ['열심히 해서 받으세요 \n']
# _
# Q:  ['엄마 아빠 보고 싶다']
# A:  ['\t 연락 보세요 \n']
# p:  ['여행 은 이 될 거 예요 \n']
# _
# Q:  ['업무 또']
# A:  ['\t 업무 능력 이 없는 게 아니라 가 부족한 걸 수도 있어요 \n']
# p:  ['다음 달 에는 조금 줄 여보세요 \n']
# _
# Q:  ['업무 가']
# A:  ['\t 힘들겠지만 하나 씩 해보세요 \n']
# p:  ['다음 에는 우산 에 이름 이랑 연락처 를 적어 보세요 \n']
# _
# Q:  ['느낌 싫다']
# A:  ['\t 타이밍 이 안 맞았나 봐요 \n']
# p:  ['자책 하지 마세요 \n']
# _
# Q:  ['후 사고 싶다']
# A:  ['\t 몇 번 안 해 먹고 둘 거 면 그냥 사 드세요 \n']
# p:  ['\n']
# _
# Q:  ['여드름 스트레스 받아']
# A:  ['\t 스트레스 가 더 큰 적 이에요 \n']
# p:  ['크게 숨 한 번 보세요 \n']
# _
# Q:  ['여름']
# A:  ['\t 곧 \n']
# p:  ['성공 을 기원 합니다 \n']
# _
# Q:  ['여우 한테 당했어']
# A:  ['\t 못 무시 하세요 \n']
# p:  ['말 해주세요 \n']
# _
# Q:  ['살 고 싶어']
# A:  ['\t 여유 는 마음 에 있어요 \n']
# p:  ['현재 를 행복하게 사세요 \n']
# _
# Q:  ['여자 로']
# A:  ['\t 항상 못 건 \n']
# p:  ['서로 에게 좋은 사람 기적 이 죠 \n']
# _
# Q:  ['여자 예요 남자 예요']
# A:  ['\t 아직 모르겠어요 에 성별 을 만드는 사람 이 되어 주세요 \n']
# p:  ['생각 이 많이 \n']
# _
# Q:  ['여자친구 가 자꾸 게 한다']
# A:  ['\t 당신 의 사랑 이 같아요 \n']
# p:  ['봐요 \n']
# _
# Q:  ['여자친구 한테 듯']
# A:  ['\t 당신 의 사랑 이 같아요 \n']
# p:  ['당신 이 생각 을 하고 있어요 \n']
# _
# Q:  ['여친 이 맨날 욕 해']
# A:  ['\t 사람 고쳐 쓰는 거 아니에요 \n']
# p:  ['사람 고쳐 쓰는 거 아니에요 \n']
# _
# Q:  ['여친 이 너무 많이']
# A:  ['\t 잘 \n']
# p:  ['너무 않아도 돼요 \n']
# _
# Q:  ['여친 이 이유 를 아직도 모르겠어']
# A:  ['\t 모르는 사실 에 더 화가 나 있을 거 예요 \n']
# p:  ['sns \n']
# _
# Q:  ['역시 나 는 야']
# A:  ['\t 제 가 더 예요 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['역시 이불 밖 은']
# A:  ['\t 이불 밖 은 \n']
# p:  ['이불 밖 은 \n']
# _
# Q:  ['연락 많이 해도 되겠지']
# A:  ['\t 많이 하면 좋죠 \n']
# p:  ['많이 만나면 돼요 \n']
# _
# Q:  ['연락 안 오면 걱정 되네']
# A:  ['\t 더 많이 \n']
# p:  ['딱 걱정 하지 마세요 \n']
# _
# Q:  ['연락 안해 서 미안해']
# A:  ['\t 연락 은 기본 중 의 기본 이에요 \n']
# p:  ['엄마 한테 돼요 \n']
# _
# Q:  ['연락 갑자기 왜 만나자고 하지']
# A:  ['\t 이렇게 고민 하게 봐요 \n']
# p:  ['좋아하는 마음 은 힘들어요 \n']
# _
# Q:  ['연락 좀 빨리 하지']
# A:  ['\t 바쁜 가봐요 \n']
# p:  ['서로 의 마음 에 \n']
# _
# Q:  ['연애 상담']
# A:  ['\t 열심히 \n']
# p:  ['저 도 듣고 싶네요 \n']
# _
# Q:  ['연애 위기 인 거 같아']
# A:  ['\t 저 는 위기 조차 없네요 \n']
# p:  ['당신 도 좋아하는지 모르겠네요 \n']
# _
# Q:  ['연애 하고 싶어']
# A:  ['\t 잘 할 수 있을 거니 걱정 마세요 \n']
# p:  ['서로 마음 이 \n']
# _
# Q:  ['연예인 도 있겠지']
# A:  ['\t 아무래도 이 요 \n']
# p:  ['많이 저 에게 해보세요 \n']
# _
# Q:  ['연예인 도 힘들겠지']
# A:  ['\t 연예인 걱정 이 제일 \n']
# p:  ['자신 의 능력 을 믿어 보세요 \n']
# _
# Q:  ['열심히 한 거 같은데 결과 가 왜 이러지']
# A:  ['\t 다음 에는 잘 될 거 예요 \n']
# p:  ['차단 받을 것 도 좋을 거 예요 \n']
# _
# Q:  ['잘 했으면 좋겠다']
# A:  ['\t 매일 조금씩 해보세요 \n']
# p:  ['기대 가 을 하죠 \n']
# _
# Q:  ['알바 하고 싶다']
# A:  ['\t 영화 를 많이 볼 수 있어서 좋을 것 같아요 \n']
# p:  ['맛 나게 드세요 \n']
# _
# Q:  ['알바 하면 좋겠다']
# A:  ['\t 영화 를 많이 볼 수 있어서 좋을 것 같아요 \n']
# p:  ['적 인 소비 를 많이 봐요 \n']
# _
# Q:  ['옆 에 있는 사람 한테 너무 같아']
# A:  ['\t 옆 사람 에게 잘 해주세요 \n']
# p:  ['그 사람 을 위해 에너지 를 요 \n']
# _
# Q:  ['예쁜 카페 볼까']
# A:  ['\t 카페 데이트 좋죠 \n']
# p:  ['받고 충격 받지 마세요 \n']
# _
# Q:  ['예의 지는']
# A:  ['\t 오는 말 이 고 가는 말 도 말 해주세요 \n']
# p:  ['연락 은 을 \n']
# _
# Q:  ['에는']
# A:  ['\t 중요한 건 지금 이 죠 \n']
# p:  ['밤 에는 \n']
# _
# Q:  ['오늘 그냥 쉬 고 싶다']
# A:  ['\t 아무 생각 하지 말고 쉬세요 \n']
# p:  ['아무 생각 하지 말고 쉬세요 \n']
# _
# Q:  ['오늘 나 좀']
# A:  ['\t 자신 에게 콩깍지 가 요 \n']
# p:  ['그럴 수 있어요 \n']
# _
# Q:  ['오늘 날씨 놀러 가고 싶어']
# A:  ['\t 친구 들 과 같이 놀러 가세 요 \n']
# p:  ['갈 때 저 도 같이 가요 \n']
# _
# Q:  ['오늘 너무 졸려']
# A:  ['\t 오늘 일찍 주무 세 요 \n']
# p:  ['을 잠깐 괜찮아요 \n']
# _
# Q:  ['오늘 생각 보다']
# A:  ['\t 감기 조심하세요 \n']
# p:  ['그럴 수 있을 거 예요 \n']
# _
# Q:  ['오늘 아무 것 도 안 가져 왔다']
# A:  ['\t 만 돼요 \n']
# p:  ['만 돼요 \n']
# _
# Q:  ['오늘 운 이 이다']
# A:  ['\t 다른 곳 에 운 을 봐요 \n']
# p:  ['를 \n']
# _
# Q:  ['오늘 운 이 안']
# A:  ['\t 다른 곳 에 운 을 봐요 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['오늘 저녁 은']
# A:  ['\t 맛있는 거 드세요 \n']
# p:  ['예쁘게 오세요 \n']
# _
# Q:  ['오늘 은']
# A:  ['\t 맛있는 거 드세요 \n']
# p:  ['그럴 수 있을 거 예요 \n']
# _
# Q:  ['오늘 좀']
# A:  ['\t 힘내세요 \n']
# p:  ['많이 만나 보세요 \n']
# _
# Q:  ['오늘 밖 으로 안 지']
# A:  ['\t 와 한 몸 이 되어 푹 쉬세요 \n']
# p:  ['고민 이 있나 봐요 \n']
# _
# Q:  ['오늘 하루 도 이렇게 마무리']
# A:  ['\t 내일 의 시작 이 죠 \n']
# p:  ['현실 을 꿈 처럼 만들어 봐요 \n']
# _
# Q:  ['오늘 좋다']
# A:  ['\t 추천 합니다 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['오늘 회식 안 하나']
# A:  ['\t 드세요 \n']
# p:  ['가 많이 \n']
# _
# Q:  ['오늘 도 가']
# A:  ['\t 마스크 하세요 \n']
# p:  ['감기 조심하세요 \n']
# _
# Q:  ['오늘이 네']
# A:  ['\t 축하 합니다 \n']
# p:  ['다른 일 가 되겠네요 \n']
# _
# Q:  ['오래 살아야 할텐데']
# A:  ['\t 스트레스 받지 마세요 \n']
# p:  ['잘 하고 있어요 \n']
# _
# Q:  ['오랜 만 에 좋았는데']
# A:  ['\t 감정 은 그 자체 로 \n']
# p:  ['사랑 의 시작 \n']
# _
# Q:  ['오랜 만 에 쇼핑']
# A:  ['\t 바라요 \n']
# p:  ['마음 의 안정 을 기 좋은 취미 네 요 \n']
# _
# Q:  ['타고 싶다']
# A:  ['\t 것 같아요 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['했는데 왜 안 오지']
# A:  ['\t 조금 만 더 \n']
# p:  ['기다리는 전화 죠 \n']
# _
# Q:  ['옷 걸 데 가 없어']
# A:  ['\t 지난 계절 옷 을 잘 정리 해 보세요 \n']
# p:  ['제 가 곁 에 \n']
# _
# Q:  ['옷 사 줘']
# A:  ['\t 아직 월급 날 이 \n']
# p:  ['잘 거 예요 \n']
# _
# Q:  ['옷 좀']
# A:  ['\t 아직 월급 날 이 \n']
# p:  ['좋은 거 예요 \n']
# _
# Q:  ['옷 이 다']
# A:  ['\t 감기 조심 하세요 \n']
# p:  ['를 해보세요 \n']
# _
# Q:  ['와 다']
# A:  ['\t 확인 해보세요 \n']
# p:  ['즐거운 \n']
# _
# Q:  ['사고 싶다']
# A:  ['\t 몇 번 안 해 먹고 둘 거 면 그냥 사 드세요 \n']
# p:  ['열심히 해서 받으세요 \n']
# _
# Q:  ['좀 하고 싶다']
# A:  ['\t 완벽한 사람 은 수도 없어요 \n']
# p:  ['지금 도 충분히 \n']
# _
# Q:  ['완전 느낌']
# A:  ['\t 축하 해요 \n']
# p:  ['깊은 곳 까지 \n']
# _
# Q:  ['완전 재미']
# A:  ['\t 웃 을 때 까지 이야기 해 \n']
# p:  ['깊은 사람 \n']
# _
# Q:  ['완전 이다']
# A:  ['\t 이제 때 예요 \n']
# p:  ['잘 \n']
# _
# Q:  ['인가 봄']
# A:  ['\t 친구 들 과 잘 보세요 \n']
# p:  ['봄 은 하죠 \n']
# _
# Q:  ['왜 공부 모르겠어']
# A:  ['\t 미래 의 가 \n']
# p:  ['저 도 요 \n']
# _
# Q:  ['왜 모르겠어']
# A:  ['\t 조금 더 생각 해 보세요 \n']
# p:  ['잘 찾아보세요 \n']
# _
# Q:  ['왜 에서']
# A:  ['\t 하는 곳 이 있을 거 예요 \n']
# p:  ['서로 에게 좋은 적 인 선물 이 될 거 예요 \n']
# _
# Q:  ['왜 성적 이 안']
# A:  ['\t 나 한테 맞는 공부 방법 게 \n']
# p:  ['아직 일이 그럴 수도 있어요 \n']
# _
# Q:  ['왜 이렇게']
# A:  ['\t 친구 를 보세요 \n']
# p:  ['서로 태어난 이유 는 저 목소리 를 위 자신 의 목소리 를 \n']
# _
# Q:  ['왜 이제 까']
# A:  ['\t 이렇게 고민 하게 봐요 \n']
# p:  ['마지막 이 힘들 거 예요 \n']
# _
# Q:  ['왜 이제 연락']
# A:  ['\t 이렇게 고민 하게 봐요 \n']
# p:  ['이렇게 고민 하게 봐요 \n']
# _
# Q:  ['왜 진급 이 안 되지']
# A:  ['\t 열심히 하면 할 수 있을 거 예요 \n']
# p:  ['미련 이 안 나 나 나 의 이 되어 나 하는 건 어떨까 요 \n']
# _
# Q:  ['타고 싶어']
# A:  ['\t 저 도 타고 싶어요 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['요즘 너무']
# A:  ['\t 마음 에 따라 얼마 바뀔 수 있어요 \n']
# p:  ['좋은 생각 많이 하세요 \n']
# _
# Q:  ['요즘 되는 일이 없네']
# A:  ['\t 이제 부터 일이 잘 풀릴 거 예요 \n']
# p:  ['저 도 커피 좋아해요 \n']
# _
# Q:  ['요즘 웃 을 일이 없네']
# A:  ['\t 억지로 라도 웃어 보세요 \n']
# p:  ['저 도 \n']
# _
# Q:  ['요즘 잠 을']
# A:  ['\t 잠 이 최고 의 이에요 노력 해보세요 \n']
# p:  ['잠 은 정말 \n']
# _
# Q:  ['요즘 제 정신 이 아니야']
# A:  ['\t 그럴 때 가 있죠 \n']
# p:  ['요즘 은 잘 안 배우는 도 좋은 거 같아요 \n']
# _
# Q:  ['요즘 게 많아']
# A:  ['\t 무서운 세 죠 \n']
# p:  ['얼른 새 출발 하세요 \n']
# _
# Q:  ['용돈 달라 고 볼까']
# A:  ['\t \n']
# p:  ['말 해보세요 \n']
# _
# Q:  ['용돈 벌써 다']
# A:  ['\t 올려 달라 고 말 해보세요 \n']
# p:  ['알바 해보세요 \n']
# _
# Q:  ['용돈']
# A:  ['\t 올려 달라 고 말 해보세요 \n']
# p:  ['기분 좋겠어요 \n']
# _
# Q:  ['우리 집 거 같은데 나 어떡하지']
# A:  ['\t 집 에 도움 이 노력 해보세요 \n']
# p:  ['대화 를 많이 \n']
# _
# Q:  ['우산 놓고 왔다']
# A:  ['\t 다음 에는 우산 에 이름 이랑 연락처 를 적어 보세요 \n']
# p:  ['저 한테 말 해보세요 \n']
# _
# Q:  ['우산 또 왔다']
# A:  ['\t 주변 에서 우산 을 빌려 보세요 \n']
# p:  ['빌려 보세요 \n']
# _
# Q:  ['운명 이 됐어']
# A:  ['\t 멋진 \n']
# p:  ['사랑 의 예의 가 없네요 \n']
# _
# Q:  ['이란 게 뭘 까']
# A:  ['\t 힘들 때 같이 있는 거 요 \n']
# p:  ['힘들 때 같이 있는 거 요 \n']
# _
# Q:  ['운동 매일 하기 힘들다']
# A:  ['\t 제일 힘들어요 습관 으로 만들어 보세요 \n']
# p:  ['연예인 을 준비 하니 보다 다 \n']
# _
# Q:  ['운동 을 너무 열심히 했어']
# A:  ['\t 고생 했어요 \n']
# p:  ['잘 할 수 있을 거 예요 \n']
# _
# Q:  ['운동 해도 살이 안']
# A:  ['\t 이랑 같이 해보세요 \n']
# p:  ['소 서 에 가서 잘 해봐요 \n']
# _
# Q:  ['가 나을까 가 나을까']
# A:  ['\t 로 을 내 보세요 \n']
# p:  ['준비 하는 게 좋을 거 예요 \n']
# _
# Q:  ['운명 인가']
# A:  ['\t 인연 인가 봐요 \n']
# p:  ['좋은 운명 도 있을거예요 \n']
# _
# Q:  ['만드는 너']
# A:  ['\t 상대방 도 해주세요 \n']
# p:  ['계속 마세요 \n']
# _
# Q:  ['']
# A:  ['\t 복 이 \n']
# p:  ['\n']
# _
# Q:  ['원래 일 은 배우는 거야']
# A:  ['\t 그냥 돼요 \n']
# p:  ['마음 의 정리 가 \n']
# _
# Q:  ['']
# A:  ['\t 너무 \n']
# p:  ['\n']
# _
# Q:  ['월급']
# A:  ['\t 축하 합니다 \n']
# p:  ['축하 해요 \n']
# _
# Q:  ['월급 이 안 들어와']
# A:  ['\t 큰일 이네 요 \n']
# p:  ['가 기본 인데 요 \n']
# _
# Q:  ['']
# A:  ['\t 돈 을 얼른 모아 야할 이유 가 \n']
# p:  ['\n']
# _
# Q:  ['너무']
# A:  ['\t 친구 가 잘 못 봐요 \n']
# p:  ['자신 에게 좀 더 여유 로 요 \n']
# _
# Q:  ['뭐 볼까']
# A:  ['\t 안 이 있는지 먼저 \n']
# p:  ['오늘 은 이 요 \n']
# _
# Q:  ['위로 해줄 사람 이 없어']
# A:  ['\t 제 가 있잖아요 \n']
# p:  ['제 가 있잖아요 \n']
# _
# Q:  ['난 거 같아']
# A:  ['\t 스트레스 받는 일이 봅니다 \n']
# p:  ['\n']
# _
# Q:  ['너무']
# A:  ['\t 를 가지 고 을 하세요 \n']
# p:  ['자신 에게 좀 더 여유 로 요 \n']
# _
# Q:  ['음']
# A:  ['\t 음 \n']
# p:  ['잘 좋겠네요 \n']
# _
# Q:  ['괜찮은 사람 이네']
# A:  ['\t 칭찬 이네 요 \n']
# p:  ['사람 이 가장 말 이 죠 \n']
# _
# Q:  ['야']
# A:  ['\t 칭찬 이네 요 \n']
# p:  ['네 \n']
# _
# Q:  ['인 점 이 많은 사람 이야']
# A:  ['\t 칭찬 이네 요 \n']
# p:  ['\n']
# _
# Q:  ['의욕 이 안']
# A:  ['\t 하고 싶은 걸 찾아보세요 \n']
# p:  ['얼른 보아 요 \n']
# _
# Q:  ['가 불편해']
# A:  ['\t 를 바꿔 보세요 \n']
# p:  ['를 바꿔 보세요 \n']
# _
# Q:  ['이 길이 나 에게 맞는걸 까']
# A:  ['\t 잘 가고 있을 거 예요 \n']
# p:  ['사람 마음 은 알다가도 봐요 \n']
# _
# Q:  ['이 바보 이']
# A:  ['\t 좋은 말 만 해주세요 \n']
# p:  ['\n']
# _
# Q:  ['이 걸 로']
# A:  ['\t 내 가 있는 곳 그 자리 에서 것 이 중요해요 \n']
# p:  ['서로 에게 좋은 말 이 \n']
# _
# Q:  ['이 에서']
# A:  ['\t 약 챙겨 치과 가보세요 \n']
# p:  ['\n']
# _
# Q:  ['커피 자고']
# A:  ['\t 잘 될 거 예요 \n']
# p:  ['그게 최고 죠 \n']
# _
# Q:  ['있을 때 가 아니야']
# A:  ['\t 행동 할 때 인 것 같네요 응원 해요 \n']
# p:  ['마음 의 준비 를 하세요 \n']
# _
# Q:  ['이런 일상 에서 싶어']
# ...
# p:  ['작은 것 같네요 \n']
# _
# Q:  ['인연 이 있다고 생각 해']
# A:  ['\t 저 랑 당신 도 인연 이 죠 \n']
# p:  ['인연 은 있어요 \n']
# _
# Q:  ['데이트 어떨까']
# A:  ['\t 로맨틱 할 것 같아요 \n']
# p:  ['잘 될 거 예요 \n']
# _
# Q:  ['잘 만나고 있는데 나 어쩌지 걱정 이야']
# A:  ['\t 을 연습 하 거나 미리 걱정 할 필요 없어요 \n']
# p:  ['말 기분 이 \n']
# _
# Q:  ['잘 먹는 여자 가 좋아']
# A:  ['\t 복 스럽게 먹으면 더 좋죠 \n']
# p:  ['저 도 부러워요 \n']
# _
# Q:  ['잘 더 래']
# A:  ['\t 를 로 아는 사람 만나지 마세요 \n']
# p:  ['조금 더 기다려 보세요 \n']
# _
# Q:  ['잠 안 불러 줬어']
# A:  ['\t 로맨틱 하네요 \n']
# p:  ['다시 해 요 \n']
# _
# Q:  ['장거리 썸 고백 해도 될까']
# A:  ['\t 많이 만나 보는 게 좋겠지만 연락 을 더 자주 해보세요 \n']
# p:  ['상대방 이 부담 을 생각 해보세요 \n']
# _
# Q:  ['고백 받았어']
# A:  ['\t 그럴 수도 있어요 \n']
# p:  ['썸 으로 연인 으로 좋을 것 같아요 \n']
# _
# Q:  ['저 를 좋아하는 사람 은 없을 거 예요']
# A:  ['\t 그건 절대 아닐 거 예요 \n']
# p:  ['달라지는 게 없어도 말아요 이별 앞 에 사람 을 더 힘들게 할 거 예요 \n']
# _
# Q:  ['저 를 좋아하는 사람 한테 호감 이 안']
# A:  ['\t 맘 처럼 할 수 없는 부분 같아요 \n']
# p:  ['감정 에 확신 이 있다면 연락 해보세요 \n']
# _
# Q:  ['저 한 테 만 장난 남자 애가 나 좋아하나']
# A:  ['\t 호감 이 모르겠어요 \n']
# p:  ['sns \n']
# _
# Q:  ['전여친 하고 짝녀 가 친구 야']
# A:  ['\t 신경 상황 같아요 \n']
# p:  ['다른 사람 들 을 못 한 사람 은 행복 은 좋을 거 예요 \n']
# _
# Q:  ['정말 잘 맞는 사람 이 있을까']
# A:  ['\t 잘 사람 이 있는 거 겠죠 \n']
# p:  ['당신 은 정말 멋진 사람 이에요 아 내 마세요 \n']
# _
# Q:  ['한 벌']
# A:  ['\t 잘 했어요 \n']
# p:  ['조금 만 하세요 \n']
# _
# Q:  ['제대로 사랑 하고싶어']
# A:  ['\t 사랑 에는 이 같아요 \n']
# p:  ['사랑 은 누구 나 해 요 \n']
# _
# Q:  ['종교 가 다른 여자친구']
# A:  ['\t 종교 큰 문제 죠 \n']
# p:  ['인연 이 거기 까지 였나 봐요 \n']
# _
# Q:  ['좋아하게 된 남자 가 있는데 많이 수 있을까']
# A:  ['\t 충분히 수 있어요 \n']
# p:  ['다른 사람 들 을 위 한 의 일 거 예요 \n']
# _
# Q:  ['좋아하는 거 랑 사랑 하는게 다른 거야']
# A:  ['\t 마음 에 것 같습니다 \n']
# p:  ['생각 의 \n']
# _
# Q:  ['좋아하는 걸 알 게 되면 갑자기 무슨 심리 일까 요']
# A:  ['\t 심리 일까 요 \n']
# p:  ['사랑 을 하는 건 없어요 \n']
# _
# Q:  ['좋아하는 그 사람 은 야 좋아해도 될까']
# A:  ['\t 상처 받을 거 예요 \n']
# p:  ['누구 나 좋아할 가 있어요 \n']
# _
# Q:  ['좋아하는 남자 애 생겼는데 완전 설레']
# A:  ['\t 길이 \n']
# p:  ['\n']
# _
# Q:  ['좋아하는 남자 애가 게임 을 좋아하는데 이야기 오래 가는 좀 알려줘']
# A:  ['\t 요즘 인기 있는 게임 을 해봐요 \n']
# p:  ['고백 할 타이밍 을 받아 \n']
# _
# Q:  ['좋아하는 남자 애 랑 같은 반 이 됐는데 너무 떨려']
# A:  ['\t 정말 잘 됐어요 \n']
# p:  ['충분히 해 요 \n']
# _
# Q:  ['좋아하는 남자 애 한테 어떻게 관심 표현 함']
# A:  ['\t 칭찬 을 자주 해주는 건 어떨까 요 \n']
# p:  ['진심 으로 대하 고 싶다고 말 해보세요 \n']
# _
# Q:  ['좋아하는 남자 한테 연락 하지 말 자고 했는데']
# A:  ['\t 확실한 의사 표현 이 중요해요 \n']
# p:  ['한 말 하기 좋은 연애 \n']
# _
# Q:  ['좋아하는 가 날 너무 애 함']
# A:  ['\t 가 걸 어필 해봐요 \n']
# p:  ['그건 습관 이에요 \n']
# _
# Q:  ['좋아하는 마음 짝남 이 헷갈리게 해']
# A:  ['\t 확실한 의사 를 해보는 건 어떨까 요 \n']
# p:  ['부담 스럽지 않은 선 이 좋겠어요 \n']
# _
# Q:  ['좋아하는 마음 을 길이 없어']
# A:  ['\t 감정 을 어려운 일이 에요 \n']
# p:  ['계속 마세요 \n']
# _
# Q:  ['좋아하는 마음 이 안 생길 것 떠난 남자']
# A:  ['\t 이제 그 \n']
# p:  ['그렇게 잊어 가는 거 예요 \n']
# _
# Q:  ['좋아하는 마음 이 안 생길 것 떠난 여자']
# A:  ['\t 이제 그녀 를 놓아주세요 \n']
# p:  ['\n']
# _
# Q:  ['좋아하는 사람 앞 에서 를 했어']
# A:  ['\t 생각 만해 도 \n']
# p:  ['를 만날 수 있을 거 예요 \n']
# _
# Q:  ['좋아하는 사람 이상형 에 나를 할까']
# A:  ['\t 맞춰 보는 과정 이 수도 있겠어요 \n']
# p:  ['사람 마다 너무 다를 것 같아요 \n']
# _
# Q:  ['좋아하는 사람 있는데 내 가 좀']
# A:  ['\t 할 수 있을 거 예요 \n']
# p:  ['관심사 를 찾아보세요 \n']
# _
# Q:  ['좋아하는 사람 에 대한 예의 가 없는 것 같아']
# A:  ['\t 예의 없는 사람 마세요 \n']
# p:  ['만남 에 무슨 문제 가 \n']
# _
# Q:  ['좋아하는 사람 에 대해 착각 게 되는 내 자신 이 싫어']
# A:  ['\t 짝사랑 앞 에 판단 이 마련 이에요 \n']
# p:  ['짝사랑 이 을 \n']
# _
# Q:  ['좋아하는 사람 을 될 것 같아']
# A:  ['\t 원망 은 아픔 만 뿐 이에요 버리세요 \n']
# p:  ['적극 적 으로 요 \n']
# _
# Q:  ['좋아하는 사람 이 거짓말 을 하면']
# A:  ['\t 속 는 것 도 사랑 이 죠 \n']
# p:  ['편하게 수 있을 거 예요 \n']
# _
# Q:  ['좋아하는 사람 이 나 한테 먼저 연락 하는 방법']
# A:  ['\t 그 분 이 관심 갈 만 한 일 을 해보는 건 어떨까 요 \n']
# p:  ['직접 물어보는 건 \n']
# _
# Q:  ['좋아하는 사람 이 너무']
# A:  ['\t 좋아하는 마음 을 표현 하기 더 힘들겠어요 \n']
# p:  ['자신 이 때문 이 겠죠 \n']
# _
# Q:  ['좋아하는 사람 이 너무 예뻐']
# A:  ['\t 을 더 \n']
# p:  ['마음 이 뿐 살 수 있어요 \n']
# _
# Q:  ['좋아하는 사람 이 다른 여자 얘기 하는게 너무 가슴']
# A:  ['\t 마음 을 \n']
# p:  ['좀 더 \n']
# _
# Q:  ['좋아하는 사람 이 이 있는 걸 부담스러워 해 요']
# A:  ['\t 은 친구 들 과 함께 만나는게 좋겠어요 \n']
# p:  ['사랑 은 하는 거 예요 \n']
# _
# Q:  ['좋아하는 사람 이 말 한 이상형 이랑 나 랑 너무']
# A:  ['\t 이상형 은 이상형 수도 있어요 \n']
# p:  ['누구 나 그럴 거 예요 \n']
# _
# Q:  ['좋아하는 사람 이 쓰레기 면 어떻게']
# A:  ['\t 쓰레기 옆 에 거 예요 \n']
# p:  ['당신 에게 물어보세요 \n']
# _
# Q:  ['좋아하는 사람 이 인기 가 많은데 남친 이 없어']
# A:  ['\t 본인 이 그럴 수도 있어요 \n']
# p:  ['혼자 가 있는지 \n']
# _
# Q:  ['좋아하는 사람 이 있는데 고백 하는 건']
# A:  ['\t 되기 싫은 건지 생각 해보세요 \n']
# p:  ['수도 있고 혼자 만 썸일 수도 있겠어요 \n']
# _
# Q:  ['좋아하는 사람 이 있는데 관계 에 이 없어']
# A:  ['\t 한 발 을 변화 가 필요 \n']
# p:  ['무슨 일이 있었나 봐요 \n']
# _
# Q:  ['좋아하는 사람 이 있는데 이']
# A:  ['\t 천천히 말씀 해보세요 \n']
# p:  ['직접 물어보는 게 좋을 것 같아요 \n']
# _
# Q:  ['좋아하는 사람 이 있는데 종교 가 달라']
# A:  ['\t 종교 가 큰 문제 가 되 기도 하죠 \n']
# p:  ['정말 나쁜 사람 이네 요 \n']
# _
# Q:  ['좋아하는 사람 이 좋아하는 것 들 되는데 인가']
# A:  ['\t 이에요 \n']
# p:  ['다른 생각 을 해보세요 \n']
# _
# Q:  ['좋아하는 사람 이 행동 하는 모든 게 좋아']
# A:  ['\t 사랑 의 콩깍지 가 요 \n']
# p:  ['감정 의 변화 가 모르겠어요 \n']
# _
# Q:  ['좋아하는 사람 이랑 같은 반']
# A:  ['\t 기도 할게요 \n']
# p:  ['저 도 \n']
# _
# Q:  ['좋아하는 사람 이랑 친구']
# A:  ['\t 그건 좀 힘들 것 같아요 \n']
# p:  ['이야기 도 잘 몰라요 \n']
# _
# Q:  ['좋아하는 사람 한테 내 가 자꾸 걸 귀찮아 할까']
# A:  ['\t 정말 답장 하지 않을 거 예요 \n']
# p:  ['사람 마다 행복 을 하고 있어요 \n']
# _
# Q:  ['좋아하는 사람 한테 선톡 하 려고 하는데']
# A:  ['\t 먼저 태도 좋아요 \n']
# p:  ['계속 마세요 \n']
# _
# Q:  ['좋아하는 애 없으면 포기 하는게']
# A:  ['\t 이 없다면 정리 하는게 덜 거 예요 \n']
# p:  ['좋아하는 감정 은 한 만 그럴 때 요 \n']
# _
# Q:  ['좋아하는 애 피하 는 방법 조언 좀']
# A:  ['\t 을 어느 정도 하는게 도움 이 \n']
# p:  ['질투 를 해 보는 방법 도 있다고 합니다 \n']
# _
# Q:  ['좋아하는 애 피하 는']
# A:  ['\t 마음 을 정리 봐요 \n']
# p:  ['충분한 대화 가 \n']
# _
# Q:  ['좋아하는 애 피 우울해']
# A:  ['\t 못 하는 \n']
# p:  ['사실 을 힘들어요 \n']
# _
# Q:  ['좋아하는 애 랑 같은 반 됐어']
# A:  ['\t 축하 해요 \n']
# p:  ['그런 사람 바랄게요 \n']
# _
# Q:  ['좋아하는 애 랑 된 가 많은데']
# A:  ['\t 는 일 뿐 이에요 \n']
# p:  ['저 는 생각 이 저 는 이 없어요 \n']
# _
# Q:  ['좋아하는 애 랑 영화 은 좀']
# A:  ['\t 좋아하는 가 뭔 지 하세요 \n']
# p:  ['마음 을 주세요 \n']
# _
# Q:  ['좋아하는 애 한테 하고 싶은 말 이 뭐 야']
# A:  ['\t 나를 좋아해 줬으면 좋겠어 \n']
# p:  ['사람 마다 \n']
# _
# Q:  ['좋아하는 여 선배 가 있는데 말 할 수도']
# A:  ['\t 왜 말 을 못 해요 \n']
# p:  ['당황 \n']
# _
# Q:  ['좋아하는 여자 가 다른 남자 랑']
# A:  ['\t 충분히 신경 부분 이에요 \n']
# p:  ['많이 생각 해요 \n']
# _
# Q:  ['좋아하는 여자 가 때 까지 결국 가능할까 요']
# A:  ['\t 좋아하는 마음 이 있으면 \n']
# p:  ['자신 을 사랑 할수록 의 인정 은 필요 없어요 \n']
# _
# Q:  ['좋아하는 여자애 생각 하느라 성적 이']
# A:  ['\t 좋아하는 마음 때문 에 공부 안 한 당신 때문 이에요 \n']
# p:  ['서로 의 가치관 에 따라 \n']
# _
# Q:  ['좋아하는 여자애 생겼는데 떨려']
# A:  ['\t 더 힘들 때 네 요 \n']
# p:  ['좋아하나 봐요 \n']
# _
# Q:  ['좋아하는 여자애 가 우리 형 을 나']
# A:  ['\t 천천히 마음 을 정리 하는게 좋겠네요 \n']
# p:  ['sns 다시 연락 하는게 서로 에게 처음 을 확인 해보세요 \n']
# _
# Q:  ['좋아하는 여자애 한테 줘도 돼']
# A:  ['\t 만큼 이 선물 도 없을 거 예요 \n']
# p:  ['\n']
# _
# Q:  ['좋아하는 여자 에 프사 가']
# A:  ['\t 신경 봐요 \n']
# p:  ['생각 을 해도 군침 이 도 네 요 \n']
# _
# Q:  ['좋아하는 여자 한테 관심 없는 척 하고 있어']
# A:  ['\t 표현 하기 봐요 \n']
# p:  ['그 사람 을 위 하는 거 라고 생각 해요 \n']
# _
# Q:  ['좋아하는 여자 한테 선물 해도 괜찮을까']
# A:  ['\t 좋아할 거 예요 \n']
# p:  ['받는 사람 은 정말 좋겠어요 \n']
# _
# Q:  ['좋아하는 여자 한테 연락 하지 말 자고 했는데 후회 해']
# A:  ['\t 그게 최선 의 선택 이었을 거 예요 \n']
# p:  ['감정 에 확신 이 있다면 연락 해보세요 \n']
# _
# Q:  ['좋아하는 오빠 가 날 봐']
# A:  ['\t 오빠 동생 사이 로 기간 이 있으면 그럴 수 있어요 \n']
# p:  ['다 알 고 있을 거 예요 \n']
# _
# Q:  ['좋아하는데 시간 이 보통 어떻게 돼요']
# A:  ['\t 가 수도 있고 평생 이 수도 있어요 \n']
# p:  ['상대 를 위 한 선택 가 \n']
# _
# Q:  ['좋아하는지 확신 이 안 들어']
# A:  ['\t 그 분 이 다른 사람과 함께 있는 상황 을 생각 해봐요 느낌 이 올 거 예요 \n']
# p:  ['좀 \n']
# _
# Q:  ['더 게 사랑 인가']
# A:  ['\t 사랑 은 사람 마다 가 다를 거 예요 \n']
# p:  ['감정 이 그 자체 만으로 것 \n']
# _
# Q:  ['않는데 계속 연락 하고']
# A:  ['\t 가벼운 로 생각 할 수도 있죠 \n']
# p:  ['연락 하고 나면 더 힘들 거 예요 \n']
# _
# Q:  ['좋아했던 사람 도 금방 잊을 수 있을까']
# A:  ['\t 아무래도 시간 이 \n']
# p:  ['시간 은 상대 \n']
# _
# Q:  ['고백 은 못 하겠어']
# A:  ['\t 사랑 이네 요 \n']
# p:  ['고백 도 용기 가 필요해요 \n']
# _
# Q:  ['주변 에서 제 가 그녀 를 좋아하는 거 라는 데']
# A:  ['\t 좋아하는 감정 을 수 있어요 \n']
# p:  ['감정 이 그 분 에게도 거 예요 \n']
# _
# Q:  ['연애 가 것 같아']
# A:  ['\t 좋은 소 네 요 \n']
# p:  ['나를 사랑 하지 않는 사람 하고 계속 가는 건 나 자신 을 사랑 하지 않는 사람 들 이나 하는 일이 에요 \n']
# _
# Q:  ['지금 남친 을 별로 안 좋아하는 것 같은데']
# A:  ['\t 정리 를 하는게 좋겠어요 \n']
# p:  ['노력 하고 있는 중 입니다 \n']
# _
# Q:  ['지금 사귀고 있는 사람 이랑 결혼 하고 싶어']
# A:  ['\t 같이 살 자고 프로포즈 해보세요 \n']
# p:  ['연락 할 핑계 를 찾아보세요 \n']
# _
# Q:  ['진심 으로 좋아하는 애가']
# A:  ['\t 좋은 사람 이 생길 거 예요 \n']
# p:  ['거 예요 \n']
# _
# Q:  ['진짜 나를 좋아하는 남자 랑 사귈 걸']
# A:  ['\t 어떤 선택 이든 후회 가 마련 이에요 \n']
# p:  ['이제 최선 의 여자 를 만날 예요 \n']
# _
# Q:  ['짝남 못']
# A:  ['\t 완전히 잊을 순 새로운 사랑 으로 수도 있어요 \n']
# p:  ['다른 사람 들 이 별로 도 말 하는 이유 를 생각 해보세요 \n']
# _
# Q:  ['짝남 갈']
# A:  ['\t 많이 실수 하지 말고 잘 \n']
# p:  ['기분 이 \n']
# _
# Q:  ['짝남 여친 있는지 어떻게']
# A:  ['\t 된 친구 한테 물어보세요 \n']
# p:  ['서로 배려 하고 대화 하는 게 중요한 것 같아요 \n']
# _
# Q:  ['짝남 과 자연 스럽게 수 있는 방법 있을까']
# A:  ['\t 관심사 를 찾아보세요 \n']
# p:  ['거리 를 두세요 \n']
# _
# Q:  ['짝남 보다 더 나은 사람 은']
# A:  ['\t 더 나은 사람 많아요 \n']
# p:  ['매력 만큼 그런 사람 이네 요 \n']
# _
# Q:  ['짝남 이 갑자기 못 나']
# A:  ['\t 어떤 가 거 예요 \n']
# p:  ['sns \n']
# _
# Q:  ['짝남 이 날 신경 쓰는 것 같은 건 내 착각 일까']
# A:  ['\t 좀 더 것 도 좋겠어요 \n']
# p:  ['이상형 이 수도 있어요 \n']
# _
# Q:  ['짝남 이 날 좋아하게 할 방법 이 있을까']
# A:  ['\t 우선 꾸준히 연락 하고 잘 해줘 보세요 \n']
# p:  ['질투 를 연락 해보세요 \n']
# _
# Q:  ['짝남 이 내 친구 좋아하는 현실 어떻게']
# A:  ['\t 가슴 인정 순간 이네 요 \n']
# p:  ['너무 마세요 \n']
# _
# Q:  ['짝남 이 내 가 1 도']
# A:  ['\t 1 은 알 게 해야죠 \n']
# p:  ['나 사람 만나세요 \n']
# _
# Q:  ['짝남 이 너무 인기 가 많아서 같아 두려워']
# A:  ['\t 얼른 적극 적 으로 \n']
# p:  ['병원 에 연락 하고 관심 을 확인 해보세요 \n']
# _
# Q:  ['짝남 이 너무 좋은데 가 별로 야']
# A:  ['\t 은 사귀고 나서 돼요 \n']
# p:  ['직접 적 으로 물어보는게 좋겠어요 \n']
# _
# Q:  ['짝남 이 연락 이 안 되는데 자고 있는 걸까']
# A:  ['\t 자고 몰라요 \n']
# p:  ['상대방 을 헷갈리게 하는건 좋지 않아요 \n']
# _
# Q:  ['짝남 이 인데 연락 하면 귀찮아 할까']
# A:  ['\t 가 되지 않는 시간 에 보내 보세요 \n']
# p:  ['연락 은 싸움 의 이 죠 \n']
# _
# Q:  ['짝남 이 있는데 나 는 이 안 돼 연애 를 안 하는게 맞는걸 까']
# A:  ['\t 이 뭔 지 좋아하는 건 괜찮아요 \n']
# p:  ['다른 사람 들 이 별로 라고 말 하는 이유 를 생각 해보세요 \n']
# _
# Q:  ['짝남 이 졸업 하는데 뭘 주면 인상']
# A:  ['\t 부담 스럽지 않는 선물 을 생각 해보세요 \n']
# p:  ['좋아하는 마음 이 라면 연락 해보세요 \n']
# _
# Q:  ['짝남 이 했던 노래 이 새벽 에 참 어울리는 노래 야']
# A:  ['\t 분위기 있는 노래 인가 봐요 \n']
# p:  ['자신 과 대화 하는 시간 이 필요하죠 \n']
# _
# Q:  ['짝남 이랑 같이 도서관 가고 싶어 방법 좀']
# A:  ['\t 공부 도 와 달라 고 해보세요 \n']
# p:  ['같이 가는 여행 도 좋지만 혼자 여행 도 좋을 거 예요 \n']
# _
# Q:  ['짝남 이랑 동생 이름 이']
# A:  ['\t \n']
# p:  ['다 괜찮아질 거 예요 \n']
# _
# Q:  ['짝남 이랑 술 기분 만 더']
# A:  ['\t 항상 후회 만 남 나 봐요 \n']
# p:  ['회사 는 스트레스 의 이 죠 \n']
# _
# Q:  ['짝남 이랑 아직 덜 오늘 아무 말 대 함']
# A:  ['\t 시간 \n']
# p:  ['혼자 도 좋아요 \n']
# _
# Q:  ['짝 에 술 마시고 실수 했어']
# A:  ['\t 마음 이 아프네요 큰 실수 바랄게요 \n']
# p:  ['말 하기 쉽지 \n']
# _
# Q:  ['짝남 한테 감정 안 하고 싶다']
# A:  ['\t 짝사랑 때문 에 하는 감정 는 사람 을 힘들게 해 요 \n']
# p:  ['인기 가 \n']
# _
# Q:  ['짝남 한테 게임 초대 톡']
# A:  ['\t 게임 초대 \n']
# p:  ['상황 에 따라 \n']
# _
# Q:  ['짝남 한테 늦은 생일 선물 가는데 떨려']
# A:  ['\t 그 가 좋아할 거 예요 \n']
# p:  ['공부 도 와 달라 고 해보세요 \n']
# _
# Q:  ['짝남 한테 왔는데 답장 뭐라고 해야 할지 모르겠어']
# A:  ['\t 자연 스럽게 대화 를 좋아요 \n']
# p:  ['그럴 수 있어요 안부 인사 나 관심사 로 시작 하는 건 어떨까 요 \n']
# _
# Q:  ['짝남 한테 톡 와 있네']
# A:  ['\t 궁금하네요 \n']
# p:  ['후회 할 행동 은 좋아요 \n']
# _
# Q:  ['짝녀 때문 에 화가 나 요']
# A:  ['\t 안 좋은 일이 있었나 봐요 \n']
# p:  ['남자 사람 친구 여자 사람 친구 하세요 \n']
# _
# Q:  ['짝녀 마음 정리 하는 중이 데 자꾸 꿈 에']
# A:  ['\t 생각 이 많이 봅니다 \n']
# p:  ['생각 을 많이 해서 그런 가봐요 \n']
# _
# Q:  ['짝녀 보고 싶다']
# A:  ['\t 그럴 만 해 요 \n']
# p:  ['정리 가 할 수 있는 게 다른 일 것 같아요 \n']
# _
# Q:  ['짝녀 생각 에 잠 을']
# A:  ['\t 짝사랑 이 생각 을 만들어요 \n']
# p:  ['기억 과 함께 건 어떨까 요 \n']
# _
# Q:  ['짝녀 있는데 소개팅']
# A:  ['\t 그렇게 해도 돼요 \n']
# p:  ['그 분 생각 으로 잠 이 오지 봐요 \n']
# _
# Q:  ['짝녀 줄 있는 선물 추천 좀 해주세요']
# A:  ['\t 그녀 가 무엇 을 좋아하는지 주변 에 \n']
# p:  ['둘 중 에 하나 죠 \n']
# _
# Q:  ['짝녀 가 인데 요']
# A:  ['\t 기다릴 자신 이 없다면 정리 하는게 좋겠어요 \n']
# p:  ['직접 적 이든 간접 적 이든 의사 를 확실히 보세요 \n']
# _
# Q:  ['짝녀 가 나를 걸까']
# A:  ['\t 을 확실히 하는 편이 좋겠네요 \n']
# p:  ['상황 이 않는 으로 봐요 \n']
# _
# Q:  ['짝녀 가 날 너무 친구 로 생각 해']
# A:  ['\t 친구 이상 으로 생각 한다고 말 해보세요 \n']
# p:  ['이성 으로 대하 고 싶다고 말 해보세요 \n']
# _
# Q:  ['짝녀 가 톡 답장 하고 은 답장 안해']
# A:  ['\t 이네 요 \n']
# p:  ['좋아하는 마음 이 라면 이해 할 거 예요 \n']
# _
# Q:  ['짝녀 가 사람 이랑 헤어졌는데 고백 해도 되나']
# A:  ['\t 아직 마음 의 정리 가 조금 만 기다리는 게 좋겠네요 \n']
# p:  ['이 인가요 \n']
# _
# Q:  ['짝녀 가 예쁜 건 아닌데']
# A:  ['\t 외모 보다 마음 이 중요해요 \n']
# p:  ['나 는 나이 \n']
# _
# Q:  ['짝녀 가 인데 연락처 될까']
# A:  ['\t 연락처 물어보는 건 이에요 \n']
# p:  ['당신 이 상관 \n']
# _
# Q:  ['짝녀 가 우리 과 에서 인기 가 너무 많아']
# A:  ['\t 사람 들 보는 눈 이 \n']
# p:  ['적극 적 으로 요 \n']
# _
# Q:  ['짝녀 가 있는데 연애 는 인거 같아']
# A:  ['\t 연애 가 인 사람 은 없어요 \n']
# p:  ['그 분 이 미련 이 \n']
# _
# Q:  ['짝녀 가 못']
# A:  ['\t 시간 이 필요한 때 인 것 같아요 \n']
# p:  ['노력 하고 있어요 \n']
# _
# Q:  ['짝녀 가 저 한테 관심 이 없는 것 계속 연락 해도 될까 요']
# A:  ['\t 아직 아니라면 연락 좋을 것 같아요 \n']
# p:  ['수도 있지만 미리 걱정 하지 말아요 \n']
# _
# Q:  ['짝녀 가 좋아하는거 눈치 1 도 못']
# A:  ['\t 1 은 알 게 해야죠 \n']
# p:  ['\n']
# _
# Q:  ['짝녀 랑 이름 이 애']
# A:  ['\t 같은 이름 이라니 \n']
# p:  ['사랑 앞 에 \n']
# _
# Q:  ['짝녀 랑 드디어']
# A:  ['\t 좋은 소 네 요 \n']
# p:  ['부럽네요 \n']
# _
# Q:  ['짝녀 에게 남친 이']
# A:  ['\t 생각 해요 \n']
# p:  ['자연스러운 현상 이에요 \n']
# _
# Q:  ['짝녀 와 같이 데 어디 로 갈까']
# A:  ['\t 같이 분위기 있는 곳 이 좋겠어요 \n']
# p:  ['생각 을 \n']
# _
# Q:  ['짝녀 한테 고백 했는데 짝녀 가 오해 하게 해서 너무']
# A:  ['\t 생각 해요 \n']
# p:  ['에 따라 다를 것 같아요 \n']
# _
# Q:  ['짝녀 한테 고 싶지 내 가 싫다']
# A:  ['\t 자신 의 의지 를 히 하세요 \n']
# p:  ['상대 에게 믿음 을 주 하면 \n']
# _
# Q:  ['짝녀 한테 도 성격 이 왜 그럴까 요']
# A:  ['\t 있는게 아닐까 요 \n']
# p:  ['정말 나쁜 사람 이네 요 \n']
# _
# Q:  ['짝사랑 중 솔로 탈출 했어요']
# A:  ['\t 좋은 소 네 요 \n']
# p:  ['이 봐요 \n']
# _
# Q:  ['짝사랑 하는 남자 가 인데 어떻게 수 있을까']
# A:  ['\t 많이 만날 수 있는 를 만들어 보세요 \n']
# p:  ['서로 에게 부담 없는 작은 상대 에게 연락 해보세요 \n']
# _
# Q:  ['짝사랑 하는 사람 보다 좋은 사람']
# A:  ['\t 더 좋은 사람 만날 거 라 생각 해요 \n']
# p:  ['진심 을 위 한 최선 의 선택 일 거 라 생각 해요 \n']
# _
# Q:  ['짝사랑 하는 사람 이 날 좋아할 은']
# A:  ['\t 만큼 이 거 예요 \n']
# p:  ['다른 사람 을 좋아하게 \n']
# _
# Q:  ['짝사랑 하는 사람 이 너무 내 가 여']
# A:  ['\t 사랑 앞 에 해 요 \n']
# p:  ['그럴 수도 있어요 신경 쓰지 않는 연습 을 해봐요 \n']
# _
# Q:  ['짝사랑 하면 무슨 기분 인지 해 요']
# A:  ['\t 저 는 짝사랑 전공 이에요 \n']
# p:  ['짝사랑 이 전 에는 노력 하고 노력 해주세요 \n']
# _
# Q:  ['짝사랑 했던 그 에게 여자친구 가 생겼어']
# A:  ['\t 마음 이 \n']
# p:  ['이 수도 있겠어요 \n']
# _
# Q:  ['짝사랑 에서 연인 으로 발전 어떻게 해야 해']
# A:  ['\t 나 의 존재 를 인지 \n']
# p:  ['좋아하는 마음 은 힘들어요 \n']
# _
# Q:  ['짝사랑 인가 썸 인가']
# A:  ['\t 바랄게요 \n']
# p:  ['그 분 이 좋아하는 행동 이 무엇 인지 알아보세요 \n']
# _
# Q:  ['짝사랑 중 이야']
# A:  ['\t 진정 으로 사랑 한다면 그 사람 도 당신 의 사랑 을 \n']
# p:  ['사랑 에서 서로 의 에 \n']
# _
# Q:  ['짝사랑 한 만큼 상처 도']
# A:  ['\t 상처 가 시간 이 몰라요 \n']
# p:  ['그렇게 해 가 좋겠네요 \n']
# _
# Q:  ['차 없으면 데이트 못 해']
# A:  ['\t 하는 데이트 가 진정한 데이트 죠 \n']
# p:  ['적 인 소비 를 할 수 있을 거 예요 \n']
# _
# Q:  ['좋아하는 감정 이 않아요']
# A:  ['\t 정말 많이 봐요 \n']
# p:  ['알 면 제 가 하죠 \n']
# _
# Q:  ['건지 좋아하는 건지']
# A:  ['\t 말 해보세요 \n']
# p:  ['직접 물어보세요 \n']
# _
# Q:  ['처음 마음 이 첫사랑 인가']
# A:  ['\t 지지 않은 사랑 은 모두 \n']
# p:  ['반지 는 주변 사람 들 한테 물어보는 건 어떨까 요 \n']
# _
# Q:  ['의 짝사랑 이 기분']
# A:  ['\t 일이 있었나 봐요 \n']
# p:  ['사랑 만큼 변덕 것 도 \n']
# _
# Q:  ['첫 데이트 에 뭐 좋을까']
# A:  ['\t 좋아하는 걸 \n']
# p:  ['큰 선물 이 될 거 예요 \n']
# _
# Q:  ['첫 눈 에']
# A:  ['\t 운명 적 인 사랑 이네 요 \n']
# p:  ['\n']
# _
# Q:  ['첫 눈 에 좋아할 수 있어']
# A:  ['\t \n']
# p:  ['오늘 은 바지 가 같아요 \n']
# _
# Q:  ['첫사랑 다시 만나도 사랑 할 수 있을까']
# A:  ['\t 다시 만나는 건 을 일이 에요 \n']
# p:  ['진정 으로 사랑 한다면 같아요 \n']
# _
# Q:  ['첫사랑 생각나']
# A:  ['\t 추억 이라고 생각 해보세요 \n']
# p:  ['지금 의 사랑 에 \n']
# _
# Q:  ['첫사랑 을 다시 만났어']
# A:  ['\t 새로운 사랑 의 시작 이 되길 바라요 \n']
# p:  ['마음 이 정리 되길 바랄게요 \n']
# _
# Q:  ['첫사랑 을 추억 해']
# A:  ['\t 첫사랑 은 항상 추억 의 이 죠 \n']
# p:  ['새로운 스타일 도전 해 보시 면 어때요 \n']
# _
# Q:  ['첫사랑 이']
# A:  ['\t 마음 그냥 좋은 거 같아요 \n']
# p:  ['사랑 의 이 예요 \n']
# _
# Q:  ['청첩장 누구 한테 줘']
# A:  ['\t 그게 제일 고민 이 죠 \n']
# p:  ['당신 은 잘 지내고 있을 거 예요 \n']
# _
# Q:  ['에 헤어진 짝남 한테 연락 하면 주변 에서 욕 할까']
# A:  ['\t 주변 의 시선 을 신경 아무 것 도 못 해요 \n']
# p:  ['마음 이 \n']
# _
# Q:  ['에 헤어진 짝남 한테 지금 연락 하기는 너무']
# A:  ['\t 위로 를 연락 해보세요 \n']
# p:  ['많이 사랑 하 나 봐요 \n']
# _
# Q:  ['인데 연애 해도 될까']
# A:  ['\t 취업 이랑 연애 둘 다 잘 할 수 있을 거 예요 \n']
# p:  ['공부 랑 연애 랑 둘 다 잘 하고 싶은 욕심 네 요 \n']
# _
# Q:  ['취향 좀 존중']
# A:  ['\t 각자 마다 취향 이 있는 거 죠 \n']
# p:  ['좋은 생각 이에요 \n']
# _
# Q:  ['친구 같은 연애 하고 싶어']
# A:  ['\t 가 맞는 사람 을 찾아보세요 \n']
# p:  ['뭐 든 열심히 하는 사람 은 좋아 보여요 \n']
# _
# Q:  ['친구 들 이 이 덜 샤워']
# A:  ['\t 좋은 친구 들 \n']
# p:  ['너무 \n']
# _
# Q:  ['친한 동생 인데 짝사랑 하는 것 같습니다']
# A:  ['\t 사이 에서 있을 수 있는 일 입니다 \n']
# p:  ['언젠가 그런 것 같아요 \n']
# _
# Q:  ['친한 친구 가 저 를 좋아하는 것 같아요']
# A:  ['\t 가 걱정 되나 봐요 \n']
# p:  ['알 수 있을 거 예요 \n']
# _
# Q:  ['친한 친구 의 구 여친 이랑 되나']
# A:  ['\t 친구 라면 많이 \n']
# p:  ['바쁜 상황 일 수도 있어요 \n']
# _
# Q:  ['카톡 에 아직도 누구 티 내는 법 좀']
# A:  ['\t 의미 심장 한 가 어떨까 요 \n']
# p:  ['모습 을 해보세요 \n']
# _
# Q:  ['카톡 하고 자꾸 그러면 좋아하는 건가']
# A:  ['\t 그럴 거 예요 \n']
# p:  ['이제 는 만나면 돼요 \n']
# _
# Q:  ['하는 썸남 어때']
# A:  ['\t 그게 무슨 문제 인가요 \n']
# p:  ['사랑 에 나이 는 중요하지 않아요 \n']
# _
# Q:  ['큰 시험 짝사랑 하는 사랑 이']
# A:  ['\t 마음 을 좋겠어요 \n']
# p:  ['\n']
# _
# Q:  ['을 좋아하게 됐는데 고백 하면']
# A:  ['\t 서로 의 마음 에 확신 이 들 때 고백 하세요 \n']
# p:  ['잘 하는 것 도 좋은 방법 이에요 \n']
# _
# Q:  ['사랑 하고 싶어']
# A:  ['\t 가봐요 \n']
# p:  ['이 하는 것 처럼 반응 이 완전히 되죠 \n']
# _
# Q:  ['연애 어때']
# A:  ['\t 거 같아요 \n']
# p:  ['서로 에게 귀 방법 도 있어요 \n']
# _
# Q:  ['하고 많은 사람 중 에 왜']
# A:  ['\t 당신 이니까 요 \n']
# p:  ['감성 적 딱 좋죠 \n']
# _
# Q:  ['하루 종일 연락 하면 썸']
# A:  ['\t 친구 랑 하루 종일 연락 안해 요 \n']
# p:  ['호감 이 있을 수도 있어요 그렇지만 조금 더 상황 을 지켜보세요 \n']
# _
# Q:  ['학교 에 있는데 연락 해볼까']
# A:  ['\t 호감 을 어느 정도 표현 해보는 것 도 좋을 것 같아요 \n']
# p:  ['서로 가 한다면 상관 없어요 \n']
# _
# Q:  ['학원 에 좋아하는 여자애 가 있는데 말 거 는 방법 좀']
# A:  ['\t 라도 전하 대화 를 나눠 봐요 \n']
# p:  ['관심사 를 찾아보세요 \n']
# _
# Q:  ['만 호감 이면']
# A:  ['\t 짝사랑 입니다 \n']
# p:  ['다른 도전 을 해보세요 \n']
# _
# Q:  ['한 의 같은 우리']
# A:  ['\t \n']
# p:  ['잘 하고 있어요 \n']
# _
# Q:  ['항상 여친 집']
# A:  ['\t 시간 과 돈 이 \n']
# p:  ['저 도 \n']
# _
# Q:  ['이 성격 이랑 무슨 상관 이지']
# A:  ['\t 상관 없는 거 같아요 \n']
# p:  ['\n']
# _
# Q:  ['혼자 노력 하는 연애 인 거 같아']
# A:  ['\t 잠시 방법 이에요 \n']
# p:  ['만남 에 무슨 문제 는 \n']
# _
# Q:  ['혼자 썸 타는 기분 이야']
# A:  ['\t 직접 적 이든 간접 적 이든 의사 를 확실히 보세요 \n']
# p:  ['그 분 이 꼭 \n']
# _
# Q:  ['혼자 만 혼자 서 짝사랑']
# A:  ['\t 맘 고생 많았어요 \n']
# p:  ['혼자 인 것 보다 연락 하고 연락 해 보세요 \n']
# _
# Q:  ['에 고백 할까 요']
# A:  ['\t 선물 을 당당하게 고백 해보세요 \n']
# p:  ['선물 을 당당하게 고백 해보세요 \n']
# _
# Q:  ['확실히 날 좋아하는 걸 아는 남자 랑 친구 가 될 수 있을까']
# A:  ['\t 그 사람 을 위 그러면 안 돼요 \n']
# p:  ['그럴 수도 있어요 신경 쓰지 않는 연습 을 해봐요 \n']
# _
# Q:  ['해주는 짝남']
# A:  ['\t \n']
# p:  ['많이 바쁜 가봐요 \n']

# %% [markdown]
# ## Encoder with Attention

# %%
class EncoderA(tf.keras.Model):
    def __init__(self):
        super(EncoderA, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
        
    def call(self, x, training=False, mask=None):
        x = self.emb(x)
        H, h, c = self.lstm(x)
        return H, h, c

# %% [markdown]
# ## Decoder with Attention

# %%
class DecoderA(tf.keras.Model):
    def __init__(self):
        super(DecoderA, self).__init__()
        # Adding layers for shifted output
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        # decoder need to store whole state from lstm so return_sequences should be True
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
        self.att = tf.keras.layers.Attention()
        self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')
        
    def call(self, inputs, training=False, mask=None):
        y_, s0, c0, H = inputs
        S, h, c = self.lstm(y_, initial_state=[s0, c0])
        
        S_ = tf.concat([s0[:, tf.newaxis, :], S[:, :-1, :]], axis=1)
        A = self.att([S_, H])
        y = tf.concat([S, A], axis=-1)
        
        return self.dense(y), h, c

# %% [markdown]
# ## Seq2seq model with Attention

# %%
class Seq2seqA(tf.keras.Model):
    def __init__(self, sos, eos):
        super(Seq2seqA, self).__init__()
        self.enc = EncoderA()
        self.dec = DecoderA()
        self.sos = sos
        self.eos = eos
        
    def call(self, inputs, training=False, mask=None):
        # When training, input is just shifted, so the process is very simple
        if training:
            x, y = inputs
            H, h, c = self.enc(x)
            y, _, _ = self.dec((y, h, c, H))
            return y
        else:
            x = inputs
            H, h, c = self.enc(x)
            y = tf.convert_to_tensor(self.sos)
            y = tf.reshape(y, (1, 1))
            
            seq = tf.TensorArray(tf.int32, 64)
            
            # Through tf.range, we can iterate it with autoGraph
            for idx in tf.range(64):
                y, h, c = self.dec([y, h, c,H])
                
                # To convert sparse type
                y = tf.cast(tf.argmax(y, axis=-1), dtype=tf.int32)
                
                # To express batch shape
                y = tf.reshape(y, (1, 1))
                seq = seq.write(idx, y)
                
                if y == self.eos:
                    break
                
            return tf.reshape(seq.stack(), (1, 64))

# %%
# Create model
model = Seq2seqA(sos=tokenizer.word_index['\t'], eos=tokenizer.word_index['\n'])

# Define loss and optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# Define performance metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %%
@tf.function
def train_step(model, inputs, labels, loss_object, optimizer, train_loss, train_accuracy):
    output_labels = labels[:, 1:]
    shifted_labels = labels[:, :-1]
    
    with tf.GradientTape() as tape:
        predictions = model([inputs, shifted_labels], training=True)
        loss = loss_object(output_labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)
    train_accuracy(output_labels, predictions)
    
@tf.function
def test_step(model, inputs):
    return model(inputs, training=False)

# %%
for epoch in range(EPOCHS):
    for seqs, labels in train_ds:
        train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)
        
    template = 'Epoch {}, Loss: {}, Accuracy: {}'
    print(template.format(epoch + 1, 
                          train_loss.result(), 
                          train_accuracy.result() * 100))
    
    train_loss.reset_states()
    train_accuracy.reset_states()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fe5991dcd62d> in <module>
#       1 for epoch in range(EPOCHS):
#       2     for seqs, labels in train_ds:
# ----> 3         train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)
#       4
#       5     template = 'Epoch {}, Loss: {}, Accuracy: {}'
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     625       # This is the first call of __call__, so we have to initialize.
#     626       initializers = []
# --> 627       self._initialize(args, kwds, add_initializers_to=initializers)
#     628     finally:
#     629       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     504     self._concrete_stateful_fn = (
#     505         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 506             *args, **kwds))
#     507
#     508     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2444       args, kwargs = None, None
#    2445     with self._lock:
# -> 2446       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2447     return graph_function
#    2448
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2665             arg_names=arg_names,
#    2666             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2667             capture_by_value=self._capture_by_value),
#    2668         self._function_attributes,
#    2669         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     966           except Exception as e:  # pylint:disable=broad-except
#     967             if hasattr(e, "ag_error_metadata"):
# --> 968               raise e.ag_error_metadata.to_exception(e)
#     969             else:
#     970               raise
#
# ValueError: in user code:
#
#     <ipython-input-20-9a717ee3f867>:7 train_step  *
#         predictions = model([inputs, shifted_labels], training=True)
#     <ipython-input-17-f6d2cfd8c3d4>:14 call  *
#         y, _, _ = self.dec((y, h, c, H))
#     <ipython-input-16-7f3ef2b274f4>:13 call  *
#         S, h, c = self.lstm(y_, initial_state=[s0, c0])
#     /home/chanseok/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/recurrent.py:707 __call__  **
#         return super(RNN, self).__call__(inputs, **kwargs)
#     /home/chanseok/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py:886 __call__
#         self.name)
#     /home/chanseok/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/input_spec.py:180 assert_input_compatibility
#         str(x.shape.as_list()))
#
#     ValueError: Input 0 of layer lstm_1 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: [32, 64]
